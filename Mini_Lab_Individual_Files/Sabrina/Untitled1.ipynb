# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
data = pd.read_csv("C:/Users/sabri/Documents/Masters/Viz_6390/capex_data.csv")
pd.DataFrame(data)
# Out:
#                              Industry   Firms      CapEx  Depreciation  \
# 0                         Advertising    48.0     582.51        825.37
# 1                   Aerospace/Defense    85.0   10725.53      10952.94
# 2                       Air Transport    18.0   19791.43       9491.23
# 3                             Apparel    50.0    1692.04       1699.89
# 4                        Auto & Truck    14.0   37127.24      22605.93
# ..                                ...     ...        ...           ...
# 91                           Trucking    28.0   15675.96       4943.16
# 92                  Utility (General)    18.0   33551.80      15404.10
# 93                    Utility (Water)    19.0    2833.28        898.00
# 94                      Total Market   7209.0  951365.12     752027.59
# 95  Total Market (without financials)  6004.0  906257.79     734740.25
#
#     Cap/Ex/Dep  Acquisitions     NetRD  NetCapEx  EBITDA  Sales/Capital
# ...

# %%
data.head()
# Out:
#             Industry  Firms     CapEx  Depreciation  Cap/Ex/Dep  Acquisitions  \
# 0        Advertising   48.0    582.51        825.37        0.71        580.85
# 1  Aerospace/Defense   85.0  10725.53      10952.94        0.98      22898.04
# 2      Air Transport   18.0  19791.43       9491.23        2.09         14.10
# 3            Apparel   50.0   1692.04       1699.89        1.00       1105.95
# 4       Auto & Truck   14.0  37127.24      22605.93        1.64        135.10
#
#     NetRD  NetCapEx  EBITDA  Sales/Capital
# 0    0.76      0.01    0.14           5.78
# 1  137.08      0.06    0.62           3.72
# 2   11.60      0.06    0.66           1.40
# 3    0.01      0.02    0.23           1.62
# 4  688.61      0.05    1.58           0.90

# %%
data.describe()
# Out:
#              Firms          CapEx   Depreciation  Cap/Ex/Dep   Acquisitions  \
# count    96.000000      96.000000      96.000000   94.000000      96.000000
# mean    212.729167   29260.292500   23320.785938    1.462234   15047.843229
# std     946.695621  132837.747437  106178.880565    1.156660   68345.066516
# min       2.000000       7.090000       0.000000    0.150000     -97.310000
# 25%      20.000000    1876.092500    1365.815000    0.875000     412.000000
# 50%      43.000000    5158.625000    3976.780000    1.120000    2252.300000
# 75%      91.250000   11999.192500    9515.520000    1.632500    6808.600000
# max    7209.000000  951365.120000  752027.590000    7.370000  489171.180000
#
#               NetRD   NetCapEx     EBITDA  Sales/Capital
# count     96.000000  96.000000  93.000000      96.000000
# mean     897.779375   0.061875   0.932258       1.673125
# std     4177.268848   0.084134   2.643874       1.557775
# ...

# %%
alt.Chart(data).mark_point().encode(
    x='	CapEx:Q',
    y='NetRD:Q',
    color = 'Firms'
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
crime = pd.read_csv("C:/Users/sabri\Documents/GitHub/NewYorkCityCrimes2015/Lab2_Individual_Files/Sabrina/Crime_TS2.csv")

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CMPLNT_FR_DT         4380 non-null   object
#  1   Daytime              4380 non-null   object
#  2   Day                  4380 non-null   int64
#  3   Day_Name             4380 non-null   object
#  4   Precip               4380 non-null   float64
#  5   Holiday              4380 non-null   int64
#  6   Temp_Min             4380 non-null   int64
#  7   Temp_Max             4380 non-null   int64
#  8   Is_Event             4380 non-null   int64
#  9   Sum of count_cmplnt  4380 non-null   int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 342.3+ KB

# %%
alt.Chart(crime).mark_point().encode(
    x='Precip:Q',
    y='Sum.of.count_cmplnt:Q',
    color = 'Day:N'
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
