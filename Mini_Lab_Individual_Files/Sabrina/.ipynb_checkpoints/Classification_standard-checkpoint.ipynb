# %% [markdown]
# ## Setting Up the Data

# %%
import pandas as pd
import numpy as np

# %%
crime = pd.read_csv('Training_and_Test_Set.csv') # read in the csv %%file

# %%
crime.dtypes
# Out:
# JURIS_DESC            object
# BORO_NM               object
# ADDR_PCT_CD          float64
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# Day_Name              object
# Duration             float64
# Duration_to_PD       float64
# Month                 object
# Day                  float64
# Year                 float64
# Duration_lbl          object
# Season                object
# Daytime               object
# GeoCell              float64
# GeoCell_X            float64
# GeoCell_Y            float64
# y                      int64
# dtype: object

# %%
crime.head()
# Out:
#          JURIS_DESC        BORO_NM  ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 0  N.Y. POLICE DEPT  STATEN ISLAND        120.0            INSIDE
# 1  N.Y. POLICE DEPT  STATEN ISLAND        121.0            INSIDE
# 2  N.Y. POLICE DEPT          BRONX         43.0            INSIDE
# 3  N.Y. POLICE DEPT       BROOKLYN         75.0            INSIDE
# 4  N.Y. POLICE DEPT      MANHATTAN          6.0          FRONT OF
#
#             PREM_TYP_DESC Day_Name  Duration  Duration_to_PD      Month   Day  \
# 0     COMMERCIAL BUILDING   Friday       3.0             0.0  September   5.0
# 1         RESIDENCE-HOUSE   Sunday       1.0             0.0   December  27.0
# 2  RESIDENCE - APT. HOUSE   Sunday      14.0           171.0  September   1.0
# 3         RESIDENCE-HOUSE   Friday       6.0            28.0    October  10.0
# 4                  STREET   Sunday       1.0             0.0  September  28.0
#
#      Year Duration_lbl  Season        Daytime  GeoCell  GeoCell_X  GeoCell_Y  \
# 0  2014.0        Short    Fall        Morning     23.0        3.0        3.0
# 1  2015.0        Short  Winter            Day     23.0        3.0        3.0
# 2  2013.0       Medium    Fall          Night     78.0        8.0        8.0
# 3  2014.0        Short    Fall            Day     47.0        7.0        5.0
# 4  2014.0        Short    Fall  Early Morning     55.0        5.0        6.0
#
#    y
# 0  0
# 1  1
# 2  0
# 3  0
# 4  0

# %%
### This was all done as part of the data prep and is now 'y' in the dataset

#Create categorical list of all 68 possible offenses
#4 types of crime: Personal, Property, Statutory/State, and Other

#Personal - Assault, Battery, Abuse, Kidnapping, Rape, Homicide, Harrassment
#personal_list = ['ASSAULT', 'BATTERY', 'MURDER', 'MANSLAUGHTER', 'HARRASSMENT', 'KIDNAPPING', 'RAPE', 'SEX', 'HOMICIDE', 'WEAPON', 'WEAPONS', 'PERSON']

#Property - Arson, Theft, Mischief, Burglary, Larceny, Robbery, Forgery, Embezzlement, Shoplifting, Trespass, Fraud/Financial
#property_list = ['ARSON', 'THEFT', 'THEF', 'MISCHIEF', 'ROBBERY', 'BURGLARY', 'JOSTLING', 'TOOLS', 'FRAUD', 'FRAUDS', 'FRAUDULENT', 'LARCENY', 'FORGERY', 'STOLEN', 'UNAUTHORIZED', 'TRESPASS']

#Statutory - State-Related offenses, DUI, DWI, Gambling, Loitering, Drug, Traffic, Public Servant/Admin-related crimes
#statutory_list = ['DRUGS', 'DRUG', 'SENSBLTY', 'PENAL', 'PUBLIC', 'INTOXICATED', 'TRAFFIC', 'ADMINISTRATIVE', 'GAMBLING', 'PROSTITUTION', 'ALCOHOLIC', 'DISORDERLY']

#Violent vs Non-Violent
#violent = personal_list
#non_violent = property_list + statutory_list

# %%
#Value Counts by Crime Type
crime['y'].value_counts()
# Out:
# 0    365333
# 1    163540
# Name: y, dtype: int64

# %%
#dropping any remaining NANs
crime = crime.dropna()

# %%
crime.isnull().values.any()
# Out:
# False

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528873 entries, 0 to 528872
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   JURIS_DESC         528873 non-null  object
#  1   BORO_NM            528873 non-null  object
#  2   ADDR_PCT_CD        528873 non-null  float64
#  3   LOC_OF_OCCUR_DESC  528873 non-null  object
#  4   PREM_TYP_DESC      528873 non-null  object
#  5   Day_Name           528873 non-null  object
#  6   Duration           528873 non-null  float64
#  7   Duration_to_PD     528873 non-null  float64
#  8   Month              528873 non-null  object
#  9   Day                528873 non-null  float64
#  10  Year               528873 non-null  float64
#  11  Duration_lbl       528873 non-null  object
#  12  Season             528873 non-null  object
#  13  Daytime            528873 non-null  object
#  14  GeoCell            528873 non-null  float64
#  15  GeoCell_X          528873 non-null  float64
#  16  GeoCell_Y          528873 non-null  float64
#  17  y                  528873 non-null  int64
# dtypes: float64(8), int64(1), object(9)
# memory usage: 76.7+ MB

# %%
# replace the current Violent Crime classification atribute with something slightly more intuitive and readable
#crime['NonViolent'] = crime.OFNS_DESC_TYPE=='Non-Violent Crime' 
#crime.NonViolent = crime.NonViolent.astype(np.int)

# %%
# perform one-hot encoding of the categorical data on 'JURIS_DESC','BORO_NM','LOC_OF_OCCUR_DESC',
#'ADDR_PCT_CD','PREM_TYP_DESC','Day_Name','Month','Duration_lbl','Season','Daytime'
tmp_df = pd.get_dummies(crime.JURIS_DESC,prefix='JURIS_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.BORO_NM,prefix='BORO_NM')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.LOC_OF_OCCUR_DESC,prefix='LOC_OF_OCCUR_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.ADDR_PCT_CD,prefix='ADDR_PCT_CD')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.PREM_TYP_DESC,prefix='PREM_TYP_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Day_Name,prefix='Day_Name')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Month,prefix='Month')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Duration_lbl,prefix='Duration_lbl')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Season,prefix='Season')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Daytime,prefix='Daytime')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528873 entries, 0 to 528872
# Columns: 225 entries, JURIS_DESC to Daytime_Night
# dtypes: float64(8), int64(1), object(9), uint8(207)
# memory usage: 181.1+ MB

# %%
#Now we drop the original variables
if 'JURIS_DESC' in crime:    
    del crime['JURIS_DESC'] # get rid of the original category as it is now one-hot encoded
if 'BORO_NM' in crime:    
    del crime['BORO_NM'] # get rid of the original category as it is now one-hot encoded
if 'LOC_OF_OCCUR_DESC' in crime:    
    del crime['LOC_OF_OCCUR_DESC'] # get rid of the original category as it is now one-hot encoded
if 'ADDR_PCT_CD' in crime:    
    del crime['ADDR_PCT_CD'] # get rid of the original category as it is now one-hot encoded
if 'PREM_TYP_DESC' in crime:    
    del crime['PREM_TYP_DESC'] # get rid of the original category as it is now one-hot encoded
if 'Day_Name' in crime:    
    del crime['Day_Name'] # get rid of the original category as it is now one-hot encoded
if 'Month' in crime:    
    del crime['Month'] # get rid of the original category as it is now one-hot encoded
if 'Duration_lbl' in crime:    
    del crime['Duration_lbl'] # get rid of the original category as it is now one-hot encoded
if 'Season' in crime:    
    del crime['Season'] # get rid of the original category as it is now one-hot encoded
if 'Daytime' in crime:    
    del crime['Daytime'] # get rid of the original category as it is now one-hot encoded

# %%
pd.set_option('display.max_rows', 300)
crime.dtypes
# Out:
# Duration                                      float64
# Duration_to_PD                                float64
# Day                                           float64
# Year                                          float64
# GeoCell                                       float64
# GeoCell_X                                     float64
# GeoCell_Y                                     float64
# y                                               int64
# JURIS_DESC_AMTRACK                              uint8
# JURIS_DESC_DEPT OF CORRECTIONS                  uint8
# JURIS_DESC_HEALTH & HOSP CORP                   uint8
# JURIS_DESC_LONG ISLAND RAILRD                   uint8
# JURIS_DESC_METRO NORTH                          uint8
# JURIS_DESC_N.Y. HOUSING POLICE                  uint8
# JURIS_DESC_N.Y. POLICE DEPT                     uint8
# JURIS_DESC_N.Y. STATE PARKS                     uint8
# JURIS_DESC_N.Y. STATE POLICE                    uint8
# JURIS_DESC_N.Y. TRANSIT POLICE                  uint8
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE         uint8
# JURIS_DESC_NYC PARKS                            uint8
# JURIS_DESC_NYS DEPT TAX AND FINANCE             uint8
# JURIS_DESC_OTHER                                uint8
# JURIS_DESC_POLICE DEPT NYC                      uint8
# JURIS_DESC_PORT AUTHORITY                       uint8
# JURIS_DESC_STATN IS RAPID TRANS                 uint8
# JURIS_DESC_TRI-BORO BRDG TUNNL                  uint8
# JURIS_DESC_U.S. PARK POLICE                     uint8
# BORO_NM_BRONX                                   uint8
# BORO_NM_BROOKLYN                                uint8
# BORO_NM_MANHATTAN                               uint8
# BORO_NM_QUEENS                                  uint8
# BORO_NM_STATEN ISLAND                           uint8
# LOC_OF_OCCUR_DESC_FRONT OF                      uint8
# LOC_OF_OCCUR_DESC_INSIDE                        uint8
# LOC_OF_OCCUR_DESC_OPPOSITE OF                   uint8
# LOC_OF_OCCUR_DESC_REAR OF                       uint8
# ADDR_PCT_CD_1.0                                 uint8
# ADDR_PCT_CD_5.0                                 uint8
# ADDR_PCT_CD_6.0                                 uint8
# ADDR_PCT_CD_7.0                                 uint8
# ADDR_PCT_CD_9.0                                 uint8
# ADDR_PCT_CD_10.0                                uint8
# ADDR_PCT_CD_13.0                                uint8
# ADDR_PCT_CD_14.0                                uint8
# ADDR_PCT_CD_17.0                                uint8
# ADDR_PCT_CD_18.0                                uint8
# ADDR_PCT_CD_19.0                                uint8
# ADDR_PCT_CD_20.0                                uint8
# ADDR_PCT_CD_22.0                                uint8
# ADDR_PCT_CD_23.0                                uint8
# ADDR_PCT_CD_24.0                                uint8
# ADDR_PCT_CD_25.0                                uint8
# ADDR_PCT_CD_26.0                                uint8
# ADDR_PCT_CD_28.0                                uint8
# ADDR_PCT_CD_30.0                                uint8
# ADDR_PCT_CD_32.0                                uint8
# ADDR_PCT_CD_33.0                                uint8
# ADDR_PCT_CD_34.0                                uint8
# ADDR_PCT_CD_40.0                                uint8
# ADDR_PCT_CD_41.0                                uint8
# ADDR_PCT_CD_42.0                                uint8
# ADDR_PCT_CD_43.0                                uint8
# ADDR_PCT_CD_44.0                                uint8
# ADDR_PCT_CD_45.0                                uint8
# ADDR_PCT_CD_46.0                                uint8
# ADDR_PCT_CD_47.0                                uint8
# ADDR_PCT_CD_48.0                                uint8
# ADDR_PCT_CD_49.0                                uint8
# ADDR_PCT_CD_50.0                                uint8
# ADDR_PCT_CD_52.0                                uint8
# ADDR_PCT_CD_60.0                                uint8
# ADDR_PCT_CD_61.0                                uint8
# ADDR_PCT_CD_62.0                                uint8
# ADDR_PCT_CD_63.0                                uint8
# ADDR_PCT_CD_66.0                                uint8
# ADDR_PCT_CD_67.0                                uint8
# ADDR_PCT_CD_68.0                                uint8
# ADDR_PCT_CD_69.0                                uint8
# ADDR_PCT_CD_70.0                                uint8
# ADDR_PCT_CD_71.0                                uint8
# ADDR_PCT_CD_72.0                                uint8
# ADDR_PCT_CD_73.0                                uint8
# ADDR_PCT_CD_75.0                                uint8
# ADDR_PCT_CD_76.0                                uint8
# ADDR_PCT_CD_77.0                                uint8
# ADDR_PCT_CD_78.0                                uint8
# ADDR_PCT_CD_79.0                                uint8
# ADDR_PCT_CD_81.0                                uint8
# ADDR_PCT_CD_83.0                                uint8
# ADDR_PCT_CD_84.0                                uint8
# ADDR_PCT_CD_88.0                                uint8
# ADDR_PCT_CD_90.0                                uint8
# ADDR_PCT_CD_94.0                                uint8
# ADDR_PCT_CD_100.0                               uint8
# ADDR_PCT_CD_101.0                               uint8
# ADDR_PCT_CD_102.0                               uint8
# ADDR_PCT_CD_103.0                               uint8
# ADDR_PCT_CD_104.0                               uint8
# ADDR_PCT_CD_105.0                               uint8
# ADDR_PCT_CD_106.0                               uint8
# ADDR_PCT_CD_107.0                               uint8
# ADDR_PCT_CD_108.0                               uint8
# ADDR_PCT_CD_109.0                               uint8
# ADDR_PCT_CD_110.0                               uint8
# ADDR_PCT_CD_111.0                               uint8
# ADDR_PCT_CD_112.0                               uint8
# ADDR_PCT_CD_113.0                               uint8
# ADDR_PCT_CD_114.0                               uint8
# ADDR_PCT_CD_115.0                               uint8
# ADDR_PCT_CD_120.0                               uint8
# ADDR_PCT_CD_121.0                               uint8
# ADDR_PCT_CD_122.0                               uint8
# ADDR_PCT_CD_123.0                               uint8
# PREM_TYP_DESC_ABANDONED BUILDING                uint8
# PREM_TYP_DESC_AIRPORT TERMINAL                  uint8
# PREM_TYP_DESC_ATM                               uint8
# PREM_TYP_DESC_BANK                              uint8
# PREM_TYP_DESC_BAR/NIGHT CLUB                    uint8
# PREM_TYP_DESC_BEAUTY & NAIL SALON               uint8
# PREM_TYP_DESC_BOOK/CARD                         uint8
# PREM_TYP_DESC_BRIDGE                            uint8
# PREM_TYP_DESC_BUS (NYC TRANSIT)                 uint8
# PREM_TYP_DESC_BUS (OTHER)                       uint8
# PREM_TYP_DESC_BUS STOP                          uint8
# PREM_TYP_DESC_BUS TERMINAL                      uint8
# PREM_TYP_DESC_CANDY STORE                       uint8
# PREM_TYP_DESC_CEMETERY                          uint8
# PREM_TYP_DESC_CHAIN STORE                       uint8
# PREM_TYP_DESC_CHECK CASHING BUSINESS            uint8
# PREM_TYP_DESC_CHURCH                            uint8
# PREM_TYP_DESC_CLOTHING/BOUTIQUE                 uint8
# PREM_TYP_DESC_COMMERCIAL BUILDING               uint8
# PREM_TYP_DESC_CONSTRUCTION SITE                 uint8
# PREM_TYP_DESC_DEPARTMENT STORE                  uint8
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE             uint8
# PREM_TYP_DESC_DRUG STORE                        uint8
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY               uint8
# PREM_TYP_DESC_FACTORY/WAREHOUSE                 uint8
# PREM_TYP_DESC_FAST FOOD                         uint8
# PREM_TYP_DESC_FERRY/FERRY TERMINAL              uint8
# PREM_TYP_DESC_FOOD SUPERMARKET                  uint8
# PREM_TYP_DESC_GAS STATION                       uint8
# PREM_TYP_DESC_GROCERY/BODEGA                    uint8
# PREM_TYP_DESC_GYM/FITNESS FACILITY              uint8
# PREM_TYP_DESC_HIGHWAY/PARKWAY                   uint8
# PREM_TYP_DESC_HOSPITAL                          uint8
# PREM_TYP_DESC_HOTEL/MOTEL                       uint8
# PREM_TYP_DESC_JEWELRY                           uint8
# PREM_TYP_DESC_LIQUOR STORE                      uint8
# PREM_TYP_DESC_LOAN COMPANY                      uint8
# PREM_TYP_DESC_MARINA/PIER                       uint8
# PREM_TYP_DESC_MOSQUE                            uint8
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS)            uint8
# PREM_TYP_DESC_OTHER                             uint8
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP            uint8
# PREM_TYP_DESC_PARK/PLAYGROUND                   uint8
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)      uint8
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)       uint8
# PREM_TYP_DESC_PHOTO/COPY                        uint8
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL          uint8
# PREM_TYP_DESC_PUBLIC BUILDING                   uint8
# PREM_TYP_DESC_PUBLIC SCHOOL                     uint8
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE            uint8
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING        uint8
# PREM_TYP_DESC_RESIDENCE-HOUSE                   uint8
# PREM_TYP_DESC_RESTAURANT/DINER                  uint8
# PREM_TYP_DESC_SHOE                              uint8
# PREM_TYP_DESC_SMALL MERCHANT                    uint8
# PREM_TYP_DESC_SOCIAL CLUB/POLICY                uint8
# PREM_TYP_DESC_STORAGE FACILITY                  uint8
# PREM_TYP_DESC_STORE UNCLASSIFIED                uint8
# PREM_TYP_DESC_STREET                            uint8
# PREM_TYP_DESC_SYNAGOGUE                         uint8
# PREM_TYP_DESC_TAXI (LIVERY LICENSED)            uint8
# PREM_TYP_DESC_TAXI (YELLOW LICENSED)            uint8
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED)          uint8
# PREM_TYP_DESC_TELECOMM. STORE                   uint8
# PREM_TYP_DESC_TRAMWAY                           uint8
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY              uint8
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER)          uint8
# PREM_TYP_DESC_TUNNEL                            uint8
# PREM_TYP_DESC_VARIETY STORE                     uint8
# PREM_TYP_DESC_VIDEO STORE                       uint8
# Day_Name_Friday                                 uint8
# Day_Name_Monday                                 uint8
# Day_Name_Saturday                               uint8
# Day_Name_Sunday                                 uint8
# Day_Name_Thursday                               uint8
# Day_Name_Tuesday                                uint8
# Day_Name_Wednesday                              uint8
# Month_April                                     uint8
# Month_August                                    uint8
# Month_December                                  uint8
# Month_February                                  uint8
# Month_January                                   uint8
# Month_July                                      uint8
# Month_June                                      uint8
# Month_March                                     uint8
# Month_May                                       uint8
# Month_November                                  uint8
# Month_October                                   uint8
# Month_September                                 uint8
# Duration_lbl_Long                               uint8
# Duration_lbl_Medium                             uint8
# Duration_lbl_Short                              uint8
# Season_Fall                                     uint8
# Season_Spring                                   uint8
# Season_Summer                                   uint8
# Season_Winter                                   uint8
# Daytime_Day                                     uint8
# Daytime_Early Morning                           uint8
# Daytime_Evening                                 uint8
# Daytime_Late Night                              uint8
# Daytime_Morning                                 uint8
# Daytime_Night                                   uint8
# dtype: object

# %%
#Balancing the Dataset

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'y' in crime:
    y = crime['y'].values # get the labels we want
    del crime['y'] # get rid of the class label
    X = crime.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn

# %% [markdown]
# ## Logistic Regression Model 1

# %%
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
# run logistic regression and vary some parameters
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt

# first we create a reusable logisitic regression object
#   here we can setup the object with different learning parameters and constants
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None, solver='liblinear' ) # get object

# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("confusion matrix\n",conf)
    iter_num+=1
    
# Also note that every time you run the above code
#   it randomly creates a new training and testing set, 
#   so accuracy will be different each time
# Out:
# ====Iteration 0  ====
# accuracy 0.7326022216969983
# confusion matrix
#  [[62552 10570]
#  [17714 14939]]
# ====Iteration 1  ====
# accuracy 0.7303616166390924
# confusion matrix
#  [[63596  9513]
#  [19008 13658]]
# ====Iteration 2  ====
# accuracy 0.7263247459229497
# confusion matrix
#  [[63693  9223]
#  [19725 13134]]

# %%
# this does the exact same thing as the above block of code, but with shorter syntax

for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
    lr_clf.fit(X[train_indices],y[train_indices])  # train object
    y_hat = lr_clf.predict(X[test_indices]) # get test set precitions

    # print the accuracy and confusion matrix 
    print("====Iteration",iter_num," ====")
    print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
    print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# ====Iteration 0  ====
# accuracy 0.7310801229023871
# confusion matrix
#  [[63801  9537]
#  [18908 13529]]
# ====Iteration 1  ====
# accuracy 0.7273079650200898
# confusion matrix
#  [[64011  8885]
#  [19959 12920]]
# ====Iteration 2  ====
# accuracy 0.7271094303947058
# confusion matrix
#  [[62862 10056]
#  [18809 14048]]

# %%
# and here is an even shorter way of getting the accuracies for each training and test set
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(lr_clf, X, y=y, cv=cv_object) # this also can help with parallelism
print(accuracies)
# Out:
# [0.72620184 0.72826282 0.72866935]

# %%
# here we can change some of the parameters interactively
from ipywidgets import widgets as wd

def lr_explor(cost):
    lr_clf = LogisticRegression(penalty='l2', C=cost, class_weight=None,solver='liblinear') # get object
    accuracies = cross_val_score(lr_clf,X,y=y,cv=cv_object) # this also can help with parallelism
    print(accuracies)

wd.interact(lr_explor,cost=(0.001,5.0,0.05),__manual=True)
# Out:
# interactive(children=(FloatSlider(value=2.451, description='cost', max=5.0, min=0.001, step=0.05), Output()), …
# <function __main__.lr_explor(cost)>

# %%
# interpret the weights

# iterate over the coefficients
weights = lr_clf.coef_.T # take transpose to make a column vector
variable_names = crime.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
# Out:
# Duration has weight of -0.23628844062335957
# Duration_to_PD has weight of -0.0006010763813712672
# Day has weight of 0.00033963514769972975
# Year has weight of -0.00031188771074477814
# GeoCell has weight of 0.00020118607172487903
# GeoCell_X has weight of 0.03109419286219269
# GeoCell_Y has weight of -0.0038212176097626787
# JURIS_DESC_AMTRACK has weight of 7.108257418293816e-05
# JURIS_DESC_DEPT OF CORRECTIONS has weight of -0.025151734356524912
# JURIS_DESC_HEALTH & HOSP CORP has weight of 0.06601869224711802
# JURIS_DESC_LONG ISLAND RAILRD has weight of -0.001044115187290764
# JURIS_DESC_METRO NORTH has weight of 0.00034280342179901654
# JURIS_DESC_N.Y. HOUSING POLICE has weight of 0.36812461748894976
# JURIS_DESC_N.Y. POLICE DEPT has weight of -0.22209516324343426
# JURIS_DESC_N.Y. STATE PARKS has weight of -0.0007550330015095624
# JURIS_DESC_N.Y. STATE POLICE has weight of -0.041138518448666145
# JURIS_DESC_N.Y. TRANSIT POLICE has weight of -0.0011118431059078723
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE has weight of -0.0003948117194155119
# JURIS_DESC_NYC PARKS has weight of -0.001366639895103877
# JURIS_DESC_NYS DEPT TAX AND FINANCE has weight of -0.0013854860705633915
# JURIS_DESC_OTHER has weight of -0.11453760754264972
# JURIS_DESC_POLICE DEPT NYC has weight of 0.0006435643453132448
# JURIS_DESC_PORT AUTHORITY has weight of 0.004445516580946394
# JURIS_DESC_STATN IS RAPID TRANS has weight of -0.0003840957149081467
# JURIS_DESC_TRI-BORO BRDG TUNNL has weight of -0.0317560967794211
# JURIS_DESC_U.S. PARK POLICE has weight of 0.0007429514681465794
# BORO_NM_BRONX has weight of 0.04828892473140172
# BORO_NM_BROOKLYN has weight of -0.07277357720718415
# BORO_NM_MANHATTAN has weight of -0.2920087932879427
# BORO_NM_QUEENS has weight of 0.010568058171278481
# BORO_NM_STATEN ISLAND has weight of 0.3051934706552473
# LOC_OF_OCCUR_DESC_FRONT OF has weight of 0.39420129471427234
# LOC_OF_OCCUR_DESC_INSIDE has weight of 0.4820625170976067
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of -0.3966767879989324
# LOC_OF_OCCUR_DESC_REAR OF has weight of -0.48031894074992704
# ADDR_PCT_CD_1.0 has weight of -0.13722952305166758
# ADDR_PCT_CD_5.0 has weight of -0.0021648451041779812
# ADDR_PCT_CD_6.0 has weight of -0.1654476184084468
# ADDR_PCT_CD_7.0 has weight of 0.09888000938364387
# ADDR_PCT_CD_9.0 has weight of -0.1501571399321898
# ADDR_PCT_CD_10.0 has weight of -0.08746210315990674
# ADDR_PCT_CD_13.0 has weight of -0.13759904100336834
# ADDR_PCT_CD_14.0 has weight of -0.26149005701283023
# ADDR_PCT_CD_17.0 has weight of -0.041549484553494914
# ADDR_PCT_CD_18.0 has weight of 0.012747194023477494
# ADDR_PCT_CD_19.0 has weight of -0.3124273709121467
# ADDR_PCT_CD_20.0 has weight of -0.045419579342156034
# ADDR_PCT_CD_22.0 has weight of -0.0012777906262153172
# ADDR_PCT_CD_23.0 has weight of 0.07476660211338816
# ADDR_PCT_CD_24.0 has weight of 0.036007964993938844
# ADDR_PCT_CD_25.0 has weight of 0.008734643380120997
# ADDR_PCT_CD_26.0 has weight of 0.029035388327433125
# ADDR_PCT_CD_28.0 has weight of 0.016412924076027527
# ADDR_PCT_CD_30.0 has weight of 0.24971311673045554
# ADDR_PCT_CD_32.0 has weight of 0.17894017649353128
# ADDR_PCT_CD_33.0 has weight of 0.1394858121538992
# ADDR_PCT_CD_34.0 has weight of 0.2054919281427608
# ADDR_PCT_CD_40.0 has weight of -0.10727018825045795
# ADDR_PCT_CD_41.0 has weight of 0.05028158989044379
# ADDR_PCT_CD_42.0 has weight of 0.10376904342420222
# ADDR_PCT_CD_43.0 has weight of -0.02879996679406606
# ADDR_PCT_CD_44.0 has weight of 0.12889065339230055
# ADDR_PCT_CD_45.0 has weight of 0.013898275729595297
# ADDR_PCT_CD_46.0 has weight of 0.09635606799213259
# ADDR_PCT_CD_47.0 has weight of 0.056570835765863414
# ADDR_PCT_CD_48.0 has weight of -0.0024410723816032727
# ADDR_PCT_CD_49.0 has weight of -0.07978373078752661
# ADDR_PCT_CD_50.0 has weight of -0.05433379694006475
# ADDR_PCT_CD_52.0 has weight of -0.1288487863094045
# ADDR_PCT_CD_60.0 has weight of 0.06516836919822502
# ADDR_PCT_CD_61.0 has weight of -0.14621987554247445
# ADDR_PCT_CD_62.0 has weight of 0.03614545320684264
# ADDR_PCT_CD_63.0 has weight of -0.037366935974526665
# ADDR_PCT_CD_66.0 has weight of -0.09065061005184616
# ADDR_PCT_CD_67.0 has weight of 0.30232312301914127
# ADDR_PCT_CD_68.0 has weight of -0.01222961543075263
# ADDR_PCT_CD_69.0 has weight of 0.15108367146424367
# ADDR_PCT_CD_70.0 has weight of -0.03399353461981692
# ADDR_PCT_CD_71.0 has weight of 0.016598983239744767
# ADDR_PCT_CD_72.0 has weight of 0.10241428920446341
# ADDR_PCT_CD_73.0 has weight of 0.17075306250318523
# ADDR_PCT_CD_75.0 has weight of 0.09788695054319112
# ADDR_PCT_CD_76.0 has weight of -0.03179208748558938
# ADDR_PCT_CD_77.0 has weight of 0.04458325441406086
# ADDR_PCT_CD_78.0 has weight of -0.15652383087598024
# ADDR_PCT_CD_79.0 has weight of 0.06607183410675067
# ADDR_PCT_CD_81.0 has weight of 0.06254151671495257
# ADDR_PCT_CD_83.0 has weight of -0.0889027138038599
# ADDR_PCT_CD_84.0 has weight of -0.0873252367303926
# ADDR_PCT_CD_88.0 has weight of -0.037280621390983135
# ADDR_PCT_CD_90.0 has weight of -0.30347221103313193
# ADDR_PCT_CD_94.0 has weight of -0.16206384882515384
# ADDR_PCT_CD_100.0 has weight of 0.03473041291982764
# ADDR_PCT_CD_101.0 has weight of 0.0649539406808592
# ADDR_PCT_CD_102.0 has weight of 0.11509510635590343
# ADDR_PCT_CD_103.0 has weight of 0.10141817729249493
# ADDR_PCT_CD_104.0 has weight of 0.04707651217183389
# ADDR_PCT_CD_105.0 has weight of 0.038327455007421386
# ADDR_PCT_CD_106.0 has weight of -0.08907565561530494
# ADDR_PCT_CD_107.0 has weight of -0.07410696563969973
# ADDR_PCT_CD_108.0 has weight of 0.09449040315599805
# ADDR_PCT_CD_109.0 has weight of -0.07042156099458868
# ADDR_PCT_CD_110.0 has weight of -0.08119453577391786
# ADDR_PCT_CD_111.0 has weight of -0.11969255435054162
# ADDR_PCT_CD_112.0 has weight of -0.2191257902624729
# ADDR_PCT_CD_113.0 has weight of -0.018003734201712387
# ADDR_PCT_CD_114.0 has weight of 0.11925618983738955
# ADDR_PCT_CD_115.0 has weight of 0.06631769453030346
# ADDR_PCT_CD_120.0 has weight of 0.18088424788391053
# ADDR_PCT_CD_121.0 has weight of 0.03966122182171959
# ADDR_PCT_CD_122.0 has weight of 0.012727106076740533
# ADDR_PCT_CD_123.0 has weight of 0.07192089487288715
# PREM_TYP_DESC_ABANDONED BUILDING has weight of -0.021138494647757407
# PREM_TYP_DESC_AIRPORT TERMINAL has weight of 0.0005412520330744007
# PREM_TYP_DESC_ATM has weight of -0.08406899969034017
# PREM_TYP_DESC_BANK has weight of -0.2504360382534374
# PREM_TYP_DESC_BAR/NIGHT CLUB has weight of 0.42841922684806294
# PREM_TYP_DESC_BEAUTY & NAIL SALON has weight of 0.07926558164941368
# PREM_TYP_DESC_BOOK/CARD has weight of -0.01835894820242858
# PREM_TYP_DESC_BRIDGE has weight of -0.03046819285159986
# PREM_TYP_DESC_BUS (NYC TRANSIT) has weight of 0.051522590440606884
# PREM_TYP_DESC_BUS (OTHER) has weight of 0.029525128557917175
# PREM_TYP_DESC_BUS STOP has weight of 0.004062427569915795
# PREM_TYP_DESC_BUS TERMINAL has weight of 0.02090584602651769
# PREM_TYP_DESC_CANDY STORE has weight of 0.03408733520015477
# PREM_TYP_DESC_CEMETERY has weight of 0.0016721947962139324
# PREM_TYP_DESC_CHAIN STORE has weight of -1.2128257922289531
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of -0.09978166107802806
# PREM_TYP_DESC_CHURCH has weight of -0.008244664697205261
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of -0.7524554630443123
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of -0.06982797385346759
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of -0.029921351784375126
# PREM_TYP_DESC_DEPARTMENT STORE has weight of -1.442522934582094
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE has weight of 0.08523400291365643
# PREM_TYP_DESC_DRUG STORE has weight of -0.8297490938149849
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY has weight of -0.027617059054635174
# PREM_TYP_DESC_FACTORY/WAREHOUSE has weight of 0.011302952386176476
# PREM_TYP_DESC_FAST FOOD has weight of 0.055472029606685756
# PREM_TYP_DESC_FERRY/FERRY TERMINAL has weight of 0.0352174646049103
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of -0.46004575230292477
# PREM_TYP_DESC_GAS STATION has weight of -0.07063368691677616
# PREM_TYP_DESC_GROCERY/BODEGA has weight of 0.17893885725566258
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of -0.2771951358052007
# PREM_TYP_DESC_HIGHWAY/PARKWAY has weight of -0.006393205040485854
# PREM_TYP_DESC_HOSPITAL has weight of 0.43990758165534977
# PREM_TYP_DESC_HOTEL/MOTEL has weight of 0.17387543097975217
# PREM_TYP_DESC_JEWELRY has weight of -0.04930773421813511
# PREM_TYP_DESC_LIQUOR STORE has weight of -0.07578206807862709
# PREM_TYP_DESC_LOAN COMPANY has weight of -0.0032688406826320367
# PREM_TYP_DESC_MARINA/PIER has weight of -0.007234511156601324
# PREM_TYP_DESC_MOSQUE has weight of 0.0004926982330963226
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS) has weight of -0.006925357272139027
# PREM_TYP_DESC_OTHER has weight of 0.5993200036013985
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP has weight of 0.010380116041820707
# PREM_TYP_DESC_PARK/PLAYGROUND has weight of 0.08927704273716482
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of -0.14513849033390552
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of -0.13314731225621787
# PREM_TYP_DESC_PHOTO/COPY has weight of -0.01087358339346635
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL has weight of 0.05408561386923129
# PREM_TYP_DESC_PUBLIC BUILDING has weight of 0.1781573327884257
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of 1.1478717329418084
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of 1.287158571398232
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of 0.41733052021888006
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of 0.9462015393190436
# PREM_TYP_DESC_RESTAURANT/DINER has weight of 0.05219253607276908
# PREM_TYP_DESC_SHOE has weight of -0.06183056858959402
# PREM_TYP_DESC_SMALL MERCHANT has weight of -0.11340318540744417
# PREM_TYP_DESC_SOCIAL CLUB/POLICY has weight of 0.04880597210346829
# PREM_TYP_DESC_STORAGE FACILITY has weight of -0.019730284123188828
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of -0.14245311705620523
# PREM_TYP_DESC_STREET has weight of 0.3336482799893055
# PREM_TYP_DESC_SYNAGOGUE has weight of 0.005786332595243426
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of -0.03162034581263798
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of -0.04294708380914284
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED) has weight of -0.004757475314213957
# PREM_TYP_DESC_TELECOMM. STORE has weight of -0.13258647525694728
# PREM_TYP_DESC_TRAMWAY has weight of -0.0003425425122333366
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY has weight of -0.0007481273129560799
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER) has weight of -0.01960653270396733
# PREM_TYP_DESC_TUNNEL has weight of -0.010002437579118213
# PREM_TYP_DESC_VARIETY STORE has weight of -0.08696082525391513
# PREM_TYP_DESC_VIDEO STORE has weight of -0.011038765398695834
# Day_Name_Friday has weight of -0.0603135413630261
# Day_Name_Monday has weight of -0.007505019741971159
# Day_Name_Saturday has weight of 0.05852516819276211
# Day_Name_Sunday has weight of 0.2222467754381266
# Day_Name_Thursday has weight of -0.05115428826190699
# Day_Name_Tuesday has weight of -0.08817896860253135
# Day_Name_Wednesday has weight of -0.07435204259885189
# Month_April has weight of -0.03666986164481629
# Month_August has weight of -0.00018464206639271224
# Month_December has weight of -0.026873775225920427
# Month_February has weight of -0.024862857756738552
# Month_January has weight of -0.02343476989984121
# Month_July has weight of 0.06040135447285607
# Month_June has weight of 0.030708423627684084
# Month_March has weight of -0.035152243631506944
# Month_May has weight of 0.07841203224939712
# Month_November has weight of -0.04030539355425861
# Month_October has weight of -0.01183691941789918
# Month_September has weight of 0.029066735910230262
# Duration_lbl_Long has weight of 1.2359588294823352
# Duration_lbl_Medium has weight of -0.6828972763199554
# Duration_lbl_Short has weight of -0.5537934701004285
# Season_Fall has weight of -0.023075577061842125
# Season_Spring has weight of 0.006589926973191558
# Season_Summer has weight of 0.09092513603424845
# Season_Winter has weight of -0.07517140288236675
# Daytime_Day has weight of -0.16256932795641954
# Daytime_Early Morning has weight of 0.11063911684793838
# Daytime_Evening has weight of -0.05993637833553522
# Daytime_Late Night has weight of 0.13342252762868498
# Daytime_Morning has weight of -0.027823616810873444
# Daytime_Night has weight of 0.005535761689078587

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,crime.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.7320538879697471
# [[62094 10822]
#  [17520 15339]]
# Duration has weight of -1.8919403919594386
# PREM_TYP_DESC_DEPARTMENT STORE has weight of -0.4324150461625149
# Duration_lbl_Short has weight of -0.42335819484285125
# PREM_TYP_DESC_CHAIN STORE has weight of -0.33046252003195387
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of -0.2470997684854501
# PREM_TYP_DESC_DRUG STORE has weight of -0.2459271667545502
# LOC_OF_OCCUR_DESC_REAR OF has weight of -0.14330828899904563
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of -0.13922578074765155
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of -0.13340729553391764
# PREM_TYP_DESC_ATM has weight of -0.10330223636619212
# PREM_TYP_DESC_BANK has weight of -0.09795373947418072
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of -0.09472270000159086
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of -0.07714054903586152
# PREM_TYP_DESC_TELECOMM. STORE has weight of -0.06866320308454758
# ADDR_PCT_CD_19.0 has weight of -0.06379292821191997
# Duration_lbl_Medium has weight of -0.06351501569775936
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of -0.05760187877054101
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of -0.056092242686457336
# BORO_NM_MANHATTAN has weight of -0.055643981356895494
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of -0.055606355910101574
# PREM_TYP_DESC_SMALL MERCHANT has weight of -0.05390458627484105
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of -0.05090591930088523
# PREM_TYP_DESC_VARIETY STORE has weight of -0.04985361829410449
# PREM_TYP_DESC_SHOE has weight of -0.048163874940631936
# ADDR_PCT_CD_90.0 has weight of -0.04499633136740855
# PREM_TYP_DESC_LIQUOR STORE has weight of -0.04090219190318534
# PREM_TYP_DESC_JEWELRY has weight of -0.04011593296336141
# Daytime_Day has weight of -0.04010586943292369
# ADDR_PCT_CD_14.0 has weight of -0.039494989469745716
# ADDR_PCT_CD_6.0 has weight of -0.03890837479877901
# PREM_TYP_DESC_RESTAURANT/DINER has weight of -0.03683116914979603
# ADDR_PCT_CD_9.0 has weight of -0.0341030789644022
# PREM_TYP_DESC_GAS STATION has weight of -0.03326794700263325
# PREM_TYP_DESC_GROCERY/BODEGA has weight of -0.032532846475799335
# PREM_TYP_DESC_BRIDGE has weight of -0.03223141234426366
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of -0.0316823888446532
# PREM_TYP_DESC_ABANDONED BUILDING has weight of -0.03131386764310894
# JURIS_DESC_NYS DEPT TAX AND FINANCE has weight of -0.02911728159286892
# ADDR_PCT_CD_94.0 has weight of -0.02853496424632824
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of -0.02785770333613788
# PREM_TYP_DESC_BOOK/CARD has weight of -0.02749990714845612
# ADDR_PCT_CD_10.0 has weight of -0.02747799367132986
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY has weight of -0.027261520852019973
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of -0.025696807700807983
# ADDR_PCT_CD_112.0 has weight of -0.025430317226675672
# ADDR_PCT_CD_13.0 has weight of -0.02498265424560506
# Day_Name_Tuesday has weight of -0.02470602583903173
# ADDR_PCT_CD_78.0 has weight of -0.024402591405293772
# JURIS_DESC_OTHER has weight of -0.02368142610120241
# Day_Name_Wednesday has weight of -0.022778782758006568
# PREM_TYP_DESC_FAST FOOD has weight of -0.02208904951602211
# ADDR_PCT_CD_111.0 has weight of -0.021549983537664567
# PREM_TYP_DESC_STORAGE FACILITY has weight of -0.020353442065980772
# ADDR_PCT_CD_17.0 has weight of -0.019568554955154378
# JURIS_DESC_TRI-BORO BRDG TUNNL has weight of -0.018744982848807254
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY has weight of -0.01828206380724459
# PREM_TYP_DESC_CHURCH has weight of -0.01777509724774738
# JURIS_DESC_DEPT OF CORRECTIONS has weight of -0.01701829167405609
# ADDR_PCT_CD_61.0 has weight of -0.016978754363835218
# ADDR_PCT_CD_1.0 has weight of -0.01690537135470414
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER) has weight of -0.016634423133834595
# ADDR_PCT_CD_52.0 has weight of -0.016012539563119838
# ADDR_PCT_CD_107.0 has weight of -0.015858312666966346
# Day_Name_Friday has weight of -0.015375766257474725
# JURIS_DESC_STATN IS RAPID TRANS has weight of -0.014933066460216544
# Day_Name_Thursday has weight of -0.014927807784421971
# JURIS_DESC_N.Y. STATE POLICE has weight of -0.014621946821058687
# Season_Winter has weight of -0.014364655084024897
# Month_March has weight of -0.014203362855660937
# PREM_TYP_DESC_PHOTO/COPY has weight of -0.013544053517970325
# Daytime_Evening has weight of -0.013473351781084376
# ADDR_PCT_CD_83.0 has weight of -0.012425802100953882
# ADDR_PCT_CD_40.0 has weight of -0.012350191159576255
# Month_January has weight of -0.011797649825415198
# PREM_TYP_DESC_VIDEO STORE has weight of -0.011367021416701015
# PREM_TYP_DESC_TRAMWAY has weight of -0.01100275153536204
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS) has weight of -0.010586190777183925
# Month_April has weight of -0.010429572364499385
# ADDR_PCT_CD_76.0 has weight of -0.010152148070499216
# ADDR_PCT_CD_50.0 has weight of -0.009947776198957044
# ADDR_PCT_CD_106.0 has weight of -0.009906096002384878
# Month_February has weight of -0.009278023062146869
# PREM_TYP_DESC_LOAN COMPANY has weight of -0.009056592140060504
# ADDR_PCT_CD_66.0 has weight of -0.008961508929833264
# ADDR_PCT_CD_88.0 has weight of -0.008809832246192783
# PREM_TYP_DESC_HIGHWAY/PARKWAY has weight of -0.008684173509596667
# PREM_TYP_DESC_MARINA/PIER has weight of -0.007563634210419596
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED) has weight of -0.007359363969539846
# PREM_TYP_DESC_FACTORY/WAREHOUSE has weight of -0.0067535567768537644
# JURIS_DESC_N.Y. STATE PARKS has weight of -0.0066083519245098265
# PREM_TYP_DESC_TUNNEL has weight of -0.005832896668679753
# ADDR_PCT_CD_49.0 has weight of -0.005402598289979997
# ADDR_PCT_CD_84.0 has weight of -0.005097397132212146
# ADDR_PCT_CD_5.0 has weight of -0.004994051888573324
# PREM_TYP_DESC_CANDY STORE has weight of -0.004959259641544421
# Month_October has weight of -0.004591641658416016
# ADDR_PCT_CD_25.0 has weight of -0.0044838167755855435
# PREM_TYP_DESC_STREET has weight of -0.004400743432144997
# Season_Fall has weight of -0.004285352743484914
# ADDR_PCT_CD_22.0 has weight of -0.004061934960184929
# PREM_TYP_DESC_SYNAGOGUE has weight of -0.004043141584257076
# ADDR_PCT_CD_26.0 has weight of -0.003888524121174325
# ADDR_PCT_CD_110.0 has weight of -0.003800053272314775
# ADDR_PCT_CD_109.0 has weight of -0.0037634691551345846
# PREM_TYP_DESC_BUS TERMINAL has weight of -0.0037575410501072644
# JURIS_DESC_N.Y. TRANSIT POLICE has weight of -0.0037567399886826755
# PREM_TYP_DESC_BEAUTY & NAIL SALON has weight of -0.0035284451639620174
# JURIS_DESC_NYC PARKS has weight of -0.003216410874300549
# ADDR_PCT_CD_20.0 has weight of -0.0032135603400768368
# Month_November has weight of -0.003110248418908106
# Month_December has weight of -0.002818180477670994
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE has weight of -0.0024548982706527915
# ADDR_PCT_CD_71.0 has weight of -0.002413483785361344
# Daytime_Morning has weight of -0.002280246445438717
# ADDR_PCT_CD_23.0 has weight of -0.00220940257565404
# PREM_TYP_DESC_MOSQUE has weight of -0.0020421923690445687
# PREM_TYP_DESC_BUS STOP has weight of -0.0015409060411454075
# ADDR_PCT_CD_113.0 has weight of -0.0012276136410924652
# ADDR_PCT_CD_24.0 has weight of -0.0010872349997543397
# Season_Spring has weight of -0.00016971302002240064
# ADDR_PCT_CD_48.0 has weight of -6.664820232147971e-05
# JURIS_DESC_POLICE DEPT NYC has weight of 0.00039881262105519156
# ADDR_PCT_CD_70.0 has weight of 0.0005725702574073419
# Day_Name_Monday has weight of 0.0007015350458463287
# ADDR_PCT_CD_7.0 has weight of 0.001010820697121356
# Month_August has weight of 0.0010666615461737312
# Month_September has weight of 0.0012305912539409423
# PREM_TYP_DESC_CEMETERY has weight of 0.0013019344888305872
# JURIS_DESC_N.Y. POLICE DEPT has weight of 0.001407765004797786
# PREM_TYP_DESC_AIRPORT TERMINAL has weight of 0.0015604401081526756
# JURIS_DESC_LONG ISLAND RAILRD has weight of 0.0017659261863776957
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE has weight of 0.002152177991005122
# ADDR_PCT_CD_68.0 has weight of 0.0023542542040403077
# JURIS_DESC_U.S. PARK POLICE has weight of 0.0026330271126132456
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP has weight of 0.0027878584968187986
# JURIS_DESC_METRO NORTH has weight of 0.0032866919333884325
# ADDR_PCT_CD_43.0 has weight of 0.0033750346951440676
# Duration_to_PD has weight of 0.003901976144727288
# ADDR_PCT_CD_100.0 has weight of 0.004104203026097149
# ADDR_PCT_CD_81.0 has weight of 0.004199845665626805
# Day has weight of 0.004253487812315835
# ADDR_PCT_CD_18.0 has weight of 0.004454241671223224
# ADDR_PCT_CD_28.0 has weight of 0.004914213712740362
# ADDR_PCT_CD_77.0 has weight of 0.004950130974288886
# JURIS_DESC_AMTRACK has weight of 0.005011602216860419
# ADDR_PCT_CD_115.0 has weight of 0.005211313596024779
# PREM_TYP_DESC_PUBLIC BUILDING has weight of 0.005564861884414581
# PREM_TYP_DESC_FERRY/FERRY TERMINAL has weight of 0.005829064607339127
# GeoCell_Y has weight of 0.00615503658820449
# JURIS_DESC_N.Y. HOUSING POLICE has weight of 0.006729035651696229
# JURIS_DESC_PORT AUTHORITY has weight of 0.007428871297899665
# ADDR_PCT_CD_79.0 has weight of 0.007446239459288211
# ADDR_PCT_CD_122.0 has weight of 0.008300743674863354
# ADDR_PCT_CD_105.0 has weight of 0.008665365951127347
# ADDR_PCT_CD_63.0 has weight of 0.009257044544508111
# GeoCell has weight of 0.00928578677713737
# ADDR_PCT_CD_104.0 has weight of 0.009370072208502715
# PREM_TYP_DESC_HOTEL/MOTEL has weight of 0.009454557090860523
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL has weight of 0.009482935532502684
# PREM_TYP_DESC_SOCIAL CLUB/POLICY has weight of 0.00980644601929889
# ADDR_PCT_CD_60.0 has weight of 0.009833646733120455
# ADDR_PCT_CD_114.0 has weight of 0.009896676342492302
# ADDR_PCT_CD_62.0 has weight of 0.009990591079008593
# ADDR_PCT_CD_33.0 has weight of 0.010051612973464382
# ADDR_PCT_CD_42.0 has weight of 0.010067756127699317
# PREM_TYP_DESC_PARK/PLAYGROUND has weight of 0.010290389995567431
# Month_June has weight of 0.010578436638191462
# ADDR_PCT_CD_32.0 has weight of 0.010733705397856117
# BORO_NM_QUEENS has weight of 0.01091837663423154
# BORO_NM_BROOKLYN has weight of 0.011898167837582536
# ADDR_PCT_CD_101.0 has weight of 0.012488093266918281
# ADDR_PCT_CD_72.0 has weight of 0.012665224532874756
# ADDR_PCT_CD_47.0 has weight of 0.012694007987945535
# PREM_TYP_DESC_BUS (OTHER) has weight of 0.012853986443094816
# ADDR_PCT_CD_123.0 has weight of 0.013778635786399169
# ADDR_PCT_CD_41.0 has weight of 0.013837897731940193
# ADDR_PCT_CD_108.0 has weight of 0.014019375985940356
# BORO_NM_BRONX has weight of 0.014042296851535642
# ADDR_PCT_CD_46.0 has weight of 0.014342185294669688
# JURIS_DESC_HEALTH & HOSP CORP has weight of 0.014692983437283442
# LOC_OF_OCCUR_DESC_FRONT OF has weight of 0.015508670260961172
# ADDR_PCT_CD_45.0 has weight of 0.015736259308526953
# ADDR_PCT_CD_121.0 has weight of 0.01579026345866084
# ADDR_PCT_CD_102.0 has weight of 0.016425372933243396
# PREM_TYP_DESC_BUS (NYC TRANSIT) has weight of 0.017075053895534188
# ADDR_PCT_CD_44.0 has weight of 0.01769809395587039
# Month_July has weight of 0.01806276707851659
# Season_Summer has weight of 0.018885185585565113
# ADDR_PCT_CD_103.0 has weight of 0.019552745724982824
# ADDR_PCT_CD_75.0 has weight of 0.020176887404719682
# Day_Name_Saturday has weight of 0.020291507059040412
# Daytime_Night has weight of 0.02119965631581543
# Daytime_Early Morning has weight of 0.02241361836451122
# Daytime_Late Night has weight of 0.02253463070919761
# PREM_TYP_DESC_BAR/NIGHT CLUB has weight of 0.02310877071036526
# ADDR_PCT_CD_34.0 has weight of 0.023110657931576472
# ADDR_PCT_CD_73.0 has weight of 0.023155962767239895
# Month_May has weight of 0.02338061459919869
# ADDR_PCT_CD_30.0 has weight of 0.024954315538808333
# ADDR_PCT_CD_69.0 has weight of 0.027077667811699388
# ADDR_PCT_CD_120.0 has weight of 0.03245504244673824
# BORO_NM_STATEN ISLAND has weight of 0.03770246777510571
# Year has weight of 0.04605798653434635
# GeoCell_X has weight of 0.046273497822057544
# ADDR_PCT_CD_67.0 has weight of 0.04634270628922032
# PREM_TYP_DESC_OTHER has weight of 0.04718807212681415
# PREM_TYP_DESC_HOSPITAL has weight of 0.04772643521721222
# Day_Name_Sunday has weight of 0.05840542115497149
# LOC_OF_OCCUR_DESC_INSIDE has weight of 0.09003407930526908
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of 0.12036482113085185
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of 0.1445853027253882
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of 0.18090014633570733
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of 0.33800025886142016
# Duration_lbl_Long has weight of 0.736352456043345

# %%
# now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=crime.columns)
weights.plot(kind='bar', figsize = (16,8))
plt.show()

# %%
zip_vars
# Out:
# [(array([-1.89194039]), 'Duration'),
#  (array([-0.43241505]), 'PREM_TYP_DESC_DEPARTMENT STORE'),
#  (array([-0.42335819]), 'Duration_lbl_Short'),
#  (array([-0.33046252]), 'PREM_TYP_DESC_CHAIN STORE'),
#  (array([-0.24709977]), 'PREM_TYP_DESC_CLOTHING/BOUTIQUE'),
#  (array([-0.24592717]), 'PREM_TYP_DESC_DRUG STORE'),
#  (array([-0.14330829]), 'LOC_OF_OCCUR_DESC_REAR OF'),
#  (array([-0.13922578]), 'LOC_OF_OCCUR_DESC_OPPOSITE OF'),
#  (array([-0.1334073]), 'PREM_TYP_DESC_FOOD SUPERMARKET'),
#  (array([-0.10330224]), 'PREM_TYP_DESC_ATM'),
#  (array([-0.09795374]), 'PREM_TYP_DESC_BANK'),
#  (array([-0.0947227]), 'PREM_TYP_DESC_GYM/FITNESS FACILITY'),
#  (array([-0.07714055]), 'PREM_TYP_DESC_COMMERCIAL BUILDING'),
#  (array([-0.0686632]), 'PREM_TYP_DESC_TELECOMM. STORE'),
#  (array([-0.06379293]), 'ADDR_PCT_CD_19.0'),
#  (array([-0.06351502]), 'Duration_lbl_Medium'),
#  (array([-0.05760188]), 'PREM_TYP_DESC_CHECK CASHING BUSINESS'),
#  (array([-0.05609224]), 'PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)'),
#  (array([-0.05564398]), 'BORO_NM_MANHATTAN'),
#  (array([-0.05560636]), 'PREM_TYP_DESC_STORE UNCLASSIFIED'),
#  (array([-0.05390459]), 'PREM_TYP_DESC_SMALL MERCHANT'),
#  (array([-0.05090592]), 'PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)'),
#  (array([-0.04985362]), 'PREM_TYP_DESC_VARIETY STORE'),
#  (array([-0.04816387]), 'PREM_TYP_DESC_SHOE'),
#  (array([-0.04499633]), 'ADDR_PCT_CD_90.0'),
#  (array([-0.04090219]), 'PREM_TYP_DESC_LIQUOR STORE'),
#  (array([-0.04011593]), 'PREM_TYP_DESC_JEWELRY'),
#  (array([-0.04010587]), 'Daytime_Day'),
#  (array([-0.03949499]), 'ADDR_PCT_CD_14.0'),
#  (array([-0.03890837]), 'ADDR_PCT_CD_6.0'),
#  (array([-0.03683117]), 'PREM_TYP_DESC_RESTAURANT/DINER'),
#  (array([-0.03410308]), 'ADDR_PCT_CD_9.0'),
#  (array([-0.03326795]), 'PREM_TYP_DESC_GAS STATION'),
#  (array([-0.03253285]), 'PREM_TYP_DESC_GROCERY/BODEGA'),
#  (array([-0.03223141]), 'PREM_TYP_DESC_BRIDGE'),
#  (array([-0.03168239]), 'PREM_TYP_DESC_TAXI (YELLOW LICENSED)'),
#  (array([-0.03131387]), 'PREM_TYP_DESC_ABANDONED BUILDING'),
#  (array([-0.02911728]), 'JURIS_DESC_NYS DEPT TAX AND FINANCE'),
#  (array([-0.02853496]), 'ADDR_PCT_CD_94.0'),
#  (array([-0.0278577]), 'PREM_TYP_DESC_CONSTRUCTION SITE'),
#  (array([-0.02749991]), 'PREM_TYP_DESC_BOOK/CARD'),
#  (array([-0.02747799]), 'ADDR_PCT_CD_10.0'),
#  (array([-0.02726152]), 'PREM_TYP_DESC_DRY CLEANER/LAUNDRY'),
#  (array([-0.02569681]), 'PREM_TYP_DESC_TAXI (LIVERY LICENSED)'),
#  (array([-0.02543032]), 'ADDR_PCT_CD_112.0'),
#  (array([-0.02498265]), 'ADDR_PCT_CD_13.0'),
#  (array([-0.02470603]), 'Day_Name_Tuesday'),
#  (array([-0.02440259]), 'ADDR_PCT_CD_78.0'),
#  (array([-0.02368143]), 'JURIS_DESC_OTHER'),
#  (array([-0.02277878]), 'Day_Name_Wednesday'),
#  (array([-0.02208905]), 'PREM_TYP_DESC_FAST FOOD'),
#  (array([-0.02154998]), 'ADDR_PCT_CD_111.0'),
#  (array([-0.02035344]), 'PREM_TYP_DESC_STORAGE FACILITY'),
#  (array([-0.01956855]), 'ADDR_PCT_CD_17.0'),
#  (array([-0.01874498]), 'JURIS_DESC_TRI-BORO BRDG TUNNL'),
#  (array([-0.01828206]), 'PREM_TYP_DESC_TRANSIT - NYC SUBWAY'),
#  (array([-0.0177751]), 'PREM_TYP_DESC_CHURCH'),
#  (array([-0.01701829]), 'JURIS_DESC_DEPT OF CORRECTIONS'),
#  (array([-0.01697875]), 'ADDR_PCT_CD_61.0'),
#  (array([-0.01690537]), 'ADDR_PCT_CD_1.0'),
#  (array([-0.01663442]), 'PREM_TYP_DESC_TRANSIT FACILITY (OTHER)'),
#  (array([-0.01601254]), 'ADDR_PCT_CD_52.0'),
#  (array([-0.01585831]), 'ADDR_PCT_CD_107.0'),
#  (array([-0.01537577]), 'Day_Name_Friday'),
#  (array([-0.01493307]), 'JURIS_DESC_STATN IS RAPID TRANS'),
#  (array([-0.01492781]), 'Day_Name_Thursday'),
#  (array([-0.01462195]), 'JURIS_DESC_N.Y. STATE POLICE'),
#  (array([-0.01436466]), 'Season_Winter'),
#  (array([-0.01420336]), 'Month_March'),
#  (array([-0.01354405]), 'PREM_TYP_DESC_PHOTO/COPY'),
#  (array([-0.01347335]), 'Daytime_Evening'),
#  (array([-0.0124258]), 'ADDR_PCT_CD_83.0'),
#  (array([-0.01235019]), 'ADDR_PCT_CD_40.0'),
#  (array([-0.01179765]), 'Month_January'),
#  (array([-0.01136702]), 'PREM_TYP_DESC_VIDEO STORE'),
#  (array([-0.01100275]), 'PREM_TYP_DESC_TRAMWAY'),
#  (array([-0.01058619]), 'PREM_TYP_DESC_OPEN AREAS (OPEN LOTS)'),
#  (array([-0.01042957]), 'Month_April'),
#  (array([-0.01015215]), 'ADDR_PCT_CD_76.0'),
#  (array([-0.00994778]), 'ADDR_PCT_CD_50.0'),
#  (array([-0.0099061]), 'ADDR_PCT_CD_106.0'),
#  (array([-0.00927802]), 'Month_February'),
#  (array([-0.00905659]), 'PREM_TYP_DESC_LOAN COMPANY'),
#  (array([-0.00896151]), 'ADDR_PCT_CD_66.0'),
#  (array([-0.00880983]), 'ADDR_PCT_CD_88.0'),
#  (array([-0.00868417]), 'PREM_TYP_DESC_HIGHWAY/PARKWAY'),
#  (array([-0.00756363]), 'PREM_TYP_DESC_MARINA/PIER'),
#  (array([-0.00735936]), 'PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED)'),
#  (array([-0.00675356]), 'PREM_TYP_DESC_FACTORY/WAREHOUSE'),
#  (array([-0.00660835]), 'JURIS_DESC_N.Y. STATE PARKS'),
#  (array([-0.0058329]), 'PREM_TYP_DESC_TUNNEL'),
#  (array([-0.0054026]), 'ADDR_PCT_CD_49.0'),
#  (array([-0.0050974]), 'ADDR_PCT_CD_84.0'),
#  (array([-0.00499405]), 'ADDR_PCT_CD_5.0'),
#  (array([-0.00495926]), 'PREM_TYP_DESC_CANDY STORE'),
#  (array([-0.00459164]), 'Month_October'),
#  (array([-0.00448382]), 'ADDR_PCT_CD_25.0'),
#  (array([-0.00440074]), 'PREM_TYP_DESC_STREET'),
#  (array([-0.00428535]), 'Season_Fall'),
#  (array([-0.00406193]), 'ADDR_PCT_CD_22.0'),
#  (array([-0.00404314]), 'PREM_TYP_DESC_SYNAGOGUE'),
#  (array([-0.00388852]), 'ADDR_PCT_CD_26.0'),
#  (array([-0.00380005]), 'ADDR_PCT_CD_110.0'),
#  (array([-0.00376347]), 'ADDR_PCT_CD_109.0'),
#  (array([-0.00375754]), 'PREM_TYP_DESC_BUS TERMINAL'),
#  (array([-0.00375674]), 'JURIS_DESC_N.Y. TRANSIT POLICE'),
#  (array([-0.00352845]), 'PREM_TYP_DESC_BEAUTY & NAIL SALON'),
#  (array([-0.00321641]), 'JURIS_DESC_NYC PARKS'),
#  (array([-0.00321356]), 'ADDR_PCT_CD_20.0'),
#  (array([-0.00311025]), 'Month_November'),
#  (array([-0.00281818]), 'Month_December'),
#  (array([-0.0024549]), 'JURIS_DESC_NEW YORK CITY SHERIFF OFFICE'),
#  (array([-0.00241348]), 'ADDR_PCT_CD_71.0'),
#  (array([-0.00228025]), 'Daytime_Morning'),
#  (array([-0.0022094]), 'ADDR_PCT_CD_23.0'),
#  (array([-0.00204219]), 'PREM_TYP_DESC_MOSQUE'),
#  (array([-0.00154091]), 'PREM_TYP_DESC_BUS STOP'),
#  (array([-0.00122761]), 'ADDR_PCT_CD_113.0'),
#  (array([-0.00108723]), 'ADDR_PCT_CD_24.0'),
#  (array([-0.00016971]), 'Season_Spring'),
#  (array([-6.66482023e-05]), 'ADDR_PCT_CD_48.0'),
#  (array([0.00039881]), 'JURIS_DESC_POLICE DEPT NYC'),
#  (array([0.00057257]), 'ADDR_PCT_CD_70.0'),
#  (array([0.00070154]), 'Day_Name_Monday'),
#  (array([0.00101082]), 'ADDR_PCT_CD_7.0'),
#  (array([0.00106666]), 'Month_August'),
#  (array([0.00123059]), 'Month_September'),
#  (array([0.00130193]), 'PREM_TYP_DESC_CEMETERY'),
#  (array([0.00140777]), 'JURIS_DESC_N.Y. POLICE DEPT'),
#  (array([0.00156044]), 'PREM_TYP_DESC_AIRPORT TERMINAL'),
#  (array([0.00176593]), 'JURIS_DESC_LONG ISLAND RAILRD'),
#  (array([0.00215218]), 'PREM_TYP_DESC_DOCTOR/DENTIST OFFICE'),
#  (array([0.00235425]), 'ADDR_PCT_CD_68.0'),
#  (array([0.00263303]), 'JURIS_DESC_U.S. PARK POLICE'),
#  (array([0.00278786]), 'PREM_TYP_DESC_OTHER HOUSE OF WORSHIP'),
#  (array([0.00328669]), 'JURIS_DESC_METRO NORTH'),
#  (array([0.00337503]), 'ADDR_PCT_CD_43.0'),
#  (array([0.00390198]), 'Duration_to_PD'),
#  (array([0.0041042]), 'ADDR_PCT_CD_100.0'),
#  (array([0.00419985]), 'ADDR_PCT_CD_81.0'),
#  (array([0.00425349]), 'Day'),
#  (array([0.00445424]), 'ADDR_PCT_CD_18.0'),
#  (array([0.00491421]), 'ADDR_PCT_CD_28.0'),
#  (array([0.00495013]), 'ADDR_PCT_CD_77.0'),
#  (array([0.0050116]), 'JURIS_DESC_AMTRACK'),
#  (array([0.00521131]), 'ADDR_PCT_CD_115.0'),
#  (array([0.00556486]), 'PREM_TYP_DESC_PUBLIC BUILDING'),
#  (array([0.00582906]), 'PREM_TYP_DESC_FERRY/FERRY TERMINAL'),
#  (array([0.00615504]), 'GeoCell_Y'),
#  (array([0.00672904]), 'JURIS_DESC_N.Y. HOUSING POLICE'),
#  (array([0.00742887]), 'JURIS_DESC_PORT AUTHORITY'),
#  (array([0.00744624]), 'ADDR_PCT_CD_79.0'),
#  (array([0.00830074]), 'ADDR_PCT_CD_122.0'),
#  (array([0.00866537]), 'ADDR_PCT_CD_105.0'),
#  (array([0.00925704]), 'ADDR_PCT_CD_63.0'),
#  (array([0.00928579]), 'GeoCell'),
#  (array([0.00937007]), 'ADDR_PCT_CD_104.0'),
#  (array([0.00945456]), 'PREM_TYP_DESC_HOTEL/MOTEL'),
#  (array([0.00948294]), 'PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL'),
#  (array([0.00980645]), 'PREM_TYP_DESC_SOCIAL CLUB/POLICY'),
#  (array([0.00983365]), 'ADDR_PCT_CD_60.0'),
#  (array([0.00989668]), 'ADDR_PCT_CD_114.0'),
#  (array([0.00999059]), 'ADDR_PCT_CD_62.0'),
#  (array([0.01005161]), 'ADDR_PCT_CD_33.0'),
#  (array([0.01006776]), 'ADDR_PCT_CD_42.0'),
#  (array([0.01029039]), 'PREM_TYP_DESC_PARK/PLAYGROUND'),
#  (array([0.01057844]), 'Month_June'),
#  (array([0.01073371]), 'ADDR_PCT_CD_32.0'),
#  (array([0.01091838]), 'BORO_NM_QUEENS'),
#  (array([0.01189817]), 'BORO_NM_BROOKLYN'),
#  (array([0.01248809]), 'ADDR_PCT_CD_101.0'),
#  (array([0.01266522]), 'ADDR_PCT_CD_72.0'),
#  (array([0.01269401]), 'ADDR_PCT_CD_47.0'),
#  (array([0.01285399]), 'PREM_TYP_DESC_BUS (OTHER)'),
#  (array([0.01377864]), 'ADDR_PCT_CD_123.0'),
#  (array([0.0138379]), 'ADDR_PCT_CD_41.0'),
#  (array([0.01401938]), 'ADDR_PCT_CD_108.0'),
#  (array([0.0140423]), 'BORO_NM_BRONX'),
#  (array([0.01434219]), 'ADDR_PCT_CD_46.0'),
#  (array([0.01469298]), 'JURIS_DESC_HEALTH & HOSP CORP'),
#  (array([0.01550867]), 'LOC_OF_OCCUR_DESC_FRONT OF'),
#  (array([0.01573626]), 'ADDR_PCT_CD_45.0'),
#  (array([0.01579026]), 'ADDR_PCT_CD_121.0'),
#  (array([0.01642537]), 'ADDR_PCT_CD_102.0'),
#  (array([0.01707505]), 'PREM_TYP_DESC_BUS (NYC TRANSIT)'),
#  (array([0.01769809]), 'ADDR_PCT_CD_44.0'),
#  (array([0.01806277]), 'Month_July'),
#  (array([0.01888519]), 'Season_Summer'),
#  (array([0.01955275]), 'ADDR_PCT_CD_103.0'),
#  (array([0.02017689]), 'ADDR_PCT_CD_75.0'),
#  (array([0.02029151]), 'Day_Name_Saturday'),
#  (array([0.02119966]), 'Daytime_Night'),
#  (array([0.02241362]), 'Daytime_Early Morning'),
#  (array([0.02253463]), 'Daytime_Late Night'),
#  (array([0.02310877]), 'PREM_TYP_DESC_BAR/NIGHT CLUB'),
#  (array([0.02311066]), 'ADDR_PCT_CD_34.0'),
#  (array([0.02315596]), 'ADDR_PCT_CD_73.0'),
#  (array([0.02338061]), 'Month_May'),
#  (array([0.02495432]), 'ADDR_PCT_CD_30.0'),
#  (array([0.02707767]), 'ADDR_PCT_CD_69.0'),
#  (array([0.03245504]), 'ADDR_PCT_CD_120.0'),
#  (array([0.03770247]), 'BORO_NM_STATEN ISLAND'),
#  (array([0.04605799]), 'Year'),
#  (array([0.0462735]), 'GeoCell_X'),
#  (array([0.04634271]), 'ADDR_PCT_CD_67.0'),
#  (array([0.04718807]), 'PREM_TYP_DESC_OTHER'),
#  (array([0.04772644]), 'PREM_TYP_DESC_HOSPITAL'),
#  (array([0.05840542]), 'Day_Name_Sunday'),
#  (array([0.09003408]), 'LOC_OF_OCCUR_DESC_INSIDE'),
#  (array([0.12036482]), 'PREM_TYP_DESC_PUBLIC SCHOOL'),
#  (array([0.1445853]), 'PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING'),
#  (array([0.18090015]), 'PREM_TYP_DESC_RESIDENCE-HOUSE'),
#  (array([0.33800026]), 'PREM_TYP_DESC_RESIDENCE - APT. HOUSE'),
#  (array([0.73635246]), 'Duration_lbl_Long')]

# %% [markdown]
# ## Logistic Regression Model - Iteration 2
#
# Using a subset of variables based on an importance threshold

# %%
import pandas as pd
import numpy as np

# %%
crime = pd.read_csv('Training_and_Test_Set.csv') # read in the csv %%file

# %%
crime.dtypes
# Out:
# JURIS_DESC            object
# BORO_NM               object
# ADDR_PCT_CD          float64
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# Day_Name              object
# Duration             float64
# Duration_to_PD       float64
# Month                 object
# Day                  float64
# Year                 float64
# Duration_lbl          object
# Season                object
# Daytime               object
# GeoCell              float64
# GeoCell_X            float64
# GeoCell_Y            float64
# y                      int64
# dtype: object

# %%
#Value Counts by Crime Type
crime['y'].value_counts()
# Out:
# 0    365333
# 1    163540
# Name: y, dtype: int64

# %%
#dropping any remaining NANs
crime = crime.dropna()

# %%
crime.isnull().values.any()
# Out:
# False

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 528873 entries, 0 to 528872
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   JURIS_DESC         528873 non-null  object
#  1   BORO_NM            528873 non-null  object
#  2   ADDR_PCT_CD        528873 non-null  float64
#  3   LOC_OF_OCCUR_DESC  528873 non-null  object
#  4   PREM_TYP_DESC      528873 non-null  object
#  5   Day_Name           528873 non-null  object
#  6   Duration           528873 non-null  float64
#  7   Duration_to_PD     528873 non-null  float64
#  8   Month              528873 non-null  object
#  9   Day                528873 non-null  float64
#  10  Year               528873 non-null  float64
#  11  Duration_lbl       528873 non-null  object
#  12  Season             528873 non-null  object
#  13  Daytime            528873 non-null  object
#  14  GeoCell            528873 non-null  float64
#  15  GeoCell_X          528873 non-null  float64
#  16  GeoCell_Y          528873 non-null  float64
#  17  y                  528873 non-null  int64
# dtypes: float64(8), int64(1), object(9)
# memory usage: 76.7+ MB

# %%
# perform one-hot encoding of the categorical data on 'JURIS_DESC','BORO_NM','LOC_OF_OCCUR_DESC',
#'ADDR_PCT_CD','PREM_TYP_DESC','Day_Name','Month','Duration_lbl','Season','Daytime'
tmp_df = pd.get_dummies(crime.JURIS_DESC,prefix='JURIS_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.BORO_NM,prefix='BORO_NM')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.LOC_OF_OCCUR_DESC,prefix='LOC_OF_OCCUR_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.ADDR_PCT_CD,prefix='ADDR_PCT_CD')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.PREM_TYP_DESC,prefix='PREM_TYP_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Day_Name,prefix='Day_Name')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Month,prefix='Month')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Duration_lbl,prefix='Duration_lbl')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Season,prefix='Season')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Daytime,prefix='Daytime')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

# %%
#Now we drop the original variables
if 'JURIS_DESC' in crime:    
    del crime['JURIS_DESC'] # get rid of the original category as it is now one-hot encoded
if 'BORO_NM' in crime:    
    del crime['BORO_NM'] # get rid of the original category as it is now one-hot encoded
if 'LOC_OF_OCCUR_DESC' in crime:    
    del crime['LOC_OF_OCCUR_DESC'] # get rid of the original category as it is now one-hot encoded
if 'ADDR_PCT_CD' in crime:    
    del crime['ADDR_PCT_CD'] # get rid of the original category as it is now one-hot encoded
if 'PREM_TYP_DESC' in crime:    
    del crime['PREM_TYP_DESC'] # get rid of the original category as it is now one-hot encoded
if 'Day_Name' in crime:    
    del crime['Day_Name'] # get rid of the original category as it is now one-hot encoded
if 'Month' in crime:    
    del crime['Month'] # get rid of the original category as it is now one-hot encoded
if 'Duration_lbl' in crime:    
    del crime['Duration_lbl'] # get rid of the original category as it is now one-hot encoded
if 'Season' in crime:    
    del crime['Season'] # get rid of the original category as it is now one-hot encoded
if 'Daytime' in crime:    
    del crime['Daytime'] # get rid of the original category as it is now one-hot encoded

# %%
#Now I want to pare down the variables - cutting off at  |.03|%
X_sm = crime[[ 'PREM_TYP_DESC_HIGHWAY/PARKWAY', 'BORO_NM_MANHATTAN', 'BORO_NM_QUEENS', 'GeoCell_X', 'Year',
          'ADDR_PCT_CD_66.0', 'Day_Name_Saturday', 'LOC_OF_OCCUR_DESC_FRONT OF', 'PREM_TYP_DESC_PUBLIC BUILDING', 
          'PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING', 'PREM_TYP_DESC_RESIDENCE - APT. HOUSE', 
          'PREM_TYP_DESC_PUBLIC SCHOOL', 'Month_September', 'Duration', 'PREM_TYP_DESC_CONSTRUCTION SITE',
          'Duration_lbl_Medium', 'PREM_TYP_DESC_CEMETERY', 'PREM_TYP_DESC_CHURCH', 'PREM_TYP_DESC_DOCTOR/DENTIST OFFICE',
          'LOC_OF_OCCUR_DESC_INSIDE', 'LOC_OF_OCCUR_DESC_OPPOSITE OF', 'PREM_TYP_DESC_FERRY/FERRY TERMINAL',
          'PREM_TYP_DESC_GROCERY/BODEGA', 'PREM_TYP_DESC_CLOTHING/BOUTIQUE', 'PREM_TYP_DESC_ATM', 'PREM_TYP_DESC_AIRPORT TERMINAL',  'PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED)',  'PREM_TYP_DESC_STORAGE FACILITY', 
          'PREM_TYP_DESC_PARK/PLAYGROUND', 'PREM_TYP_DESC_SHOE', 'PREM_TYP_DESC_RESIDENCE-HOUSE', 
          'PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)', 'ADDR_PCT_CD_18.0', 'PREM_TYP_DESC_GAS STATION',
          'Duration_lbl_Long', 'PREM_TYP_DESC_CHAIN STORE', 'PREM_TYP_DESC_TUNNEL', 'PREM_TYP_DESC_RESTAURANT/DINER',          'BORO_NM_BROOKLYN',  'PREM_TYP_DESC_JEWELRY',  'ADDR_PCT_CD_88.0',  'PREM_TYP_DESC_HOTEL/MOTEL', 
          'Season_Winter', 'PREM_TYP_DESC_FOOD SUPERMARKET', 'PREM_TYP_DESC_BOOK/CARD', 'PREM_TYP_DESC_FACTORY/WAREHOUSE',          'ADDR_PCT_CD_123.0',  'PREM_TYP_DESC_DRUG STORE',  'PREM_TYP_DESC_COMMERCIAL BUILDING', 
          'PREM_TYP_DESC_TAXI (LIVERY LICENSED)', 'ADDR_PCT_CD_111.0', 'ADDR_PCT_CD_5.0', 'ADDR_PCT_CD_7.0', 
          'ADDR_PCT_CD_110.0', 'ADDR_PCT_CD_9.0','y']]

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'y' in X_sm:
    y = X_sm['y'].values # get the labels we want
    del X_sm['y'] # get rid of the class label
    X = X_sm.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn

# %%
y.shape
# Out:
# (528873,)

# %%
X.shape
# Out:
# (528873, 55)

# %%
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
# run logistic regression and vary some parameters
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt

# first we create a reusable logisitic regression object
#   here we can setup the object with different learning parameters and constants
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None, solver='liblinear' ) # get object

# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("confusion matrix\n",conf)
    iter_num+=1
    
# Also note that every time you run the above code
#   it randomly creates a new training and testing set, 
#   so accuracy will be different each time
# Out:
# ====Iteration 0  ====
# accuracy 0.7186291656818719
# confusion matrix
#  [[63468  9505]
#  [20257 12545]]
# ====Iteration 1  ====
# accuracy 0.7198203734341763
# confusion matrix
#  [[63834  9364]
#  [20272 12305]]
# ====Iteration 2  ====
# accuracy 0.7187520680690144
# confusion matrix
#  [[64034  8916]
#  [20833 11992]]

# %%
# this does the exact same thing as the above block of code, but with shorter syntax

for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
    lr_clf.fit(X[train_indices],y[train_indices])  # train object
    y_hat = lr_clf.predict(X[test_indices]) # get test set precitions

    # print the accuracy and confusion matrix 
    print("====Iteration",iter_num," ====")
    print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
    print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# ====Iteration 0  ====
# accuracy 0.716880170172536
# confusion matrix
#  [[63344  9752]
#  [20195 12484]]
# ====Iteration 1  ====
# accuracy 0.7195462065705507
# confusion matrix
#  [[63525  9400]
#  [20265 12585]]
# ====Iteration 2  ====
# accuracy 0.7221838808792248
# confusion matrix
#  [[64154  9006]
#  [20380 12235]]

# %%
# and here is an even shorter way of getting the accuracies for each training and test set
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(lr_clf, X, y=y, cv=cv_object) # this also can help with parallelism
print(accuracies)
# Out:
# [0.71959348 0.71630347 0.71982037]

# %%
# interpret the weights

# iterate over the coefficients
weights = lr_clf.coef_.T # take transpose to make a column vector
variable_names = X_sm.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
    
# does this look correct?
# Out:
# PREM_TYP_DESC_HIGHWAY/PARKWAY has weight of -0.005394423487256591
# BORO_NM_MANHATTAN has weight of -0.29827726321955406
# BORO_NM_QUEENS has weight of -0.07829974146646865
# GeoCell_X has weight of 0.03752336897712395
# Year has weight of -0.0006743229146324606
# ADDR_PCT_CD_66.0 has weight of -0.0754641239096404
# Day_Name_Saturday has weight of 0.06965154911036715
# LOC_OF_OCCUR_DESC_FRONT OF has weight of 0.6262053343092435
# PREM_TYP_DESC_PUBLIC BUILDING has weight of 0.08690844663178748
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of 0.8294829552637164
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of 1.1479866792810518
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of 0.793964273862066
# Month_September has weight of -0.017975753868623278
# Duration has weight of -0.1941220187861424
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of -0.023902965334969654
# Duration_lbl_Medium has weight of -0.5230534710720529
# PREM_TYP_DESC_CEMETERY has weight of 0.0006930232815388607
# PREM_TYP_DESC_CHURCH has weight of -0.012421080856134617
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE has weight of 0.031062359671060552
# LOC_OF_OCCUR_DESC_INSIDE has weight of 0.4581597775902057
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of -0.30232514388440745
# PREM_TYP_DESC_FERRY/FERRY TERMINAL has weight of 0.028298975093704142
# PREM_TYP_DESC_GROCERY/BODEGA has weight of 0.11377195455456694
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of -0.6284740933151528
# PREM_TYP_DESC_ATM has weight of -0.06130974610274505
# PREM_TYP_DESC_AIRPORT TERMINAL has weight of 0.0004587021682000278
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED) has weight of -0.0033967771654688965
# PREM_TYP_DESC_STORAGE FACILITY has weight of -0.016765706921828834
# PREM_TYP_DESC_PARK/PLAYGROUND has weight of 0.031502502294365846
# PREM_TYP_DESC_SHOE has weight of -0.05181150141332662
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of 0.8949300501793603
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of -0.14110540736867844
# ADDR_PCT_CD_18.0 has weight of -0.0024388513677863904
# PREM_TYP_DESC_GAS STATION has weight of -0.0557175731515513
# Duration_lbl_Long has weight of 0.9312937040688719
# PREM_TYP_DESC_CHAIN STORE has weight of -1.0804036284887
# PREM_TYP_DESC_TUNNEL has weight of -0.005588163387694709
# PREM_TYP_DESC_RESTAURANT/DINER has weight of -0.004189080166194676
# BORO_NM_BROOKLYN has weight of -0.13174444817136044
# PREM_TYP_DESC_JEWELRY has weight of -0.038173804675594065
# ADDR_PCT_CD_88.0 has weight of -0.014171474292573323
# PREM_TYP_DESC_HOTEL/MOTEL has weight of 0.12350016424889755
# Season_Winter has weight of -0.08995204160652114
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of -0.3730884072041711
# PREM_TYP_DESC_BOOK/CARD has weight of -0.015367536044644243
# PREM_TYP_DESC_FACTORY/WAREHOUSE has weight of 0.004898078942003863
# ADDR_PCT_CD_123.0 has weight of 0.06515503736180181
# PREM_TYP_DESC_DRUG STORE has weight of -0.6622697771447112
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of -0.14370153551910292
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of -0.026386144647782824
# ADDR_PCT_CD_111.0 has weight of -0.09085476730897436
# ADDR_PCT_CD_5.0 has weight of -0.009879349454118483
# ADDR_PCT_CD_7.0 has weight of 0.08550136151187385
# ADDR_PCT_CD_110.0 has weight of -0.16335832665615796
# ADDR_PCT_CD_9.0 has weight of -0.08188070102029002

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set predictions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,X_sm.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.725899314582841
# [[61591 11359]
#  [17634 15191]]
# Duration has weight of -1.9179988657988467
# PREM_TYP_DESC_CHAIN STORE has weight of -0.27808751749454297
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of -0.21774413468413575
# PREM_TYP_DESC_DRUG STORE has weight of -0.21302064922662867
# BORO_NM_MANHATTAN has weight of -0.13485917994578006
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of -0.10842685271835609
# PREM_TYP_DESC_ATM has weight of -0.0947165880785051
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of -0.043603210491059134
# PREM_TYP_DESC_SHOE has weight of -0.03664508898012645
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of -0.035612094722858555
# Season_Winter has weight of -0.03365672977007159
# BORO_NM_BROOKLYN has weight of -0.03342056920478134
# PREM_TYP_DESC_JEWELRY has weight of -0.028041420758054825
# ADDR_PCT_CD_110.0 has weight of -0.025700617032275348
# ADDR_PCT_CD_111.0 has weight of -0.024638892787065172
# ADDR_PCT_CD_9.0 has weight of -0.021789841698134034
# PREM_TYP_DESC_GAS STATION has weight of -0.0207029369869892
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of -0.018196650096005535
# BORO_NM_QUEENS has weight of -0.0172482754494507
# PREM_TYP_DESC_BOOK/CARD has weight of -0.0171527300730811
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of -0.017144187256202873
# ADDR_PCT_CD_66.0 has weight of -0.012235166319380673
# PREM_TYP_DESC_STORAGE FACILITY has weight of -0.011516481963587183
# PREM_TYP_DESC_HIGHWAY/PARKWAY has weight of -0.00873179005830528
# PREM_TYP_DESC_TUNNEL has weight of -0.008534916797431829
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED) has weight of -0.008064343684282969
# ADDR_PCT_CD_88.0 has weight of -0.007247157670153728
# PREM_TYP_DESC_RESTAURANT/DINER has weight of -0.004419206210692955
# Month_September has weight of -0.00346613274611327
# PREM_TYP_DESC_CHURCH has weight of -0.00023210990240253072
# ADDR_PCT_CD_5.0 has weight of 0.0014184601257875456
# PREM_TYP_DESC_CEMETERY has weight of 0.0036982766648771593
# PREM_TYP_DESC_AIRPORT TERMINAL has weight of 0.0041334256294515564
# PREM_TYP_DESC_FACTORY/WAREHOUSE has weight of 0.004832445432682729
# ADDR_PCT_CD_18.0 has weight of 0.010519603095995122
# ADDR_PCT_CD_7.0 has weight of 0.013492088797027466
# ADDR_PCT_CD_123.0 has weight of 0.013642092647173441
# PREM_TYP_DESC_FERRY/FERRY TERMINAL has weight of 0.016115471518462664
# PREM_TYP_DESC_GROCERY/BODEGA has weight of 0.016543340899293404
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE has weight of 0.01675862573234684
# PREM_TYP_DESC_PUBLIC BUILDING has weight of 0.02067725160982277
# PREM_TYP_DESC_PARK/PLAYGROUND has weight of 0.02310690524173119
# Day_Name_Saturday has weight of 0.028554846773521655
# GeoCell_X has weight of 0.03478884961081866
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.03610238511541643
# PREM_TYP_DESC_HOTEL/MOTEL has weight of 0.037256637680805955
# Year has weight of 0.047213002038150445
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of 0.14413367775399744
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of 0.2393477002986375
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of 0.28246877842460316
# Duration_lbl_Medium has weight of 0.2975091950752979
# LOC_OF_OCCUR_DESC_INSIDE has weight of 0.42731085917133443
# LOC_OF_OCCUR_DESC_FRONT OF has weight of 0.44254686356356543
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of 0.48782171033936467
# Duration_lbl_Long has weight of 1.0335018965501683

# %%
# now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=X_sm.columns)

weights.plot(kind='bar', figsize = (16,8))  #added figsize - trying to see if it expands the view
plt.show()

# %%
weights.describe()
# Out:
# count    55.000000
# mean      0.005103
# std       0.328803
# min      -1.917999
# 25%      -0.025170
# 50%      -0.004419
# 75%       0.021892
# max       1.033502
# dtype: float64

# %%
#Compute precision, recall, F-measure and support
from sklearn.metrics import *
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81     72950
#            1       0.57      0.46      0.51     32825
#
#     accuracy                           0.73    105775
#    macro avg       0.67      0.65      0.66    105775
# weighted avg       0.71      0.73      0.72    105775

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, lr_clf.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, lr_clf.predict_proba(X_test)[:,1])
plt.figure(figsize=(16,8))
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()
