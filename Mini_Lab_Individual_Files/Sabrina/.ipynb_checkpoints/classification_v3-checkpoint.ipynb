# %% [markdown]
# ## Setting Up the Data

# %%
import pandas as pd
import numpy as np

# %%
crime = pd.read_csv('FE1_NYPD_Complaint_Data_Historic.csv') # read in the csv %%file
# Out:
# C:\Users\sabri\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
crime.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# JURIS_DESC            object
# BORO_NM               object
# ADDR_PCT_CD          float64
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# PARKS_NM              object
# HADEVELOPT            object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# Start_Dt_Tm           object
# End_Dt_Tm             object
# Day_Name              object
# Duration             float64
# Duration_to_PD       float64
# Month                 object
# Day                  float64
# Year                 float64
# Duration_lbl          object
# Season                object
# Daytime               object
# GeoCell              float64
# GeoCell_X            float64
# GeoCell_Y            float64
# dtype: object

# %%
crime.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  \
# 0   101109527   12/31/2015     23:45:00          NaN          NaN  12/31/2015
# 1   153401121   12/31/2015     23:36:00          NaN          NaN  12/31/2015
# 2   569369778   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 3   968417082   12/31/2015     23:30:00          NaN          NaN  12/31/2015
# 4   641637920   12/31/2015     23:25:00   12/31/2015     23:30:00  12/31/2015
#
#    KY_CD                        OFNS_DESC  PD_CD  \
# 0    113                          FORGERY  729.0
# 1    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2    117                  DANGEROUS DRUGS  503.0
# 3    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4    344     ASSAULT 3 & RELATED OFFENSES  101.0
#
#                           PD_DESC  ... Duration_to_PD     Month   Day    Year  \
# 0  FORGERY,ETC.,UNCLASSIFIED-FELO  ...            0.0  December  31.0  2015.0
# 1                             NaN  ...            0.0  December  31.0  2015.0
# 2  CONTROLLED SUBSTANCE,INTENT TO  ...            0.0  December  31.0  2015.0
# 3                       ASSAULT 3  ...            0.0  December  31.0  2015.0
# 4                       ASSAULT 3  ...            0.0  December  31.0  2015.0
#
#    Duration_lbl  Season     Daytime GeoCell GeoCell_X  GeoCell_Y
# 0           NaN  Winter  Late Night    77.0       7.0        8.0
# 1           NaN  Winter  Late Night    49.0       9.0        5.0
# 2           NaN  Winter  Late Night    76.0       6.0        8.0
# 3           NaN  Winter  Late Night    40.0      10.0        4.0
# 4         Short  Winter  Late Night    55.0       5.0        6.0
#
# [5 rows x 38 columns]

# %%
#Create categorical list of all 68 possible offenses
#4 types of crime: Personal, Property, Statutory/State, and Other

#Personal - Assault, Battery, Abuse, Kidnapping, Rape, Homicide, Harrassment
personal_list = ['ASSAULT', 'BATTERY', 'MURDER', 'MANSLAUGHTER', 'HARRASSMENT', 'KIDNAPPING', 'RAPE', 'SEX', 'HOMICIDE', 'WEAPON', 'WEAPONS', 'PERSON']

#Property - Arson, Theft, Mischief, Burglary, Larceny, Robbery, Forgery, Embezzlement, Shoplifting, Trespass, Fraud/Financial
property_list = ['ARSON', 'THEFT', 'THEF', 'MISCHIEF', 'ROBBERY', 'BURGLARY', 'JOSTLING', 'TOOLS', 'FRAUD', 'FRAUDS', 'FRAUDULENT', 'LARCENY', 'FORGERY', 'STOLEN', 'UNAUTHORIZED', 'TRESPASS']

#Statutory - State-Related offenses, DUI, DWI, Gambling, Loitering, Drug, Traffic, Public Servant/Admin-related crimes
statutory_list = ['DRUGS', 'DRUG', 'SENSBLTY', 'PENAL', 'PUBLIC', 'INTOXICATED', 'TRAFFIC', 'ADMINISTRATIVE', 'GAMBLING', 'PROSTITUTION', 'ALCOHOLIC', 'DISORDERLY']

#Violent vs Non-Violent
violent = personal_list
non_violent = property_list + statutory_list

# %%
#Replace all Hyphons and forward slashes with spaces
def string_replace(column):
    
    newstrings = []
    
    for string in column:
        for word in string:
            if word == '-':
                newstrings.append(string.replace('-', ' '))
                break
            elif word == '/':
                newstrings.append(string.replace('/', ' '))
                break
        else:
            newstrings.append(string)
                
    
    return ''.join(newstrings)

def crime_apply(string):
    
    for word in string.split():
        if word in violent:
            return "Violent Crime"
        elif word in non_violent:
            return "Non-Violent Crime"
    else:
        pass

# %% [markdown]
# Running the function to create the correct buckets

# %%
#Remove NA's before applying Algo.. only removes about 2-3k observations
crime = crime[crime['OFNS_DESC'].notna()] 
crime['OFNS_DESC'] = crime.apply(lambda x: string_replace(x['OFNS_DESC']), axis = 1)
crime['OFNS_DESC_TYPE'] = crime.apply(lambda x: crime_apply(x['OFNS_DESC']), axis = 1)
crime.head(15)
# Out:
#     CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0    101109527   12/31/2015     23:45:00          NaN          NaN
# 1    153401121   12/31/2015     23:36:00          NaN          NaN
# 2    569369778   12/31/2015     23:30:00          NaN          NaN
# 3    968417082   12/31/2015     23:30:00          NaN          NaN
# 4    641637920   12/31/2015     23:25:00   12/31/2015     23:30:00
# 5    365661343   12/31/2015     23:18:00   12/31/2015     23:25:00
# 6    608231454   12/31/2015     23:15:00          NaN          NaN
# 7    265023856   12/31/2015     23:15:00   12/31/2015     23:15:00
# 8    989238731   12/31/2015     23:15:00   12/31/2015     23:30:00
# 9    415095955   12/31/2015     23:10:00   12/31/2015     23:10:00
# 10   731283092   12/31/2015     23:05:00   12/31/2015     23:15:00
# 11   178090167   12/31/2015     23:00:00   12/31/2015     23:05:00
# 12   898496564   12/31/2015     23:00:00          NaN          NaN
# 13   566081066   12/31/2015     23:00:00          NaN          NaN
# 14   584555879   12/31/2015     23:00:00          NaN          NaN
#
#         RPT_DT  KY_CD                        OFNS_DESC  PD_CD  \
# 0   12/31/2015    113                          FORGERY  729.0
# 1   12/31/2015    101  MURDER & NON NEGL. MANSLAUGHTER    NaN
# 2   12/31/2015    117                  DANGEROUS DRUGS  503.0
# 3   12/31/2015    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 4   12/31/2015    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 5   12/31/2015    106                   FELONY ASSAULT  109.0
# 6   12/31/2015    235                  DANGEROUS DRUGS  511.0
# 7   12/31/2015    118                DANGEROUS WEAPONS  792.0
# 8   12/31/2015    344     ASSAULT 3 & RELATED OFFENSES  101.0
# 9   12/31/2015    341                    PETIT LARCENY  338.0
# 10  12/31/2015    341                    PETIT LARCENY  343.0
# 11  12/31/2015    341                    PETIT LARCENY  338.0
# 12  12/31/2015    109                    GRAND LARCENY  406.0
# 13  12/31/2015    109                    GRAND LARCENY  415.0
# 14  12/31/2015    113                          FORGERY  729.0
#
#                                     PD_DESC  ...     Month   Day    Year  \
# 0            FORGERY,ETC.,UNCLASSIFIED-FELO  ...  December  31.0  2015.0
# 1                                       NaN  ...  December  31.0  2015.0
# 2            CONTROLLED SUBSTANCE,INTENT TO  ...  December  31.0  2015.0
# 3                                 ASSAULT 3  ...  December  31.0  2015.0
# 4                                 ASSAULT 3  ...  December  31.0  2015.0
# 5                  ASSAULT 2,1,UNCLASSIFIED  ...  December  31.0  2015.0
# 6            CONTROLLED SUBSTANCE, POSSESSI  ...  December  31.0  2015.0
# 7                  WEAPONS POSSESSION 1 & 2  ...  December  31.0  2015.0
# 8                                 ASSAULT 3  ...  December  31.0  2015.0
# 9            LARCENY,PETIT FROM BUILDING,UN  ...  December  31.0  2015.0
# 10                 LARCENY,PETIT OF BICYCLE  ...  December  31.0  2015.0
# 11           LARCENY,PETIT FROM BUILDING,UN  ...  December  31.0  2015.0
# 12  LARCENY,GRAND FROM PERSON, BAG OPEN/DIP  ...  December  31.0  2015.0
# 13           LARCENY,GRAND FROM PERSON,PICK  ...  December  31.0  2015.0
# 14           FORGERY,ETC.,UNCLASSIFIED-FELO  ...  December  31.0  2015.0
#
#    Duration_lbl  Season     Daytime GeoCell GeoCell_X GeoCell_Y  \
# 0           NaN  Winter  Late Night    77.0       7.0       8.0
# 1           NaN  Winter  Late Night    49.0       9.0       5.0
# 2           NaN  Winter  Late Night    76.0       6.0       8.0
# 3           NaN  Winter  Late Night    40.0      10.0       4.0
# 4         Short  Winter  Late Night    55.0       5.0       6.0
# 5         Short  Winter  Late Night    46.0       6.0       5.0
# 6           NaN  Winter  Late Night    55.0       5.0       6.0
# 7           NaN  Winter  Late Night    87.0       7.0       9.0
# 8         Short  Winter  Late Night    87.0       7.0       9.0
# 9           NaN  Winter  Late Night    66.0       6.0       7.0
# 10        Short  Winter  Late Night    77.0       7.0       8.0
# 11        Short  Winter  Late Night    55.0       5.0       6.0
# 12          NaN  Winter  Late Night    65.0       5.0       7.0
# 13          NaN  Winter  Late Night    65.0       5.0       7.0
# 14          NaN  Winter  Late Night    36.0       6.0       4.0
#
#        OFNS_DESC_TYPE
# 0   Non-Violent Crime
# 1       Violent Crime
# 2   Non-Violent Crime
# 3       Violent Crime
# 4       Violent Crime
# 5       Violent Crime
# 6   Non-Violent Crime
# 7       Violent Crime
# 8       Violent Crime
# 9   Non-Violent Crime
# 10  Non-Violent Crime
# 11  Non-Violent Crime
# 12  Non-Violent Crime
# 13  Non-Violent Crime
# 14  Non-Violent Crime
#
# [15 rows x 39 columns]

# %%
#Value Counts by Crime Type
crime['OFNS_DESC_TYPE'].value_counts()
# Out:
# Non-Violent Crime    710987
# Violent Crime        333129
# Name: OFNS_DESC_TYPE, dtype: int64

# %%
#Drop the variables that are extraneous or duplicitous based on EDA
if 'CMPLNT_FR_DT' in crime:
    del crime['CMPLNT_FR_DT']
if 'CMPLNT_FR_TM' in crime:
    del crime['CMPLNT_FR_TM']
if 'CMPLNT_TO_DT' in crime:
    del crime['CMPLNT_TO_DT']
if 'CMPLNT_TO_TM' in crime:
    del crime['CMPLNT_TO_TM']
if 'PARKS_NM' in crime:
    del crime['PARKS_NM']
if 'HADEVELOPT' in crime:
    del crime['HADEVELOPT']  
if 'End_Dt_Tm' in crime:
    del crime['End_Dt_Tm']  
if 'CMPLNT_NUM' in crime:
    del crime['CMPLNT_NUM']
if 'KY_CD' in crime:
    del crime['KY_CD']
if 'RPT_DT' in crime:
    del crime['RPT_DT']
if 'PD_CD' in crime:
    del crime['PD_CD']
if 'PD_DESC' in crime:
    del crime['PD_DESC']
if 'X_COORD_CD' in crime:
    del crime['X_COORD_CD']
if 'Y_COORD_CD' in crime:
    del crime['Y_COORD_CD']
if 'Latitude' in crime:
    del crime['Latitude']
if 'Longitude' in crime:
    del crime['Longitude']
if 'Lat_Lon' in crime:
    del crime['Lat_Lon']
if 'OFNS_DESC' in crime:
    del crime['OFNS_DESC']

# %%
#dropping any remaining NANs
crime = crime.dropna()

# %%
crime.isnull().values.any()
# Out:
# False

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 586995 entries, 4 to 1048573
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CRM_ATPT_CPTD_CD   586995 non-null  object
#  1   LAW_CAT_CD         586995 non-null  object
#  2   JURIS_DESC         586995 non-null  object
#  3   BORO_NM            586995 non-null  object
#  4   ADDR_PCT_CD        586995 non-null  float64
#  5   LOC_OF_OCCUR_DESC  586995 non-null  object
#  6   PREM_TYP_DESC      586995 non-null  object
#  7   Start_Dt_Tm        586995 non-null  object
#  8   Day_Name           586995 non-null  object
#  9   Duration           586995 non-null  float64
#  10  Duration_to_PD     586995 non-null  float64
#  11  Month              586995 non-null  object
#  12  Day                586995 non-null  float64
#  13  Year               586995 non-null  float64
#  14  Duration_lbl       586995 non-null  object
#  15  Season             586995 non-null  object
#  16  Daytime            586995 non-null  object
#  17  GeoCell            586995 non-null  float64
#  18  GeoCell_X          586995 non-null  float64
#  19  GeoCell_Y          586995 non-null  float64
#  20  OFNS_DESC_TYPE     586995 non-null  object
# dtypes: float64(8), object(13)
# memory usage: 98.5+ MB

# %%
# replace the current Violent Crime classification atribute with something slightly more intuitive and readable
crime['NonViolent'] = crime.OFNS_DESC_TYPE=='Non-Violent Crime' 
crime.NonViolent = crime.NonViolent.astype(np.int)

# %%
# perform one-hot encoding of the categorical data on 'JURIS_DESC','BORO_NM','LOC_OF_OCCUR_DESC',
#'ADDR_PCT_CD','PREM_TYP_DESC','Day_Name','Month','Duration_lbl','Season','Daytime'
tmp_df = pd.get_dummies(crime.JURIS_DESC,prefix='JURIS_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.BORO_NM,prefix='BORO_NM')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.LOC_OF_OCCUR_DESC,prefix='LOC_OF_OCCUR_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.ADDR_PCT_CD,prefix='ADDR_PCT_CD')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.PREM_TYP_DESC,prefix='PREM_TYP_DESC')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Day_Name,prefix='Day_Name')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Month,prefix='Month')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Duration_lbl,prefix='Duration_lbl')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Season,prefix='Season')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Daytime,prefix='Daytime')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 586995 entries, 4 to 1048573
# Columns: 229 entries, CRM_ATPT_CPTD_CD to Daytime_Night
# dtypes: float64(8), int32(1), object(13), uint8(207)
# memory usage: 216.6+ MB

# %%
#Now we drop the original variables
if 'JURIS_DESC' in crime:    
    del crime['JURIS_DESC'] # get rid of the original category as it is now one-hot encoded
if 'BORO_NM' in crime:    
    del crime['BORO_NM'] # get rid of the original category as it is now one-hot encoded
if 'LOC_OF_OCCUR_DESC' in crime:    
    del crime['LOC_OF_OCCUR_DESC'] # get rid of the original category as it is now one-hot encoded
if 'ADDR_PCT_CD' in crime:    
    del crime['ADDR_PCT_CD'] # get rid of the original category as it is now one-hot encoded
if 'PREM_TYP_DESC' in crime:    
    del crime['PREM_TYP_DESC'] # get rid of the original category as it is now one-hot encoded
if 'Day_Name' in crime:    
    del crime['Day_Name'] # get rid of the original category as it is now one-hot encoded
if 'Month' in crime:    
    del crime['Month'] # get rid of the original category as it is now one-hot encoded
if 'Duration_lbl' in crime:    
    del crime['Duration_lbl'] # get rid of the original category as it is now one-hot encoded
if 'Season' in crime:    
    del crime['Season'] # get rid of the original category as it is now one-hot encoded
if 'Daytime' in crime:    
    del crime['Daytime'] # get rid of the original category as it is now one-hot encoded

# %%
#Drop categories not using
if 'CRM_ATPT_CPTD_CD' in crime:    
    del crime['CRM_ATPT_CPTD_CD']   
if 'LAW_CAT_CD' in crime:
    del crime['LAW_CAT_CD']
if 'Start_Dt_Tm' in crime:
    del crime['Start_Dt_Tm']

# %%
if 'OFNS_DESC_TYPE' in crime:
    del crime['OFNS_DESC_TYPE']

# %%
pd.set_option('display.max_rows', 300)
crime.dtypes
# Out:
# Duration                                      float64
# Duration_to_PD                                float64
# Day                                           float64
# Year                                          float64
# GeoCell                                       float64
# GeoCell_X                                     float64
# GeoCell_Y                                     float64
# NonViolent                                      int32
# JURIS_DESC_AMTRACK                              uint8
# JURIS_DESC_DEPT OF CORRECTIONS                  uint8
# JURIS_DESC_HEALTH & HOSP CORP                   uint8
# JURIS_DESC_LONG ISLAND RAILRD                   uint8
# JURIS_DESC_METRO NORTH                          uint8
# JURIS_DESC_N.Y. HOUSING POLICE                  uint8
# JURIS_DESC_N.Y. POLICE DEPT                     uint8
# JURIS_DESC_N.Y. STATE PARKS                     uint8
# JURIS_DESC_N.Y. STATE POLICE                    uint8
# JURIS_DESC_N.Y. TRANSIT POLICE                  uint8
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE         uint8
# JURIS_DESC_NYC PARKS                            uint8
# JURIS_DESC_NYS DEPT TAX AND FINANCE             uint8
# JURIS_DESC_OTHER                                uint8
# JURIS_DESC_POLICE DEPT NYC                      uint8
# JURIS_DESC_PORT AUTHORITY                       uint8
# JURIS_DESC_STATN IS RAPID TRANS                 uint8
# JURIS_DESC_TRI-BORO BRDG TUNNL                  uint8
# JURIS_DESC_U.S. PARK POLICE                     uint8
# BORO_NM_BRONX                                   uint8
# BORO_NM_BROOKLYN                                uint8
# BORO_NM_MANHATTAN                               uint8
# BORO_NM_QUEENS                                  uint8
# BORO_NM_STATEN ISLAND                           uint8
# LOC_OF_OCCUR_DESC_FRONT OF                      uint8
# LOC_OF_OCCUR_DESC_INSIDE                        uint8
# LOC_OF_OCCUR_DESC_OPPOSITE OF                   uint8
# LOC_OF_OCCUR_DESC_REAR OF                       uint8
# ADDR_PCT_CD_1.0                                 uint8
# ADDR_PCT_CD_5.0                                 uint8
# ADDR_PCT_CD_6.0                                 uint8
# ADDR_PCT_CD_7.0                                 uint8
# ADDR_PCT_CD_9.0                                 uint8
# ADDR_PCT_CD_10.0                                uint8
# ADDR_PCT_CD_13.0                                uint8
# ADDR_PCT_CD_14.0                                uint8
# ADDR_PCT_CD_17.0                                uint8
# ADDR_PCT_CD_18.0                                uint8
# ADDR_PCT_CD_19.0                                uint8
# ADDR_PCT_CD_20.0                                uint8
# ADDR_PCT_CD_22.0                                uint8
# ADDR_PCT_CD_23.0                                uint8
# ADDR_PCT_CD_24.0                                uint8
# ADDR_PCT_CD_25.0                                uint8
# ADDR_PCT_CD_26.0                                uint8
# ADDR_PCT_CD_28.0                                uint8
# ADDR_PCT_CD_30.0                                uint8
# ADDR_PCT_CD_32.0                                uint8
# ADDR_PCT_CD_33.0                                uint8
# ADDR_PCT_CD_34.0                                uint8
# ADDR_PCT_CD_40.0                                uint8
# ADDR_PCT_CD_41.0                                uint8
# ADDR_PCT_CD_42.0                                uint8
# ADDR_PCT_CD_43.0                                uint8
# ADDR_PCT_CD_44.0                                uint8
# ADDR_PCT_CD_45.0                                uint8
# ADDR_PCT_CD_46.0                                uint8
# ADDR_PCT_CD_47.0                                uint8
# ADDR_PCT_CD_48.0                                uint8
# ADDR_PCT_CD_49.0                                uint8
# ADDR_PCT_CD_50.0                                uint8
# ADDR_PCT_CD_52.0                                uint8
# ADDR_PCT_CD_60.0                                uint8
# ADDR_PCT_CD_61.0                                uint8
# ADDR_PCT_CD_62.0                                uint8
# ADDR_PCT_CD_63.0                                uint8
# ADDR_PCT_CD_66.0                                uint8
# ADDR_PCT_CD_67.0                                uint8
# ADDR_PCT_CD_68.0                                uint8
# ADDR_PCT_CD_69.0                                uint8
# ADDR_PCT_CD_70.0                                uint8
# ADDR_PCT_CD_71.0                                uint8
# ADDR_PCT_CD_72.0                                uint8
# ADDR_PCT_CD_73.0                                uint8
# ADDR_PCT_CD_75.0                                uint8
# ADDR_PCT_CD_76.0                                uint8
# ADDR_PCT_CD_77.0                                uint8
# ADDR_PCT_CD_78.0                                uint8
# ADDR_PCT_CD_79.0                                uint8
# ADDR_PCT_CD_81.0                                uint8
# ADDR_PCT_CD_83.0                                uint8
# ADDR_PCT_CD_84.0                                uint8
# ADDR_PCT_CD_88.0                                uint8
# ADDR_PCT_CD_90.0                                uint8
# ADDR_PCT_CD_94.0                                uint8
# ADDR_PCT_CD_100.0                               uint8
# ADDR_PCT_CD_101.0                               uint8
# ADDR_PCT_CD_102.0                               uint8
# ADDR_PCT_CD_103.0                               uint8
# ADDR_PCT_CD_104.0                               uint8
# ADDR_PCT_CD_105.0                               uint8
# ADDR_PCT_CD_106.0                               uint8
# ADDR_PCT_CD_107.0                               uint8
# ADDR_PCT_CD_108.0                               uint8
# ADDR_PCT_CD_109.0                               uint8
# ADDR_PCT_CD_110.0                               uint8
# ADDR_PCT_CD_111.0                               uint8
# ADDR_PCT_CD_112.0                               uint8
# ADDR_PCT_CD_113.0                               uint8
# ADDR_PCT_CD_114.0                               uint8
# ADDR_PCT_CD_115.0                               uint8
# ADDR_PCT_CD_120.0                               uint8
# ADDR_PCT_CD_121.0                               uint8
# ADDR_PCT_CD_122.0                               uint8
# ADDR_PCT_CD_123.0                               uint8
# PREM_TYP_DESC_ABANDONED BUILDING                uint8
# PREM_TYP_DESC_AIRPORT TERMINAL                  uint8
# PREM_TYP_DESC_ATM                               uint8
# PREM_TYP_DESC_BANK                              uint8
# PREM_TYP_DESC_BAR/NIGHT CLUB                    uint8
# PREM_TYP_DESC_BEAUTY & NAIL SALON               uint8
# PREM_TYP_DESC_BOOK/CARD                         uint8
# PREM_TYP_DESC_BRIDGE                            uint8
# PREM_TYP_DESC_BUS (NYC TRANSIT)                 uint8
# PREM_TYP_DESC_BUS (OTHER)                       uint8
# PREM_TYP_DESC_BUS STOP                          uint8
# PREM_TYP_DESC_BUS TERMINAL                      uint8
# PREM_TYP_DESC_CANDY STORE                       uint8
# PREM_TYP_DESC_CEMETERY                          uint8
# PREM_TYP_DESC_CHAIN STORE                       uint8
# PREM_TYP_DESC_CHECK CASHING BUSINESS            uint8
# PREM_TYP_DESC_CHURCH                            uint8
# PREM_TYP_DESC_CLOTHING/BOUTIQUE                 uint8
# PREM_TYP_DESC_COMMERCIAL BUILDING               uint8
# PREM_TYP_DESC_CONSTRUCTION SITE                 uint8
# PREM_TYP_DESC_DEPARTMENT STORE                  uint8
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE             uint8
# PREM_TYP_DESC_DRUG STORE                        uint8
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY               uint8
# PREM_TYP_DESC_FACTORY/WAREHOUSE                 uint8
# PREM_TYP_DESC_FAST FOOD                         uint8
# PREM_TYP_DESC_FERRY/FERRY TERMINAL              uint8
# PREM_TYP_DESC_FOOD SUPERMARKET                  uint8
# PREM_TYP_DESC_GAS STATION                       uint8
# PREM_TYP_DESC_GROCERY/BODEGA                    uint8
# PREM_TYP_DESC_GYM/FITNESS FACILITY              uint8
# PREM_TYP_DESC_HIGHWAY/PARKWAY                   uint8
# PREM_TYP_DESC_HOSPITAL                          uint8
# PREM_TYP_DESC_HOTEL/MOTEL                       uint8
# PREM_TYP_DESC_JEWELRY                           uint8
# PREM_TYP_DESC_LIQUOR STORE                      uint8
# PREM_TYP_DESC_LOAN COMPANY                      uint8
# PREM_TYP_DESC_MARINA/PIER                       uint8
# PREM_TYP_DESC_MOSQUE                            uint8
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS)            uint8
# PREM_TYP_DESC_OTHER                             uint8
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP            uint8
# PREM_TYP_DESC_PARK/PLAYGROUND                   uint8
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)      uint8
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)       uint8
# PREM_TYP_DESC_PHOTO/COPY                        uint8
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL          uint8
# PREM_TYP_DESC_PUBLIC BUILDING                   uint8
# PREM_TYP_DESC_PUBLIC SCHOOL                     uint8
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE            uint8
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING        uint8
# PREM_TYP_DESC_RESIDENCE-HOUSE                   uint8
# PREM_TYP_DESC_RESTAURANT/DINER                  uint8
# PREM_TYP_DESC_SHOE                              uint8
# PREM_TYP_DESC_SMALL MERCHANT                    uint8
# PREM_TYP_DESC_SOCIAL CLUB/POLICY                uint8
# PREM_TYP_DESC_STORAGE FACILITY                  uint8
# PREM_TYP_DESC_STORE UNCLASSIFIED                uint8
# PREM_TYP_DESC_STREET                            uint8
# PREM_TYP_DESC_SYNAGOGUE                         uint8
# PREM_TYP_DESC_TAXI (LIVERY LICENSED)            uint8
# PREM_TYP_DESC_TAXI (YELLOW LICENSED)            uint8
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED)          uint8
# PREM_TYP_DESC_TELECOMM. STORE                   uint8
# PREM_TYP_DESC_TRAMWAY                           uint8
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY              uint8
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER)          uint8
# PREM_TYP_DESC_TUNNEL                            uint8
# PREM_TYP_DESC_VARIETY STORE                     uint8
# PREM_TYP_DESC_VIDEO STORE                       uint8
# Day_Name_Friday                                 uint8
# Day_Name_Monday                                 uint8
# Day_Name_Saturday                               uint8
# Day_Name_Sunday                                 uint8
# Day_Name_Thursday                               uint8
# Day_Name_Tuesday                                uint8
# Day_Name_Wednesday                              uint8
# Month_April                                     uint8
# Month_August                                    uint8
# Month_December                                  uint8
# Month_February                                  uint8
# Month_January                                   uint8
# Month_July                                      uint8
# Month_June                                      uint8
# Month_March                                     uint8
# Month_May                                       uint8
# Month_November                                  uint8
# Month_October                                   uint8
# Month_September                                 uint8
# Duration_lbl_Long                               uint8
# Duration_lbl_Medium                             uint8
# Duration_lbl_Short                              uint8
# Season_Fall                                     uint8
# Season_Spring                                   uint8
# Season_Summer                                   uint8
# Season_Winter                                   uint8
# Daytime_Day                                     uint8
# Daytime_Early Morning                           uint8
# Daytime_Evening                                 uint8
# Daytime_Late Night                              uint8
# Daytime_Morning                                 uint8
# Daytime_Night                                   uint8
# dtype: object

# %%
#data speed of processing merits a sample run first
crime_sample = crime.sample(10000)
#also setting aside a copy for the smaller variable list before I separate out X,y
crime_sm = crime

# %%
crime_sm.dtypes
# Out:
# Duration                                      float64
# Duration_to_PD                                float64
# Day                                           float64
# Year                                          float64
# GeoCell                                       float64
# GeoCell_X                                     float64
# GeoCell_Y                                     float64
# NonViolent                                      int32
# JURIS_DESC_AMTRACK                              uint8
# JURIS_DESC_DEPT OF CORRECTIONS                  uint8
# JURIS_DESC_HEALTH & HOSP CORP                   uint8
# JURIS_DESC_LONG ISLAND RAILRD                   uint8
# JURIS_DESC_METRO NORTH                          uint8
# JURIS_DESC_N.Y. HOUSING POLICE                  uint8
# JURIS_DESC_N.Y. POLICE DEPT                     uint8
# JURIS_DESC_N.Y. STATE PARKS                     uint8
# JURIS_DESC_N.Y. STATE POLICE                    uint8
# JURIS_DESC_N.Y. TRANSIT POLICE                  uint8
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE         uint8
# JURIS_DESC_NYC PARKS                            uint8
# JURIS_DESC_NYS DEPT TAX AND FINANCE             uint8
# JURIS_DESC_OTHER                                uint8
# JURIS_DESC_POLICE DEPT NYC                      uint8
# JURIS_DESC_PORT AUTHORITY                       uint8
# JURIS_DESC_STATN IS RAPID TRANS                 uint8
# JURIS_DESC_TRI-BORO BRDG TUNNL                  uint8
# JURIS_DESC_U.S. PARK POLICE                     uint8
# BORO_NM_BRONX                                   uint8
# BORO_NM_BROOKLYN                                uint8
# BORO_NM_MANHATTAN                               uint8
# BORO_NM_QUEENS                                  uint8
# BORO_NM_STATEN ISLAND                           uint8
# LOC_OF_OCCUR_DESC_FRONT OF                      uint8
# LOC_OF_OCCUR_DESC_INSIDE                        uint8
# LOC_OF_OCCUR_DESC_OPPOSITE OF                   uint8
# LOC_OF_OCCUR_DESC_REAR OF                       uint8
# ADDR_PCT_CD_1.0                                 uint8
# ADDR_PCT_CD_5.0                                 uint8
# ADDR_PCT_CD_6.0                                 uint8
# ADDR_PCT_CD_7.0                                 uint8
# ADDR_PCT_CD_9.0                                 uint8
# ADDR_PCT_CD_10.0                                uint8
# ADDR_PCT_CD_13.0                                uint8
# ADDR_PCT_CD_14.0                                uint8
# ADDR_PCT_CD_17.0                                uint8
# ADDR_PCT_CD_18.0                                uint8
# ADDR_PCT_CD_19.0                                uint8
# ADDR_PCT_CD_20.0                                uint8
# ADDR_PCT_CD_22.0                                uint8
# ADDR_PCT_CD_23.0                                uint8
# ADDR_PCT_CD_24.0                                uint8
# ADDR_PCT_CD_25.0                                uint8
# ADDR_PCT_CD_26.0                                uint8
# ADDR_PCT_CD_28.0                                uint8
# ADDR_PCT_CD_30.0                                uint8
# ADDR_PCT_CD_32.0                                uint8
# ADDR_PCT_CD_33.0                                uint8
# ADDR_PCT_CD_34.0                                uint8
# ADDR_PCT_CD_40.0                                uint8
# ADDR_PCT_CD_41.0                                uint8
# ADDR_PCT_CD_42.0                                uint8
# ADDR_PCT_CD_43.0                                uint8
# ADDR_PCT_CD_44.0                                uint8
# ADDR_PCT_CD_45.0                                uint8
# ADDR_PCT_CD_46.0                                uint8
# ADDR_PCT_CD_47.0                                uint8
# ADDR_PCT_CD_48.0                                uint8
# ADDR_PCT_CD_49.0                                uint8
# ADDR_PCT_CD_50.0                                uint8
# ADDR_PCT_CD_52.0                                uint8
# ADDR_PCT_CD_60.0                                uint8
# ADDR_PCT_CD_61.0                                uint8
# ADDR_PCT_CD_62.0                                uint8
# ADDR_PCT_CD_63.0                                uint8
# ADDR_PCT_CD_66.0                                uint8
# ADDR_PCT_CD_67.0                                uint8
# ADDR_PCT_CD_68.0                                uint8
# ADDR_PCT_CD_69.0                                uint8
# ADDR_PCT_CD_70.0                                uint8
# ADDR_PCT_CD_71.0                                uint8
# ADDR_PCT_CD_72.0                                uint8
# ADDR_PCT_CD_73.0                                uint8
# ADDR_PCT_CD_75.0                                uint8
# ADDR_PCT_CD_76.0                                uint8
# ADDR_PCT_CD_77.0                                uint8
# ADDR_PCT_CD_78.0                                uint8
# ADDR_PCT_CD_79.0                                uint8
# ADDR_PCT_CD_81.0                                uint8
# ADDR_PCT_CD_83.0                                uint8
# ADDR_PCT_CD_84.0                                uint8
# ADDR_PCT_CD_88.0                                uint8
# ADDR_PCT_CD_90.0                                uint8
# ADDR_PCT_CD_94.0                                uint8
# ADDR_PCT_CD_100.0                               uint8
# ADDR_PCT_CD_101.0                               uint8
# ADDR_PCT_CD_102.0                               uint8
# ADDR_PCT_CD_103.0                               uint8
# ADDR_PCT_CD_104.0                               uint8
# ADDR_PCT_CD_105.0                               uint8
# ADDR_PCT_CD_106.0                               uint8
# ADDR_PCT_CD_107.0                               uint8
# ADDR_PCT_CD_108.0                               uint8
# ADDR_PCT_CD_109.0                               uint8
# ADDR_PCT_CD_110.0                               uint8
# ADDR_PCT_CD_111.0                               uint8
# ADDR_PCT_CD_112.0                               uint8
# ADDR_PCT_CD_113.0                               uint8
# ADDR_PCT_CD_114.0                               uint8
# ADDR_PCT_CD_115.0                               uint8
# ADDR_PCT_CD_120.0                               uint8
# ADDR_PCT_CD_121.0                               uint8
# ADDR_PCT_CD_122.0                               uint8
# ADDR_PCT_CD_123.0                               uint8
# PREM_TYP_DESC_ABANDONED BUILDING                uint8
# PREM_TYP_DESC_AIRPORT TERMINAL                  uint8
# PREM_TYP_DESC_ATM                               uint8
# PREM_TYP_DESC_BANK                              uint8
# PREM_TYP_DESC_BAR/NIGHT CLUB                    uint8
# PREM_TYP_DESC_BEAUTY & NAIL SALON               uint8
# PREM_TYP_DESC_BOOK/CARD                         uint8
# PREM_TYP_DESC_BRIDGE                            uint8
# PREM_TYP_DESC_BUS (NYC TRANSIT)                 uint8
# PREM_TYP_DESC_BUS (OTHER)                       uint8
# PREM_TYP_DESC_BUS STOP                          uint8
# PREM_TYP_DESC_BUS TERMINAL                      uint8
# PREM_TYP_DESC_CANDY STORE                       uint8
# PREM_TYP_DESC_CEMETERY                          uint8
# PREM_TYP_DESC_CHAIN STORE                       uint8
# PREM_TYP_DESC_CHECK CASHING BUSINESS            uint8
# PREM_TYP_DESC_CHURCH                            uint8
# PREM_TYP_DESC_CLOTHING/BOUTIQUE                 uint8
# PREM_TYP_DESC_COMMERCIAL BUILDING               uint8
# PREM_TYP_DESC_CONSTRUCTION SITE                 uint8
# PREM_TYP_DESC_DEPARTMENT STORE                  uint8
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE             uint8
# PREM_TYP_DESC_DRUG STORE                        uint8
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY               uint8
# PREM_TYP_DESC_FACTORY/WAREHOUSE                 uint8
# PREM_TYP_DESC_FAST FOOD                         uint8
# PREM_TYP_DESC_FERRY/FERRY TERMINAL              uint8
# PREM_TYP_DESC_FOOD SUPERMARKET                  uint8
# PREM_TYP_DESC_GAS STATION                       uint8
# PREM_TYP_DESC_GROCERY/BODEGA                    uint8
# PREM_TYP_DESC_GYM/FITNESS FACILITY              uint8
# PREM_TYP_DESC_HIGHWAY/PARKWAY                   uint8
# PREM_TYP_DESC_HOSPITAL                          uint8
# PREM_TYP_DESC_HOTEL/MOTEL                       uint8
# PREM_TYP_DESC_JEWELRY                           uint8
# PREM_TYP_DESC_LIQUOR STORE                      uint8
# PREM_TYP_DESC_LOAN COMPANY                      uint8
# PREM_TYP_DESC_MARINA/PIER                       uint8
# PREM_TYP_DESC_MOSQUE                            uint8
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS)            uint8
# PREM_TYP_DESC_OTHER                             uint8
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP            uint8
# PREM_TYP_DESC_PARK/PLAYGROUND                   uint8
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)      uint8
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)       uint8
# PREM_TYP_DESC_PHOTO/COPY                        uint8
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL          uint8
# PREM_TYP_DESC_PUBLIC BUILDING                   uint8
# PREM_TYP_DESC_PUBLIC SCHOOL                     uint8
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE            uint8
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING        uint8
# PREM_TYP_DESC_RESIDENCE-HOUSE                   uint8
# PREM_TYP_DESC_RESTAURANT/DINER                  uint8
# PREM_TYP_DESC_SHOE                              uint8
# PREM_TYP_DESC_SMALL MERCHANT                    uint8
# PREM_TYP_DESC_SOCIAL CLUB/POLICY                uint8
# PREM_TYP_DESC_STORAGE FACILITY                  uint8
# PREM_TYP_DESC_STORE UNCLASSIFIED                uint8
# PREM_TYP_DESC_STREET                            uint8
# PREM_TYP_DESC_SYNAGOGUE                         uint8
# PREM_TYP_DESC_TAXI (LIVERY LICENSED)            uint8
# PREM_TYP_DESC_TAXI (YELLOW LICENSED)            uint8
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED)          uint8
# PREM_TYP_DESC_TELECOMM. STORE                   uint8
# PREM_TYP_DESC_TRAMWAY                           uint8
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY              uint8
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER)          uint8
# PREM_TYP_DESC_TUNNEL                            uint8
# PREM_TYP_DESC_VARIETY STORE                     uint8
# PREM_TYP_DESC_VIDEO STORE                       uint8
# Day_Name_Friday                                 uint8
# Day_Name_Monday                                 uint8
# Day_Name_Saturday                               uint8
# Day_Name_Sunday                                 uint8
# Day_Name_Thursday                               uint8
# Day_Name_Tuesday                                uint8
# Day_Name_Wednesday                              uint8
# Month_April                                     uint8
# Month_August                                    uint8
# Month_December                                  uint8
# Month_February                                  uint8
# Month_January                                   uint8
# Month_July                                      uint8
# Month_June                                      uint8
# Month_March                                     uint8
# Month_May                                       uint8
# Month_November                                  uint8
# Month_October                                   uint8
# Month_September                                 uint8
# Duration_lbl_Long                               uint8
# Duration_lbl_Medium                             uint8
# Duration_lbl_Short                              uint8
# Season_Fall                                     uint8
# Season_Spring                                   uint8
# Season_Summer                                   uint8
# Season_Winter                                   uint8
# Daytime_Day                                     uint8
# Daytime_Early Morning                           uint8
# Daytime_Evening                                 uint8
# Daytime_Late Night                              uint8
# Daytime_Morning                                 uint8
# Daytime_Night                                   uint8
# dtype: object

# %% [markdown]
# ## Logistic Regression Model 1

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'NonViolent' in crime:
    y = crime['NonViolent'].values # get the labels we want
    del crime['NonViolent'] # get rid of the class label
    X = crime.values # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn

# %%
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
# run logistic regression and vary some parameters
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt

# first we create a reusable logisitic regression object
#   here we can setup the object with different learning parameters and constants
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None, solver='liblinear' ) # get object

# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("confusion matrix\n",conf)
    iter_num+=1
    
# Also note that every time you run the above code
#   it randomly creates a new training and testing set, 
#   so accuracy will be different each time
# Out:
# ====Iteration 0  ====
# accuracy 0.7277234047990188
# confusion matrix
#  [[14500 21919]
#  [10046 70934]]
# ====Iteration 1  ====
# accuracy 0.7280981950442508
# confusion matrix
#  [[13955 22368]
#  [ 9553 71523]]
# ====Iteration 2  ====
# accuracy 0.7317864717757392
# confusion matrix
#  [[17097 19192]
#  [12296 68814]]

# %%
# this does the exact same thing as the above block of code, but with shorter syntax

for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
    lr_clf.fit(X[train_indices],y[train_indices])  # train object
    y_hat = lr_clf.predict(X[test_indices]) # get test set precitions

    # print the accuracy and confusion matrix 
    print("====Iteration",iter_num," ====")
    print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
    print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# ====Iteration 0  ====
# accuracy 0.733515617679878
# confusion matrix
#  [[16986 19325]
#  [11960 69128]]
# ====Iteration 1  ====
# accuracy 0.7302447209942163
# confusion matrix
#  [[15698 20709]
#  [10960 70032]]
# ====Iteration 2  ====
# accuracy 0.7297166074668439
# confusion matrix
#  [[15339 21015]
#  [10716 70329]]

# %%
# and here is an even shorter way of getting the accuracies for each training and test set
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(lr_clf, X, y=y, cv=cv_object) # this also can help with parallelism
print(accuracies)
# Out:
# [0.73313231 0.7279108  0.73038101]

# %%
# here we can change some of the parameters interactively
from ipywidgets import widgets as wd

def lr_explor(cost):
    lr_clf = LogisticRegression(penalty='l2', C=cost, class_weight=None,solver='liblinear') # get object
    accuracies = cross_val_score(lr_clf,X,y=y,cv=cv_object) # this also can help with parallelism
    print(accuracies)

wd.interact(lr_explor,cost=(0.001,5.0,0.05),__manual=True)
# Out:
# interactive(children=(FloatSlider(value=2.451, description='cost', max=5.0, min=0.001, step=0.05), Output()), …
# <function __main__.lr_explor(cost)>

# %%
# interpret the weights

# iterate over the coefficients
weights = lr_clf.coef_.T # take transpose to make a column vector
variable_names = crime.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
# Out:
# Duration has weight of 0.23723503712943825
# Duration_to_PD has weight of 0.0003639938392425779
# Day has weight of -0.0007920053020342152
# Year has weight of 0.0003939936787417367
# GeoCell has weight of -0.0010243052372681497
# GeoCell_X has weight of -0.03934345292439216
# GeoCell_Y has weight of 0.004507450251383783
# JURIS_DESC_AMTRACK has weight of 0.0007610392584423392
# JURIS_DESC_DEPT OF CORRECTIONS has weight of 0.04502262865765401
# JURIS_DESC_HEALTH & HOSP CORP has weight of -0.06123482628437647
# JURIS_DESC_LONG ISLAND RAILRD has weight of 0.0015239482669734948
# JURIS_DESC_METRO NORTH has weight of 0.0007512677488130376
# JURIS_DESC_N.Y. HOUSING POLICE has weight of -0.34302747761955077
# JURIS_DESC_N.Y. POLICE DEPT has weight of 0.18166737968813748
# JURIS_DESC_N.Y. STATE PARKS has weight of 0.000741139759012025
# JURIS_DESC_N.Y. STATE POLICE has weight of 0.04098292216470679
# JURIS_DESC_N.Y. TRANSIT POLICE has weight of 0.0014039053864163356
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE has weight of 0.000836274168889651
# JURIS_DESC_NYC PARKS has weight of 0.001468771971490385
# JURIS_DESC_NYS DEPT TAX AND FINANCE has weight of 0.00169899718123381
# JURIS_DESC_OTHER has weight of 0.10099563904701873
# JURIS_DESC_POLICE DEPT NYC has weight of -0.0006564745460265776
# JURIS_DESC_PORT AUTHORITY has weight of -0.0013040847953560523
# JURIS_DESC_STATN IS RAPID TRANS has weight of 0.00036447665130700315
# JURIS_DESC_TRI-BORO BRDG TUNNL has weight of 0.02829420481500982
# JURIS_DESC_U.S. PARK POLICE has weight of 0.00038580395148086555
# BORO_NM_BRONX has weight of -0.015141914844601376
# BORO_NM_BROOKLYN has weight of 0.011432814297272203
# BORO_NM_MANHATTAN has weight of 0.23323430637642634
# BORO_NM_QUEENS has weight of 0.039052996601042264
# BORO_NM_STATEN ISLAND has weight of -0.26790266695832676
# LOC_OF_OCCUR_DESC_FRONT OF has weight of -0.3850259775089619
# LOC_OF_OCCUR_DESC_INSIDE has weight of -0.48868553755007477
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.40285040871852773
# LOC_OF_OCCUR_DESC_REAR OF has weight of 0.47153664181263516
# ADDR_PCT_CD_1.0 has weight of 0.12676729091299563
# ADDR_PCT_CD_5.0 has weight of 0.013753155327016337
# ADDR_PCT_CD_6.0 has weight of 0.1537798126279993
# ADDR_PCT_CD_7.0 has weight of -0.08904256715605993
# ADDR_PCT_CD_9.0 has weight of 0.13849572258035203
# ADDR_PCT_CD_10.0 has weight of 0.06873761344081879
# ADDR_PCT_CD_13.0 has weight of 0.13389422038243598
# ADDR_PCT_CD_14.0 has weight of 0.24298547360375786
# ADDR_PCT_CD_17.0 has weight of 0.035980961520382965
# ADDR_PCT_CD_18.0 has weight of -0.02274936961227749
# ADDR_PCT_CD_19.0 has weight of 0.3136425983234114
# ADDR_PCT_CD_20.0 has weight of 0.0371884610502573
# ADDR_PCT_CD_22.0 has weight of 0.00031169239922094783
# ADDR_PCT_CD_23.0 has weight of -0.07259858330616964
# ADDR_PCT_CD_24.0 has weight of -0.02678619108976894
# ADDR_PCT_CD_25.0 has weight of -0.02024239219585826
# ADDR_PCT_CD_26.0 has weight of -0.030708831826442094
# ADDR_PCT_CD_28.0 has weight of -0.03411726089441292
# ADDR_PCT_CD_30.0 has weight of -0.23088444007514608
# ADDR_PCT_CD_32.0 has weight of -0.1666483983706107
# ADDR_PCT_CD_33.0 has weight of -0.12744903206926164
# ADDR_PCT_CD_34.0 has weight of -0.21107562919616832
# ADDR_PCT_CD_40.0 has weight of 0.10156508981424453
# ADDR_PCT_CD_41.0 has weight of -0.03927359263754295
# ADDR_PCT_CD_42.0 has weight of -0.10505692011715231
# ADDR_PCT_CD_43.0 has weight of 0.02833429326824909
# ADDR_PCT_CD_44.0 has weight of -0.1411973175200062
# ADDR_PCT_CD_45.0 has weight of -0.004136382364155984
# ADDR_PCT_CD_46.0 has weight of -0.07685645027994871
# ADDR_PCT_CD_47.0 has weight of -0.06638092066886167
# ADDR_PCT_CD_48.0 has weight of -0.004370606917258692
# ADDR_PCT_CD_49.0 has weight of 0.08673744245936132
# ADDR_PCT_CD_50.0 has weight of 0.06440335971753983
# ADDR_PCT_CD_52.0 has weight of 0.14109009040091466
# ADDR_PCT_CD_60.0 has weight of -0.06583521256603511
# ADDR_PCT_CD_61.0 has weight of 0.1383648657308065
# ADDR_PCT_CD_62.0 has weight of -0.023332566962605873
# ADDR_PCT_CD_63.0 has weight of 0.0003234342888434472
# ADDR_PCT_CD_66.0 has weight of 0.07899675306161288
# ADDR_PCT_CD_67.0 has weight of -0.29172493969125785
# ADDR_PCT_CD_68.0 has weight of 0.006950153598713973
# ADDR_PCT_CD_69.0 has weight of -0.1447624611691037
# ADDR_PCT_CD_70.0 has weight of 0.02835263082373717
# ADDR_PCT_CD_71.0 has weight of -0.033357466392928775
# ADDR_PCT_CD_72.0 has weight of -0.08508520366463217
# ADDR_PCT_CD_73.0 has weight of -0.15053239293045914
# ADDR_PCT_CD_75.0 has weight of -0.10599311778052632
# ADDR_PCT_CD_76.0 has weight of 0.04278180753097646
# ADDR_PCT_CD_77.0 has weight of -0.04901115254443077
# ADDR_PCT_CD_78.0 has weight of 0.16538812193140565
# ADDR_PCT_CD_79.0 has weight of -0.07317310224540759
# ADDR_PCT_CD_81.0 has weight of -0.04632624817925173
# ADDR_PCT_CD_83.0 has weight of 0.08735041229588619
# ADDR_PCT_CD_84.0 has weight of 0.09783089028778962
# ADDR_PCT_CD_88.0 has weight of 0.03290188573323834
# ADDR_PCT_CD_90.0 has weight of 0.25934198959995947
# ADDR_PCT_CD_94.0 has weight of 0.1415320691499292
# ADDR_PCT_CD_100.0 has weight of -0.0028741162905131894
# ADDR_PCT_CD_101.0 has weight of -0.06523929273164616
# ADDR_PCT_CD_102.0 has weight of -0.08802050209675252
# ADDR_PCT_CD_103.0 has weight of -0.1067578611902504
# ADDR_PCT_CD_104.0 has weight of -0.02944885026867275
# ADDR_PCT_CD_105.0 has weight of -0.06179718959658309
# ADDR_PCT_CD_106.0 has weight of 0.09249607869282718
# ADDR_PCT_CD_107.0 has weight of 0.07786776130295943
# ADDR_PCT_CD_108.0 has weight of -0.08671391570667253
# ADDR_PCT_CD_109.0 has weight of 0.07132015912790152
# ADDR_PCT_CD_110.0 has weight of 0.05465670487437698
# ADDR_PCT_CD_111.0 has weight of 0.12248517545368606
# ADDR_PCT_CD_112.0 has weight of 0.1955552322683468
# ADDR_PCT_CD_113.0 has weight of 0.009125794934364582
# ADDR_PCT_CD_114.0 has weight of -0.10269593706027956
# ADDR_PCT_CD_115.0 has weight of -0.04045458072105156
# ADDR_PCT_CD_120.0 has weight of -0.1690598813574858
# ADDR_PCT_CD_121.0 has weight of -0.0188775265211634
# ADDR_PCT_CD_122.0 has weight of -0.0041350850690729385
# ADDR_PCT_CD_123.0 has weight of -0.07583017401059348
# PREM_TYP_DESC_ABANDONED BUILDING has weight of 0.023969671716495118
# PREM_TYP_DESC_AIRPORT TERMINAL has weight of 7.575453443680043e-05
# PREM_TYP_DESC_ATM has weight of 0.08088381233080941
# PREM_TYP_DESC_BANK has weight of 0.22878546295226573
# PREM_TYP_DESC_BAR/NIGHT CLUB has weight of -0.40077150587405463
# PREM_TYP_DESC_BEAUTY & NAIL SALON has weight of -0.09095033374933678
# PREM_TYP_DESC_BOOK/CARD has weight of 0.018696669269630387
# PREM_TYP_DESC_BRIDGE has weight of 0.025569287987598718
# PREM_TYP_DESC_BUS (NYC TRANSIT) has weight of -0.05140148274503402
# PREM_TYP_DESC_BUS (OTHER) has weight of -0.025386047086440953
# PREM_TYP_DESC_BUS STOP has weight of -0.004639969616746667
# PREM_TYP_DESC_BUS TERMINAL has weight of -0.011230051821041549
# PREM_TYP_DESC_CANDY STORE has weight of -0.03428746760511824
# PREM_TYP_DESC_CEMETERY has weight of 0.0006969378436710615
# PREM_TYP_DESC_CHAIN STORE has weight of 1.1386008601205253
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of 0.0965409360452267
# PREM_TYP_DESC_CHURCH has weight of 0.005085480862754745
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of 0.7149611584690632
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of 0.08103644236116438
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of 0.03252517002914398
# PREM_TYP_DESC_DEPARTMENT STORE has weight of 1.3837999156761631
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE has weight of -0.0806716664806749
# PREM_TYP_DESC_DRUG STORE has weight of 0.773889142973445
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY has weight of 0.03348321577485429
# PREM_TYP_DESC_FACTORY/WAREHOUSE has weight of -0.018069551557457104
# PREM_TYP_DESC_FAST FOOD has weight of -0.06009234969875614
# PREM_TYP_DESC_FERRY/FERRY TERMINAL has weight of -0.034927142987220126
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of 0.4458272125596713
# PREM_TYP_DESC_GAS STATION has weight of 0.06838872696438823
# PREM_TYP_DESC_GROCERY/BODEGA has weight of -0.17804457449360986
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of 0.2638947289518417
# PREM_TYP_DESC_HIGHWAY/PARKWAY has weight of 0.007306156610827624
# PREM_TYP_DESC_HOSPITAL has weight of -0.39469108789435225
# PREM_TYP_DESC_HOTEL/MOTEL has weight of -0.1599989136165548
# PREM_TYP_DESC_JEWELRY has weight of 0.04983801903106095
# PREM_TYP_DESC_LIQUOR STORE has weight of 0.06701213047104317
# PREM_TYP_DESC_LOAN COMPANY has weight of 0.00168624766703045
# PREM_TYP_DESC_MARINA/PIER has weight of 0.003045542921282564
# PREM_TYP_DESC_MOSQUE has weight of -0.0034769387837930194
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS) has weight of 0.007620341179846932
# PREM_TYP_DESC_OTHER has weight of -0.5603384391601184
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP has weight of -0.0057110249012008035
# PREM_TYP_DESC_PARK/PLAYGROUND has weight of -0.08339737856795915
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of 0.12815612652213726
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of 0.12460104265181181
# PREM_TYP_DESC_PHOTO/COPY has weight of 0.010689833550191328
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL has weight of -0.051941251396197055
# PREM_TYP_DESC_PUBLIC BUILDING has weight of -0.17503608436748042
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of -1.0538245810903957
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of -1.1567782542431044
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of -0.38423062216542375
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of -0.9724197099613473
# PREM_TYP_DESC_RESTAURANT/DINER has weight of -0.02850477630232845
# PREM_TYP_DESC_SHOE has weight of 0.05835880808867369
# PREM_TYP_DESC_SMALL MERCHANT has weight of 0.11116565794411046
# PREM_TYP_DESC_SOCIAL CLUB/POLICY has weight of -0.03954761714652576
# PREM_TYP_DESC_STORAGE FACILITY has weight of 0.018483958749251145
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of 0.1450697297671668
# PREM_TYP_DESC_STREET has weight of -0.3991973302223064
# PREM_TYP_DESC_SYNAGOGUE has weight of -0.003121155735307039
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of 0.037112751785902676
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of 0.03763138462535779
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED) has weight of 0.00276644915123026
# PREM_TYP_DESC_TELECOMM. STORE has weight of 0.1291411095880357
# PREM_TYP_DESC_TRAMWAY has weight of 0.0005380953343289699
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY has weight of 0.0007593635280380035
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER) has weight of 0.012644605981283565
# PREM_TYP_DESC_TUNNEL has weight of 0.006006982628599164
# PREM_TYP_DESC_VARIETY STORE has weight of 0.07890119421986545
# PREM_TYP_DESC_VIDEO STORE has weight of 0.008116725321475544
# Day_Name_Friday has weight of 0.04332151569681308
# Day_Name_Monday has weight of 0.00839724046201245
# Day_Name_Saturday has weight of -0.05374213075117127
# Day_Name_Sunday has weight of -0.16921955192735705
# Day_Name_Thursday has weight of 0.04053667630798483
# Day_Name_Tuesday has weight of 0.0681710227926775
# Day_Name_Wednesday has weight of 0.06321076289095229
# Month_April has weight of 0.03772838016349065
# Month_August has weight of 0.017833902001159516
# Month_December has weight of 0.0004610489945496006
# Month_February has weight of 0.006551884263990067
# Month_January has weight of 0.036625192122797814
# Month_July has weight of -0.045395476155338794
# Month_June has weight of -0.030354714503150304
# Month_March has weight of 0.04214759955234534
# Month_May has weight of -0.07671902579286892
# Month_November has weight of 0.03102192268195416
# Month_October has weight of 0.0009571185810700258
# Month_September has weight of -0.02018229643814234
# Duration_lbl_Long has weight of -1.1636241511519272
# Duration_lbl_Medium has weight of 0.6589647721322507
# Duration_lbl_Short has weight of 0.5053349144902758
# Season_Fall has weight of 0.011796744824898987
# Season_Spring has weight of 0.0031569539228733404
# Season_Summer has weight of -0.05791628865716683
# Season_Winter has weight of 0.043638125381315035
# Daytime_Day has weight of 0.13697810240364466
# Daytime_Early Morning has weight of -0.10401139430962815
# Daytime_Evening has weight of 0.055171752864379996
# Daytime_Late Night has weight of -0.09368036714682634
# Daytime_Morning has weight of 0.042807093841764995
# Daytime_Night has weight of -0.03658965218146022

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,crime.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.7319057232174039
# [[16997 19292]
#  [12182 68928]]
# Duration_lbl_Long has weight of -0.7417050180329785
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of -0.33417274657646767
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of -0.17985499904151295
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of -0.1560143669973719
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of -0.11864784917926524
# LOC_OF_OCCUR_DESC_INSIDE has weight of -0.09276692282830115
# Day_Name_Sunday has weight of -0.05805316149414534
# PREM_TYP_DESC_HOSPITAL has weight of -0.04757638455282302
# PREM_TYP_DESC_OTHER has weight of -0.04729320942238653
# GeoCell_X has weight of -0.045963093808885955
# Year has weight of -0.04514969505032638
# ADDR_PCT_CD_67.0 has weight of -0.04317752281423905
# BORO_NM_STATEN ISLAND has weight of -0.03245791188257343
# ADDR_PCT_CD_30.0 has weight of -0.027868565087888764
# ADDR_PCT_CD_69.0 has weight of -0.027635905954379255
# ADDR_PCT_CD_120.0 has weight of -0.02689392012729744
# ADDR_PCT_CD_34.0 has weight of -0.026186161819010276
# Daytime_Late Night has weight of -0.02425827714549606
# ADDR_PCT_CD_73.0 has weight of -0.023482007319831504
# ADDR_PCT_CD_75.0 has weight of -0.02330727421131642
# PREM_TYP_DESC_BAR/NIGHT CLUB has weight of -0.022224438062344146
# BORO_NM_BRONX has weight of -0.022060933347101526
# ADDR_PCT_CD_44.0 has weight of -0.02205267377045447
# Daytime_Night has weight of -0.02204583455485637
# Month_May has weight of -0.022004925920666097
# ADDR_PCT_CD_121.0 has weight of -0.020989658103178786
# Daytime_Early Morning has weight of -0.019958386098503655
# Season_Summer has weight of -0.018795818031984473
# Day_Name_Saturday has weight of -0.018704487197866205
# ADDR_PCT_CD_45.0 has weight of -0.018506588708678436
# Month_July has weight of -0.017489277905928916
# ADDR_PCT_CD_41.0 has weight of -0.01732088872479386
# JURIS_DESC_HEALTH & HOSP CORP has weight of -0.017315866812055172
# ADDR_PCT_CD_42.0 has weight of -0.017107391236425653
# PREM_TYP_DESC_BUS (NYC TRANSIT) has weight of -0.01686906205763161
# ADDR_PCT_CD_103.0 has weight of -0.016435206351446453
# ADDR_PCT_CD_47.0 has weight of -0.01639870172999278
# ADDR_PCT_CD_102.0 has weight of -0.013727367025415577
# LOC_OF_OCCUR_DESC_FRONT OF has weight of -0.01365816355071995
# ADDR_PCT_CD_46.0 has weight of -0.013640175600443744
# ADDR_PCT_CD_32.0 has weight of -0.013610989978180183
# ADDR_PCT_CD_79.0 has weight of -0.013507111712726613
# JURIS_DESC_PORT AUTHORITY has weight of -0.01314088445970914
# PREM_TYP_DESC_BUS (OTHER) has weight of -0.012562656254771196
# Month_June has weight of -0.01193618684005151
# ADDR_PCT_CD_114.0 has weight of -0.011348293756009237
# BORO_NM_QUEENS has weight of -0.011235953291235785
# ADDR_PCT_CD_33.0 has weight of -0.011061852092100003
# ADDR_PCT_CD_108.0 has weight of -0.011040215181010012
# ADDR_PCT_CD_72.0 has weight of -0.010703350945546216
# ADDR_PCT_CD_123.0 has weight of -0.01038336059844101
# JURIS_DESC_N.Y. POLICE DEPT has weight of -0.009950879995577236
# PREM_TYP_DESC_HOTEL/MOTEL has weight of -0.009448452043668013
# ADDR_PCT_CD_104.0 has weight of -0.008955486738772521
# PREM_TYP_DESC_FERRY/FERRY TERMINAL has weight of -0.008846808573152651
# PREM_TYP_DESC_PARK/PLAYGROUND has weight of -0.008251332174285456
# PREM_TYP_DESC_SOCIAL CLUB/POLICY has weight of -0.008156625413191036
# Day has weight of -0.007730497000425701
# ADDR_PCT_CD_28.0 has weight of -0.007413333268207441
# PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL has weight of -0.007039671662143877
# ADDR_PCT_CD_62.0 has weight of -0.006748077346164127
# ADDR_PCT_CD_105.0 has weight of -0.0066713899669544555
# ADDR_PCT_CD_60.0 has weight of -0.006384383591191749
# BORO_NM_BROOKLYN has weight of -0.0063452862639878475
# ADDR_PCT_CD_101.0 has weight of -0.006081158916176303
# ADDR_PCT_CD_63.0 has weight of -0.005913687914236713
# ADDR_PCT_CD_24.0 has weight of -0.005361610185314932
# ADDR_PCT_CD_77.0 has weight of -0.004948316622802869
# ADDR_PCT_CD_7.0 has weight of -0.004835644491561425
# JURIS_DESC_AMTRACK has weight of -0.0047163506027175705
# JURIS_DESC_POLICE DEPT NYC has weight of -0.0046424945519000435
# ADDR_PCT_CD_81.0 has weight of -0.004544854984095058
# Month_September has weight of -0.004275381220392429
# PREM_TYP_DESC_PUBLIC BUILDING has weight of -0.004119460823724632
# ADDR_PCT_CD_43.0 has weight of -0.004031893822677871
# ADDR_PCT_CD_115.0 has weight of -0.003875401195418368
# ADDR_PCT_CD_68.0 has weight of -0.003725770469045333
# JURIS_DESC_METRO NORTH has weight of -0.002628623369456802
# PREM_TYP_DESC_OTHER HOUSE OF WORSHIP has weight of -0.0025483095895761708
# ADDR_PCT_CD_110.0 has weight of -0.001910892280441046
# PREM_TYP_DESC_DOCTOR/DENTIST OFFICE has weight of -0.0015662854604792205
# ADDR_PCT_CD_113.0 has weight of -0.0009748919598825459
# Day_Name_Monday has weight of -0.0009482058030310242
# Month_December has weight of -0.0007464844714662167
# JURIS_DESC_U.S. PARK POLICE has weight of -0.0007290799016725226
# ADDR_PCT_CD_100.0 has weight of -0.0004914587932076031
# ADDR_PCT_CD_122.0 has weight of -0.000417693845078343
# Month_August has weight of -0.0001870047308002386
# JURIS_DESC_LONG ISLAND RAILRD has weight of 2.5396055803084984e-05
# PREM_TYP_DESC_AIRPORT TERMINAL has weight of 0.00014592387450752716
# PREM_TYP_DESC_CEMETERY has weight of 0.0001795139978845092
# PREM_TYP_DESC_SYNAGOGUE has weight of 0.0002512291377096367
# ADDR_PCT_CD_48.0 has weight of 0.0002924730989575395
# ADDR_PCT_CD_71.0 has weight of 0.00030434410263501476
# ADDR_PCT_CD_18.0 has weight of 0.00032805194724488354
# PREM_TYP_DESC_BUS STOP has weight of 0.0006707140457667167
# Season_Spring has weight of 0.0011271528586982607
# ADDR_PCT_CD_70.0 has weight of 0.0011405213956308233
# ADDR_PCT_CD_23.0 has weight of 0.0012618573971902042
# JURIS_DESC_N.Y. STATE PARKS has weight of 0.0015103360739278581
# PREM_TYP_DESC_MOSQUE has weight of 0.0018198415113669243
# GeoCell has weight of 0.002939959965980245
# PREM_TYP_DESC_TUNNEL has weight of 0.0031216627273615285
# JURIS_DESC_N.Y. TRANSIT POLICE has weight of 0.003207567273385852
# Daytime_Morning has weight of 0.0035310834618071676
# JURIS_DESC_N.Y. HOUSING POLICE has weight of 0.003576994538747639
# ADDR_PCT_CD_26.0 has weight of 0.003726497250896077
# JURIS_DESC_NEW YORK CITY SHERIFF OFFICE has weight of 0.00402264113722721
# PREM_TYP_DESC_BEAUTY & NAIL SALON has weight of 0.004101328548791783
# Month_November has weight of 0.0041976983297289635
# Season_Fall has weight of 0.004592959969062677
# ADDR_PCT_CD_109.0 has weight of 0.004615704596931036
# ADDR_PCT_CD_84.0 has weight of 0.004775030034511171
# PREM_TYP_DESC_STREET has weight of 0.004919346785458866
# ADDR_PCT_CD_88.0 has weight of 0.005628267217498337
# ADDR_PCT_CD_49.0 has weight of 0.005747054993283909
# PREM_TYP_DESC_CANDY STORE has weight of 0.005770729865674043
# ADDR_PCT_CD_25.0 has weight of 0.006064710155573218
# ADDR_PCT_CD_22.0 has weight of 0.006239923028878568
# JURIS_DESC_NYC PARKS has weight of 0.006335627662002953
# GeoCell_Y has weight of 0.00634258846632059
# ADDR_PCT_CD_5.0 has weight of 0.0065713680300382585
# ADDR_PCT_CD_50.0 has weight of 0.0067714012651962675
# ADDR_PCT_CD_20.0 has weight of 0.006785752180024938
# Month_October has weight of 0.00686317968353365
# PREM_TYP_DESC_MARINA/PIER has weight of 0.0074835595722343995
# ADDR_PCT_CD_76.0 has weight of 0.007791535371950249
# PREM_TYP_DESC_BUS TERMINAL has weight of 0.008224937266229993
# PREM_TYP_DESC_OPEN AREAS (OPEN LOTS) has weight of 0.00872708641914118
# PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED) has weight of 0.008804295774526604
# PREM_TYP_DESC_LOAN COMPANY has weight of 0.008970478266318785
# PREM_TYP_DESC_FACTORY/WAREHOUSE has weight of 0.009164941345124543
# Month_April has weight of 0.009822645012032742
# JURIS_DESC_STATN IS RAPID TRANS has weight of 0.01053386916617309
# Month_February has weight of 0.010674226734853898
# ADDR_PCT_CD_40.0 has weight of 0.011185791963537313
# ADDR_PCT_CD_83.0 has weight of 0.011880802994959399
# Month_January has weight of 0.012581063622647668
# ADDR_PCT_CD_107.0 has weight of 0.01258329282042732
# JURIS_DESC_N.Y. STATE POLICE has weight of 0.012753756372287843
# Season_Winter has weight of 0.013032272577656785
# Daytime_Evening has weight of 0.013101754938839288
# PREM_TYP_DESC_VIDEO STORE has weight of 0.013824331974165898
# ADDR_PCT_CD_106.0 has weight of 0.014034985685004947
# PREM_TYP_DESC_CHURCH has weight of 0.014118788178711756
# PREM_TYP_DESC_TRANSIT FACILITY (OTHER) has weight of 0.01441868863057243
# ADDR_PCT_CD_52.0 has weight of 0.014784283381786724
# PREM_TYP_DESC_TRAMWAY has weight of 0.014955784644858118
# Day_Name_Friday has weight of 0.014956413189778823
# Month_March has weight of 0.014970121797628999
# PREM_TYP_DESC_TRANSIT - NYC SUBWAY has weight of 0.01578502638597614
# ADDR_PCT_CD_66.0 has weight of 0.016153360617171562
# PREM_TYP_DESC_HIGHWAY/PARKWAY has weight of 0.01650618006642409
# ADDR_PCT_CD_17.0 has weight of 0.016649351715716673
# Day_Name_Thursday has weight of 0.016921762210960825
# JURIS_DESC_TRI-BORO BRDG TUNNL has weight of 0.017781582379644913
# PREM_TYP_DESC_PHOTO/COPY has weight of 0.01794912681839177
# JURIS_DESC_DEPT OF CORRECTIONS has weight of 0.018552900681042987
# ADDR_PCT_CD_61.0 has weight of 0.0189380098839843
# ADDR_PCT_CD_1.0 has weight of 0.019112919355850938
# PREM_TYP_DESC_FAST FOOD has weight of 0.020540038254293104
# PREM_TYP_DESC_BOOK/CARD has weight of 0.02060060909012005
# Day_Name_Wednesday has weight of 0.021675901643155256
# ADDR_PCT_CD_112.0 has weight of 0.022425672443928294
# Day_Name_Tuesday has weight of 0.022642969018121798
# JURIS_DESC_OTHER has weight of 0.022706481104034133
# ADDR_PCT_CD_111.0 has weight of 0.024359313160542823
# PREM_TYP_DESC_STORAGE FACILITY has weight of 0.02464457296655087
# ADDR_PCT_CD_10.0 has weight of 0.024917748563379173
# PREM_TYP_DESC_DRY CLEANER/LAUNDRY has weight of 0.02517757293787595
# JURIS_DESC_NYS DEPT TAX AND FINANCE has weight of 0.025680207407391027
# ADDR_PCT_CD_78.0 has weight of 0.026793025479247487
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of 0.026979732756603016
# PREM_TYP_DESC_GROCERY/BODEGA has weight of 0.026995897604946046
# ADDR_PCT_CD_94.0 has weight of 0.027911917463566662
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of 0.029348983120074244
# PREM_TYP_DESC_BRIDGE has weight of 0.02959338248863187
# ADDR_PCT_CD_13.0 has weight of 0.03237250346966926
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of 0.032624038038808645
# PREM_TYP_DESC_JEWELRY has weight of 0.03344353457939194
# PREM_TYP_DESC_GAS STATION has weight of 0.034619067715288464
# ADDR_PCT_CD_9.0 has weight of 0.034994539079293965
# ADDR_PCT_CD_6.0 has weight of 0.03712417125331059
# PREM_TYP_DESC_ABANDONED BUILDING has weight of 0.037202325129301925
# PREM_TYP_DESC_RESTAURANT/DINER has weight of 0.04001640257717657
# Daytime_Day has weight of 0.040143365001552654
# PREM_TYP_DESC_LIQUOR STORE has weight of 0.04181647577570231
# ADDR_PCT_CD_14.0 has weight of 0.042368830498782206
# ADDR_PCT_CD_90.0 has weight of 0.04588977972913385
# PREM_TYP_DESC_VARIETY STORE has weight of 0.04602925919890901
# PREM_TYP_DESC_SHOE has weight of 0.048114894149425505
# PREM_TYP_DESC_SMALL MERCHANT has weight of 0.050675844288918005
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of 0.05174330848941399
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of 0.053789045959037975
# BORO_NM_MANHATTAN has weight of 0.05456774648611206
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of 0.05596899546005569
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of 0.06082740370109166
# ADDR_PCT_CD_19.0 has weight of 0.061086843855357134
# PREM_TYP_DESC_TELECOMM. STORE has weight of 0.06598413910084412
# Duration_lbl_Medium has weight of 0.0690959320796534
# Duration_to_PD has weight of 0.07907107302163037
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of 0.08195429407780952
# PREM_TYP_DESC_ATM has weight of 0.09293135940520653
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of 0.0972730569102036
# PREM_TYP_DESC_BANK has weight of 0.10102412292500107
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of 0.13387018787078697
# LOC_OF_OCCUR_DESC_REAR OF has weight of 0.14131194095883498
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.14398509222680286
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of 0.24132057496017462
# PREM_TYP_DESC_DRUG STORE has weight of 0.2415613060475333
# PREM_TYP_DESC_CHAIN STORE has weight of 0.3282419636541516
# Duration_lbl_Short has weight of 0.4216033348042898
# PREM_TYP_DESC_DEPARTMENT STORE has weight of 0.44159995448165545
# Duration has weight of 1.891262299094946

# %%
# now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=crime.columns)
weights.plot(kind='bar')
plt.show()

# %%
# now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=crime.columns)
weights.plot(kind='bar')
plt.show()

# %%
zip_vars
# Out:
# [(array([-0.74170502]), 'Duration_lbl_Long'),
#  (array([-0.33417275]), 'PREM_TYP_DESC_RESIDENCE - APT. HOUSE'),
#  (array([-0.179855]), 'PREM_TYP_DESC_RESIDENCE-HOUSE'),
#  (array([-0.15601437]), 'PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING'),
#  (array([-0.11864785]), 'PREM_TYP_DESC_PUBLIC SCHOOL'),
#  (array([-0.09276692]), 'LOC_OF_OCCUR_DESC_INSIDE'),
#  (array([-0.05805316]), 'Day_Name_Sunday'),
#  (array([-0.04757638]), 'PREM_TYP_DESC_HOSPITAL'),
#  (array([-0.04729321]), 'PREM_TYP_DESC_OTHER'),
#  (array([-0.04596309]), 'GeoCell_X'),
#  (array([-0.0451497]), 'Year'),
#  (array([-0.04317752]), 'ADDR_PCT_CD_67.0'),
#  (array([-0.03245791]), 'BORO_NM_STATEN ISLAND'),
#  (array([-0.02786857]), 'ADDR_PCT_CD_30.0'),
#  (array([-0.02763591]), 'ADDR_PCT_CD_69.0'),
#  (array([-0.02689392]), 'ADDR_PCT_CD_120.0'),
#  (array([-0.02618616]), 'ADDR_PCT_CD_34.0'),
#  (array([-0.02425828]), 'Daytime_Late Night'),
#  (array([-0.02348201]), 'ADDR_PCT_CD_73.0'),
#  (array([-0.02330727]), 'ADDR_PCT_CD_75.0'),
#  (array([-0.02222444]), 'PREM_TYP_DESC_BAR/NIGHT CLUB'),
#  (array([-0.02206093]), 'BORO_NM_BRONX'),
#  (array([-0.02205267]), 'ADDR_PCT_CD_44.0'),
#  (array([-0.02204583]), 'Daytime_Night'),
#  (array([-0.02200493]), 'Month_May'),
#  (array([-0.02098966]), 'ADDR_PCT_CD_121.0'),
#  (array([-0.01995839]), 'Daytime_Early Morning'),
#  (array([-0.01879582]), 'Season_Summer'),
#  (array([-0.01870449]), 'Day_Name_Saturday'),
#  (array([-0.01850659]), 'ADDR_PCT_CD_45.0'),
#  (array([-0.01748928]), 'Month_July'),
#  (array([-0.01732089]), 'ADDR_PCT_CD_41.0'),
#  (array([-0.01731587]), 'JURIS_DESC_HEALTH & HOSP CORP'),
#  (array([-0.01710739]), 'ADDR_PCT_CD_42.0'),
#  (array([-0.01686906]), 'PREM_TYP_DESC_BUS (NYC TRANSIT)'),
#  (array([-0.01643521]), 'ADDR_PCT_CD_103.0'),
#  (array([-0.0163987]), 'ADDR_PCT_CD_47.0'),
#  (array([-0.01372737]), 'ADDR_PCT_CD_102.0'),
#  (array([-0.01365816]), 'LOC_OF_OCCUR_DESC_FRONT OF'),
#  (array([-0.01364018]), 'ADDR_PCT_CD_46.0'),
#  (array([-0.01361099]), 'ADDR_PCT_CD_32.0'),
#  (array([-0.01350711]), 'ADDR_PCT_CD_79.0'),
#  (array([-0.01314088]), 'JURIS_DESC_PORT AUTHORITY'),
#  (array([-0.01256266]), 'PREM_TYP_DESC_BUS (OTHER)'),
#  (array([-0.01193619]), 'Month_June'),
#  (array([-0.01134829]), 'ADDR_PCT_CD_114.0'),
#  (array([-0.01123595]), 'BORO_NM_QUEENS'),
#  (array([-0.01106185]), 'ADDR_PCT_CD_33.0'),
#  (array([-0.01104022]), 'ADDR_PCT_CD_108.0'),
#  (array([-0.01070335]), 'ADDR_PCT_CD_72.0'),
#  (array([-0.01038336]), 'ADDR_PCT_CD_123.0'),
#  (array([-0.00995088]), 'JURIS_DESC_N.Y. POLICE DEPT'),
#  (array([-0.00944845]), 'PREM_TYP_DESC_HOTEL/MOTEL'),
#  (array([-0.00895549]), 'ADDR_PCT_CD_104.0'),
#  (array([-0.00884681]), 'PREM_TYP_DESC_FERRY/FERRY TERMINAL'),
#  (array([-0.00825133]), 'PREM_TYP_DESC_PARK/PLAYGROUND'),
#  (array([-0.00815663]), 'PREM_TYP_DESC_SOCIAL CLUB/POLICY'),
#  (array([-0.0077305]), 'Day'),
#  (array([-0.00741333]), 'ADDR_PCT_CD_28.0'),
#  (array([-0.00703967]), 'PREM_TYP_DESC_PRIVATE/PAROCHIAL SCHOOL'),
#  (array([-0.00674808]), 'ADDR_PCT_CD_62.0'),
#  (array([-0.00667139]), 'ADDR_PCT_CD_105.0'),
#  (array([-0.00638438]), 'ADDR_PCT_CD_60.0'),
#  (array([-0.00634529]), 'BORO_NM_BROOKLYN'),
#  (array([-0.00608116]), 'ADDR_PCT_CD_101.0'),
#  (array([-0.00591369]), 'ADDR_PCT_CD_63.0'),
#  (array([-0.00536161]), 'ADDR_PCT_CD_24.0'),
#  (array([-0.00494832]), 'ADDR_PCT_CD_77.0'),
#  (array([-0.00483564]), 'ADDR_PCT_CD_7.0'),
#  (array([-0.00471635]), 'JURIS_DESC_AMTRACK'),
#  (array([-0.00464249]), 'JURIS_DESC_POLICE DEPT NYC'),
#  (array([-0.00454485]), 'ADDR_PCT_CD_81.0'),
#  (array([-0.00427538]), 'Month_September'),
#  (array([-0.00411946]), 'PREM_TYP_DESC_PUBLIC BUILDING'),
#  (array([-0.00403189]), 'ADDR_PCT_CD_43.0'),
#  (array([-0.0038754]), 'ADDR_PCT_CD_115.0'),
#  (array([-0.00372577]), 'ADDR_PCT_CD_68.0'),
#  (array([-0.00262862]), 'JURIS_DESC_METRO NORTH'),
#  (array([-0.00254831]), 'PREM_TYP_DESC_OTHER HOUSE OF WORSHIP'),
#  (array([-0.00191089]), 'ADDR_PCT_CD_110.0'),
#  (array([-0.00156629]), 'PREM_TYP_DESC_DOCTOR/DENTIST OFFICE'),
#  (array([-0.00097489]), 'ADDR_PCT_CD_113.0'),
#  (array([-0.00094821]), 'Day_Name_Monday'),
#  (array([-0.00074648]), 'Month_December'),
#  (array([-0.00072908]), 'JURIS_DESC_U.S. PARK POLICE'),
#  (array([-0.00049146]), 'ADDR_PCT_CD_100.0'),
#  (array([-0.00041769]), 'ADDR_PCT_CD_122.0'),
#  (array([-0.000187]), 'Month_August'),
#  (array([2.53960558e-05]), 'JURIS_DESC_LONG ISLAND RAILRD'),
#  (array([0.00014592]), 'PREM_TYP_DESC_AIRPORT TERMINAL'),
#  (array([0.00017951]), 'PREM_TYP_DESC_CEMETERY'),
#  (array([0.00025123]), 'PREM_TYP_DESC_SYNAGOGUE'),
#  (array([0.00029247]), 'ADDR_PCT_CD_48.0'),
#  (array([0.00030434]), 'ADDR_PCT_CD_71.0'),
#  (array([0.00032805]), 'ADDR_PCT_CD_18.0'),
#  (array([0.00067071]), 'PREM_TYP_DESC_BUS STOP'),
#  (array([0.00112715]), 'Season_Spring'),
#  (array([0.00114052]), 'ADDR_PCT_CD_70.0'),
#  (array([0.00126186]), 'ADDR_PCT_CD_23.0'),
#  (array([0.00151034]), 'JURIS_DESC_N.Y. STATE PARKS'),
#  (array([0.00181984]), 'PREM_TYP_DESC_MOSQUE'),
#  (array([0.00293996]), 'GeoCell'),
#  (array([0.00312166]), 'PREM_TYP_DESC_TUNNEL'),
#  (array([0.00320757]), 'JURIS_DESC_N.Y. TRANSIT POLICE'),
#  (array([0.00353108]), 'Daytime_Morning'),
#  (array([0.00357699]), 'JURIS_DESC_N.Y. HOUSING POLICE'),
#  (array([0.0037265]), 'ADDR_PCT_CD_26.0'),
#  (array([0.00402264]), 'JURIS_DESC_NEW YORK CITY SHERIFF OFFICE'),
#  (array([0.00410133]), 'PREM_TYP_DESC_BEAUTY & NAIL SALON'),
#  (array([0.0041977]), 'Month_November'),
#  (array([0.00459296]), 'Season_Fall'),
#  (array([0.0046157]), 'ADDR_PCT_CD_109.0'),
#  (array([0.00477503]), 'ADDR_PCT_CD_84.0'),
#  (array([0.00491935]), 'PREM_TYP_DESC_STREET'),
#  (array([0.00562827]), 'ADDR_PCT_CD_88.0'),
#  (array([0.00574705]), 'ADDR_PCT_CD_49.0'),
#  (array([0.00577073]), 'PREM_TYP_DESC_CANDY STORE'),
#  (array([0.00606471]), 'ADDR_PCT_CD_25.0'),
#  (array([0.00623992]), 'ADDR_PCT_CD_22.0'),
#  (array([0.00633563]), 'JURIS_DESC_NYC PARKS'),
#  (array([0.00634259]), 'GeoCell_Y'),
#  (array([0.00657137]), 'ADDR_PCT_CD_5.0'),
#  (array([0.0067714]), 'ADDR_PCT_CD_50.0'),
#  (array([0.00678575]), 'ADDR_PCT_CD_20.0'),
#  (array([0.00686318]), 'Month_October'),
#  (array([0.00748356]), 'PREM_TYP_DESC_MARINA/PIER'),
#  (array([0.00779154]), 'ADDR_PCT_CD_76.0'),
#  (array([0.00822494]), 'PREM_TYP_DESC_BUS TERMINAL'),
#  (array([0.00872709]), 'PREM_TYP_DESC_OPEN AREAS (OPEN LOTS)'),
#  (array([0.0088043]), 'PREM_TYP_DESC_TAXI/LIVERY (UNLICENSED)'),
#  (array([0.00897048]), 'PREM_TYP_DESC_LOAN COMPANY'),
#  (array([0.00916494]), 'PREM_TYP_DESC_FACTORY/WAREHOUSE'),
#  (array([0.00982265]), 'Month_April'),
#  (array([0.01053387]), 'JURIS_DESC_STATN IS RAPID TRANS'),
#  (array([0.01067423]), 'Month_February'),
#  (array([0.01118579]), 'ADDR_PCT_CD_40.0'),
#  (array([0.0118808]), 'ADDR_PCT_CD_83.0'),
#  (array([0.01258106]), 'Month_January'),
#  (array([0.01258329]), 'ADDR_PCT_CD_107.0'),
#  (array([0.01275376]), 'JURIS_DESC_N.Y. STATE POLICE'),
#  (array([0.01303227]), 'Season_Winter'),
#  (array([0.01310175]), 'Daytime_Evening'),
#  (array([0.01382433]), 'PREM_TYP_DESC_VIDEO STORE'),
#  (array([0.01403499]), 'ADDR_PCT_CD_106.0'),
#  (array([0.01411879]), 'PREM_TYP_DESC_CHURCH'),
#  (array([0.01441869]), 'PREM_TYP_DESC_TRANSIT FACILITY (OTHER)'),
#  (array([0.01478428]), 'ADDR_PCT_CD_52.0'),
#  (array([0.01495578]), 'PREM_TYP_DESC_TRAMWAY'),
#  (array([0.01495641]), 'Day_Name_Friday'),
#  (array([0.01497012]), 'Month_March'),
#  (array([0.01578503]), 'PREM_TYP_DESC_TRANSIT - NYC SUBWAY'),
#  (array([0.01615336]), 'ADDR_PCT_CD_66.0'),
#  (array([0.01650618]), 'PREM_TYP_DESC_HIGHWAY/PARKWAY'),
#  (array([0.01664935]), 'ADDR_PCT_CD_17.0'),
#  (array([0.01692176]), 'Day_Name_Thursday'),
#  (array([0.01778158]), 'JURIS_DESC_TRI-BORO BRDG TUNNL'),
#  (array([0.01794913]), 'PREM_TYP_DESC_PHOTO/COPY'),
#  (array([0.0185529]), 'JURIS_DESC_DEPT OF CORRECTIONS'),
#  (array([0.01893801]), 'ADDR_PCT_CD_61.0'),
#  (array([0.01911292]), 'ADDR_PCT_CD_1.0'),
#  (array([0.02054004]), 'PREM_TYP_DESC_FAST FOOD'),
#  (array([0.02060061]), 'PREM_TYP_DESC_BOOK/CARD'),
#  (array([0.0216759]), 'Day_Name_Wednesday'),
#  (array([0.02242567]), 'ADDR_PCT_CD_112.0'),
#  (array([0.02264297]), 'Day_Name_Tuesday'),
#  (array([0.02270648]), 'JURIS_DESC_OTHER'),
#  (array([0.02435931]), 'ADDR_PCT_CD_111.0'),
#  (array([0.02464457]), 'PREM_TYP_DESC_STORAGE FACILITY'),
#  (array([0.02491775]), 'ADDR_PCT_CD_10.0'),
#  (array([0.02517757]), 'PREM_TYP_DESC_DRY CLEANER/LAUNDRY'),
#  (array([0.02568021]), 'JURIS_DESC_NYS DEPT TAX AND FINANCE'),
#  (array([0.02679303]), 'ADDR_PCT_CD_78.0'),
#  (array([0.02697973]), 'PREM_TYP_DESC_TAXI (LIVERY LICENSED)'),
#  (array([0.0269959]), 'PREM_TYP_DESC_GROCERY/BODEGA'),
#  (array([0.02791192]), 'ADDR_PCT_CD_94.0'),
#  (array([0.02934898]), 'PREM_TYP_DESC_TAXI (YELLOW LICENSED)'),
#  (array([0.02959338]), 'PREM_TYP_DESC_BRIDGE'),
#  (array([0.0323725]), 'ADDR_PCT_CD_13.0'),
#  (array([0.03262404]), 'PREM_TYP_DESC_CONSTRUCTION SITE'),
#  (array([0.03344353]), 'PREM_TYP_DESC_JEWELRY'),
#  (array([0.03461907]), 'PREM_TYP_DESC_GAS STATION'),
#  (array([0.03499454]), 'ADDR_PCT_CD_9.0'),
#  (array([0.03712417]), 'ADDR_PCT_CD_6.0'),
#  (array([0.03720233]), 'PREM_TYP_DESC_ABANDONED BUILDING'),
#  (array([0.0400164]), 'PREM_TYP_DESC_RESTAURANT/DINER'),
#  (array([0.04014337]), 'Daytime_Day'),
#  (array([0.04181648]), 'PREM_TYP_DESC_LIQUOR STORE'),
#  (array([0.04236883]), 'ADDR_PCT_CD_14.0'),
#  (array([0.04588978]), 'ADDR_PCT_CD_90.0'),
#  (array([0.04602926]), 'PREM_TYP_DESC_VARIETY STORE'),
#  (array([0.04811489]), 'PREM_TYP_DESC_SHOE'),
#  (array([0.05067584]), 'PREM_TYP_DESC_SMALL MERCHANT'),
#  (array([0.05174331]), 'PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)'),
#  (array([0.05378905]), 'PREM_TYP_DESC_STORE UNCLASSIFIED'),
#  (array([0.05456775]), 'BORO_NM_MANHATTAN'),
#  (array([0.055969]), 'PREM_TYP_DESC_CHECK CASHING BUSINESS'),
#  (array([0.0608274]), 'PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)'),
#  (array([0.06108684]), 'ADDR_PCT_CD_19.0'),
#  (array([0.06598414]), 'PREM_TYP_DESC_TELECOMM. STORE'),
#  (array([0.06909593]), 'Duration_lbl_Medium'),
#  (array([0.07907107]), 'Duration_to_PD'),
#  (array([0.08195429]), 'PREM_TYP_DESC_COMMERCIAL BUILDING'),
#  (array([0.09293136]), 'PREM_TYP_DESC_ATM'),
#  (array([0.09727306]), 'PREM_TYP_DESC_GYM/FITNESS FACILITY'),
#  (array([0.10102412]), 'PREM_TYP_DESC_BANK'),
#  (array([0.13387019]), 'PREM_TYP_DESC_FOOD SUPERMARKET'),
#  (array([0.14131194]), 'LOC_OF_OCCUR_DESC_REAR OF'),
#  (array([0.14398509]), 'LOC_OF_OCCUR_DESC_OPPOSITE OF'),
#  (array([0.24132057]), 'PREM_TYP_DESC_CLOTHING/BOUTIQUE'),
#  (array([0.24156131]), 'PREM_TYP_DESC_DRUG STORE'),
#  (array([0.32824196]), 'PREM_TYP_DESC_CHAIN STORE'),
#  (array([0.42160333]), 'Duration_lbl_Short'),
#  (array([0.44159995]), 'PREM_TYP_DESC_DEPARTMENT STORE'),
#  (array([1.8912623]), 'Duration')]

# %% [markdown]
# ## Logistic Regression Model 2
#
# Using a subset of variables based on an importance threshold

# %%
#Now I want to pare down the variables - cutting off at <> .03%
crime_sm = crime_sm[['Duration_lbl_Long', 'PREM_TYP_DESC_RESIDENCE - APT. HOUSE', 'PREM_TYP_DESC_RESIDENCE-HOUSE', 'PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING', 
     'PREM_TYP_DESC_PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC_INSIDE', 'Day_Name_Sunday', 'PREM_TYP_DESC_OTHER', 'PREM_TYP_DESC_HOSPITAL', 
     'ADDR_PCT_CD_67.0', 'Year','GeoCell_X', 'PREM_TYP_DESC_TAXI (YELLOW LICENSED)', 'PREM_TYP_DESC_CONSTRUCTION SITE', 
     'PREM_TYP_DESC_TAXI (LIVERY LICENSED)', 'PREM_TYP_DESC_GAS STATION', 'ADDR_PCT_CD_9.0', 'ADDR_PCT_CD_13.0', 'PREM_TYP_DESC_RESTAURANT/DINER', 
     'PREM_TYP_DESC_JEWELRY', 'PREM_TYP_DESC_ABANDONED BUILDING', 'ADDR_PCT_CD_6.0', 'ADDR_PCT_CD_14.0', 'PREM_TYP_DESC_LIQUOR STORE', 
     'Daytime_Day', 'PREM_TYP_DESC_SHOE', 'ADDR_PCT_CD_90.0', 'PREM_TYP_DESC_VARIETY STORE', 'PREM_TYP_DESC_SMALL MERCHANT', 
      'PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)', 'BORO_NM_MANHATTAN', 'PREM_TYP_DESC_CHECK CASHING BUSINESS', 
     'PREM_TYP_DESC_STORE UNCLASSIFIED', 'ADDR_PCT_CD_19.0', 'PREM_TYP_DESC_TELECOMM. STORE', 'PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)', 
     'Duration_lbl_Medium', 'PREM_TYP_DESC_COMMERCIAL BUILDING', 'PREM_TYP_DESC_GYM/FITNESS FACILITY', 'PREM_TYP_DESC_ATM', 
      'PREM_TYP_DESC_BANK', 'LOC_OF_OCCUR_DESC_OPPOSITE OF', 'LOC_OF_OCCUR_DESC_REAR OF', 'PREM_TYP_DESC_FOOD SUPERMARKET', 
     'PREM_TYP_DESC_CLOTHING/BOUTIQUE', 'PREM_TYP_DESC_DRUG STORE', 'PREM_TYP_DESC_CHAIN STORE', 'Duration_lbl_Short', 
     'PREM_TYP_DESC_DEPARTMENT STORE', 'Duration','NonViolent']]

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'NonViolent' in crime_sm:
    y = crime_sm['NonViolent'].values # get the labels we want
    del crime_sm['NonViolent'] # get rid of the class label
    X = crime_sm.values # use everything else to predict!#rerunning logistic regression with the smaller dataset of variables

# %%
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
# run logistic regression and vary some parameters
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt

# first we create a reusable logisitic regression object
#   here we can setup the object with different learning parameters and constants
lr_clf = LogisticRegression(penalty='l2', C=1.0, class_weight=None, solver='liblinear' ) # get object

# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable logisitc regression model on the training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc = mt.accuracy_score(y_test,y_hat)
    conf = mt.confusion_matrix(y_test,y_hat)
    print("====Iteration",iter_num," ====")
    print("accuracy", acc )
    print("confusion matrix\n",conf)
    iter_num+=1
    
# Also note that every time you run the above code
#   it randomly creates a new training and testing set, 
#   so accuracy will be different each time
# Out:
# ====Iteration 0  ====
# accuracy 0.7199294712902155
# confusion matrix
#  [[12868 23528]
#  [ 9352 71651]]
# ====Iteration 1  ====
# accuracy 0.7287881498138826
# confusion matrix
#  [[15110 21000]
#  [10840 70449]]
# ====Iteration 2  ====
# accuracy 0.7272889888329542
# confusion matrix
#  [[14953 21312]
#  [10704 70430]]

# %%
# this does the exact same thing as the above block of code, but with shorter syntax

for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
    lr_clf.fit(X[train_indices],y[train_indices])  # train object
    y_hat = lr_clf.predict(X[test_indices]) # get test set precitions

    # print the accuracy and confusion matrix 
    print("====Iteration",iter_num," ====")
    print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
    print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# ====Iteration 0  ====
# accuracy 0.7225359670866021
# confusion matrix
#  [[14893 21556]
#  [11018 69932]]
# ====Iteration 1  ====
# accuracy 0.7259942588948799
# confusion matrix
#  [[15083 21487]
#  [10681 70148]]
# ====Iteration 2  ====
# accuracy 0.7215223298324517
# confusion matrix
#  [[15246 21479]
#  [11214 69460]]

# %%
# and here is an even shorter way of getting the accuracies for each training and test set
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(lr_clf, X, y=y, cv=cv_object) # this also can help with parallelism
print(accuracies)
# Out:
# [0.7266757  0.7258239  0.72084089]

# %%
# interpret the weights

# iterate over the coefficients
weights = lr_clf.coef_.T # take transpose to make a column vector
variable_names = crime_sm.columns
for coef, name in zip(weights,variable_names):
    print(name, 'has weight of', coef[0])
    
# does this look correct?
# Out:
# Duration_lbl_Long has weight of -1.2695200180657122
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of -1.0524212924346588
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of -0.719357932240358
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of -0.5750866704470415
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of -1.0679043149938159
# LOC_OF_OCCUR_DESC_INSIDE has weight of 0.04112757104941248
# Day_Name_Sunday has weight of -0.2608563260401754
# PREM_TYP_DESC_OTHER has weight of -0.547490504728834
# PREM_TYP_DESC_HOSPITAL has weight of -0.42860417349271673
# ADDR_PCT_CD_67.0 has weight of -0.285660798661585
# Year has weight of -9.084944497679059e-05
# GeoCell_X has weight of 0.0005023506609162945
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of 0.04971821976365087
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of 0.038174382210218884
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of 0.03927615289815175
# PREM_TYP_DESC_GAS STATION has weight of 0.09058986085989298
# ADDR_PCT_CD_9.0 has weight of 0.16535937971955306
# ADDR_PCT_CD_13.0 has weight of 0.1592374708010448
# PREM_TYP_DESC_RESTAURANT/DINER has weight of 0.021288041472304123
# PREM_TYP_DESC_JEWELRY has weight of 0.05811300597756293
# PREM_TYP_DESC_ABANDONED BUILDING has weight of 0.033439535139571826
# ADDR_PCT_CD_6.0 has weight of 0.17688899944751874
# ADDR_PCT_CD_14.0 has weight of 0.2914116998558336
# PREM_TYP_DESC_LIQUOR STORE has weight of 0.07854606543588873
# Daytime_Day has weight of 0.26551322225761564
# PREM_TYP_DESC_SHOE has weight of 0.07146051793979871
# ADDR_PCT_CD_90.0 has weight of 0.3330992790992416
# PREM_TYP_DESC_VARIETY STORE has weight of 0.11693494274359109
# PREM_TYP_DESC_SMALL MERCHANT has weight of 0.14437570547007428
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of 0.1672623250847049
# BORO_NM_MANHATTAN has weight of 0.4587069170415528
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of 0.12165421923725317
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of 0.1830803113623236
# ADDR_PCT_CD_19.0 has weight of 0.36021152373473736
# PREM_TYP_DESC_TELECOMM. STORE has weight of 0.15220245275119887
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of 0.18030199917177886
# Duration_lbl_Medium has weight of 0.6689292304569848
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of 0.1957332353290729
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of 0.31963181373752864
# PREM_TYP_DESC_ATM has weight of 0.09052205732863561
# PREM_TYP_DESC_BANK has weight of 0.29187712630459023
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.6657664092610487
# LOC_OF_OCCUR_DESC_REAR OF has weight of 0.8912802632106748
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of 0.5141027839883583
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of 0.8625763899205887
# PREM_TYP_DESC_DRUG STORE has weight of 0.8973188405934145
# PREM_TYP_DESC_CHAIN STORE has weight of 1.3069622971888184
# Duration_lbl_Short has weight of 0.601908475307423
# PREM_TYP_DESC_DEPARTMENT STORE has weight of 1.5876143536939362
# Duration has weight of 0.24363164432480722

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,crime_sm.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.7327660371894139
# [[17632 18633]
#  [12740 68394]]
# Duration_lbl_Long has weight of -0.7449082957394068
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of -0.34846365243042443
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of -0.19538651750833622
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of -0.15836981821159343
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of -0.1127588229791326
# Day_Name_Sunday has weight of -0.07019968251958912
# LOC_OF_OCCUR_DESC_INSIDE has weight of -0.06251178095284862
# Year has weight of -0.05331972066257032
# PREM_TYP_DESC_HOSPITAL has weight of -0.04717761206826653
# PREM_TYP_DESC_OTHER has weight of -0.044538282410424464
# ADDR_PCT_CD_67.0 has weight of -0.03611179211530696
# GeoCell_X has weight of -0.018808635507195623
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of 0.030391163924926277
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of 0.030639526667087545
# ADDR_PCT_CD_13.0 has weight of 0.030659460208643238
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of 0.03084669259612827
# ADDR_PCT_CD_6.0 has weight of 0.03269146372812432
# PREM_TYP_DESC_GAS STATION has weight of 0.03345636597594451
# ADDR_PCT_CD_9.0 has weight of 0.03510913071238089
# PREM_TYP_DESC_ABANDONED BUILDING has weight of 0.03709543318564602
# PREM_TYP_DESC_JEWELRY has weight of 0.038951863111264716
# ADDR_PCT_CD_14.0 has weight of 0.040695422720103014
# PREM_TYP_DESC_RESTAURANT/DINER has weight of 0.04175997183446927
# PREM_TYP_DESC_LIQUOR STORE has weight of 0.042902022424560086
# PREM_TYP_DESC_SHOE has weight of 0.04400864873886366
# PREM_TYP_DESC_VARIETY STORE has weight of 0.04448792185157463
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of 0.04889471595095571
# PREM_TYP_DESC_SMALL MERCHANT has weight of 0.05029188335970987
# Daytime_Day has weight of 0.051355249069926945
# ADDR_PCT_CD_90.0 has weight of 0.05321306570616637
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of 0.054078839181344644
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of 0.0561873046269609
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of 0.061056093950770204
# ADDR_PCT_CD_19.0 has weight of 0.06174755020777578
# PREM_TYP_DESC_TELECOMM. STORE has weight of 0.06620038409256802
# Duration_lbl_Medium has weight of 0.06823283119567024
# BORO_NM_MANHATTAN has weight of 0.08258681068583086
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of 0.08540759608165635
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of 0.09757464244493166
# PREM_TYP_DESC_BANK has weight of 0.09975208922741349
# PREM_TYP_DESC_ATM has weight of 0.10121356240672376
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of 0.1359064606029823
# LOC_OF_OCCUR_DESC_REAR OF has weight of 0.14229106130764474
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.14504470794571142
# PREM_TYP_DESC_DRUG STORE has weight of 0.2466444544345746
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of 0.2480346608530655
# PREM_TYP_DESC_CHAIN STORE has weight of 0.32684401572324356
# Duration_lbl_Short has weight of 0.42473872647581135
# PREM_TYP_DESC_DEPARTMENT STORE has weight of 0.44094020825105323
# Duration has weight of 1.908357489698706

# %%
# now let's make a pandas Series with the names and values, and plot them
from matplotlib import pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')


weights = pd.Series(lr_clf.coef_[0],index=crime_sm.columns)
weights.plot(kind='bar', figsize = (12,8))  #added figsize - trying to see if it expands the view
plt.show()

# %%
#Compute precision, recall, F-measure and support
from sklearn.metrics import *
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.49      0.53     36265
#            1       0.79      0.84      0.81     81134
#
#     accuracy                           0.73    117399
#    macro avg       0.68      0.66      0.67    117399
# weighted avg       0.72      0.73      0.73    117399

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, lr_clf.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, lr_clf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# ### Trying SVC on full dataset - smaller variable list

# %%
# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

# %%
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )
# Out:
# accuracy: 0.7325871600269167
# [[17421 18680]
#  [12714 68584]]

# %%
# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,crime_sm.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# Duration_lbl_Long has weight of -0.7387390157704365
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of -0.34802457681694604
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of -0.19878338498879536
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of -0.15581565203055509
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of -0.11701783890529509
# Day_Name_Sunday has weight of -0.07110552122034838
# LOC_OF_OCCUR_DESC_INSIDE has weight of -0.06438276239126973
# Year has weight of -0.0537274555945655
# PREM_TYP_DESC_HOSPITAL has weight of -0.04974628046281412
# PREM_TYP_DESC_OTHER has weight of -0.0410629281854474
# ADDR_PCT_CD_67.0 has weight of -0.03224992738426759
# GeoCell_X has weight of -0.018384251619670836
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of 0.026086143348519334
# ADDR_PCT_CD_13.0 has weight of 0.029401489807630684
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of 0.029725331992708146
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of 0.03159370404243893
# ADDR_PCT_CD_9.0 has weight of 0.034202657799784604
# PREM_TYP_DESC_RESTAURANT/DINER has weight of 0.035145107951158036
# PREM_TYP_DESC_JEWELRY has weight of 0.03541829972025554
# PREM_TYP_DESC_GAS STATION has weight of 0.036174886597180995
# PREM_TYP_DESC_ABANDONED BUILDING has weight of 0.03637855895496351
# ADDR_PCT_CD_6.0 has weight of 0.03864946089074323
# ADDR_PCT_CD_14.0 has weight of 0.04102176401557902
# PREM_TYP_DESC_LIQUOR STORE has weight of 0.043057721566358204
# PREM_TYP_DESC_VARIETY STORE has weight of 0.048376368064845535
# PREM_TYP_DESC_SHOE has weight of 0.04919183193308843
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of 0.051159971589264185
# ADDR_PCT_CD_90.0 has weight of 0.05141678579385661
# PREM_TYP_DESC_SMALL MERCHANT has weight of 0.05358705532536181
# Daytime_Day has weight of 0.05476967414327042
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of 0.057488796460405715
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of 0.05925327941130242
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of 0.059311305632530856
# ADDR_PCT_CD_19.0 has weight of 0.06466464385679815
# Duration_lbl_Medium has weight of 0.06506837428084404
# PREM_TYP_DESC_TELECOMM. STORE has weight of 0.0686528400829827
# BORO_NM_MANHATTAN has weight of 0.08154740615932365
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of 0.08351601211317869
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of 0.09858183429820928
# PREM_TYP_DESC_BANK has weight of 0.09888492687395256
# PREM_TYP_DESC_ATM has weight of 0.10447820794710298
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of 0.13476266510118481
# LOC_OF_OCCUR_DESC_REAR OF has weight of 0.14501257695810293
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.14746352149485215
# PREM_TYP_DESC_DRUG STORE has weight of 0.2422308690241563
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of 0.24377387159736374
# PREM_TYP_DESC_CHAIN STORE has weight of 0.3322845825254455
# Duration_lbl_Short has weight of 0.4234145250562187
# PREM_TYP_DESC_DEPARTMENT STORE has weight of 0.4385938588943346
# Duration has weight of 1.9048087679157921

# %%
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test)

# %%
# lets investigate SVMs on the data and play with the parameters and kernels
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto', cache_size=1000) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )

# %% [markdown]
# ## SVM (SVC) Model 1
#
# Testing with a sample set

# %%
#Now I want to pare down the variables - cutting off at <> .03%
crime_sm_sample = crime_sample[['Duration_lbl_Long', 'PREM_TYP_DESC_RESIDENCE - APT. HOUSE', 'PREM_TYP_DESC_RESIDENCE-HOUSE', 'PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING', 
     'PREM_TYP_DESC_PUBLIC SCHOOL', 'LOC_OF_OCCUR_DESC_INSIDE', 'Day_Name_Sunday', 'PREM_TYP_DESC_OTHER', 'PREM_TYP_DESC_HOSPITAL', 
     'ADDR_PCT_CD_67.0', 'Year','GeoCell_X', 'PREM_TYP_DESC_TAXI (YELLOW LICENSED)', 'PREM_TYP_DESC_CONSTRUCTION SITE', 
     'PREM_TYP_DESC_TAXI (LIVERY LICENSED)', 'PREM_TYP_DESC_GAS STATION', 'ADDR_PCT_CD_9.0', 'ADDR_PCT_CD_13.0', 'PREM_TYP_DESC_RESTAURANT/DINER', 
     'PREM_TYP_DESC_JEWELRY', 'PREM_TYP_DESC_ABANDONED BUILDING', 'ADDR_PCT_CD_6.0', 'ADDR_PCT_CD_14.0', 'PREM_TYP_DESC_LIQUOR STORE', 
     'Daytime_Day', 'PREM_TYP_DESC_SHOE', 'ADDR_PCT_CD_90.0', 'PREM_TYP_DESC_VARIETY STORE', 'PREM_TYP_DESC_SMALL MERCHANT', 
      'PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC)', 'BORO_NM_MANHATTAN', 'PREM_TYP_DESC_CHECK CASHING BUSINESS', 
     'PREM_TYP_DESC_STORE UNCLASSIFIED', 'ADDR_PCT_CD_19.0', 'PREM_TYP_DESC_TELECOMM. STORE', 'PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE)', 
     'Duration_lbl_Medium', 'PREM_TYP_DESC_COMMERCIAL BUILDING', 'PREM_TYP_DESC_GYM/FITNESS FACILITY', 'PREM_TYP_DESC_ATM', 
      'PREM_TYP_DESC_BANK', 'LOC_OF_OCCUR_DESC_OPPOSITE OF', 'LOC_OF_OCCUR_DESC_REAR OF', 'PREM_TYP_DESC_FOOD SUPERMARKET', 
     'PREM_TYP_DESC_CLOTHING/BOUTIQUE', 'PREM_TYP_DESC_DRUG STORE', 'PREM_TYP_DESC_CHAIN STORE', 'Duration_lbl_Short', 
     'PREM_TYP_DESC_DEPARTMENT STORE', 'Duration','NonViolent']]

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'NonViolent' in crime_sm_sample:
    y = crime_sm_sample['NonViolent'].values # get the labels we want
    del crime_sm_sample['NonViolent'] # get rid of the class label
    X = crime_sm_sample.values # use everything else to predict!#rerunning logistic regression with the smaller dataset of variables

# %%
# now we can use the cv_object that we setup before to iterate through the 
#    different training and testing sets. Each time we will reuse the logisitic regression 
#    object, but it gets trained on different data each time we use it.

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]

# %%
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# train the model just as before
lr_clf = LogisticRegression(penalty='l2', C=0.05, solver='liblinear') # get object, the 'C' value is less (can you guess why??)
lr_clf.fit(X_train_scaled,y_train)  # train object

y_hat = lr_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf )

# sort these attributes and spit them out
zip_vars = zip(lr_clf.coef_.T,crime_sm_sample.columns) # combine attributes
zip_vars = sorted(zip_vars)
for coef, name in zip_vars:
    print(name, 'has weight of', coef[0]) # now print them out
# Out:
# accuracy: 0.728
# [[ 305  327]
#  [ 217 1151]]
# Duration_lbl_Long has weight of -0.5361915617390903
# PREM_TYP_DESC_RESIDENCE - APT. HOUSE has weight of -0.3174142104315358
# PREM_TYP_DESC_RESIDENCE-HOUSE has weight of -0.20245283333527536
# PREM_TYP_DESC_RESIDENCE - PUBLIC HOUSING has weight of -0.1654653285192775
# PREM_TYP_DESC_PUBLIC SCHOOL has weight of -0.1306331322817641
# LOC_OF_OCCUR_DESC_INSIDE has weight of -0.09490988709045273
# Year has weight of -0.07105765232445976
# Day_Name_Sunday has weight of -0.06547497955283497
# PREM_TYP_DESC_HOSPITAL has weight of -0.052418151296446176
# PREM_TYP_DESC_OTHER has weight of -0.04050064296059276
# ADDR_PCT_CD_14.0 has weight of -0.028589389664188183
# GeoCell_X has weight of -0.025535911455030078
# ADDR_PCT_CD_67.0 has weight of -0.02524606869189631
# PREM_TYP_DESC_GAS STATION has weight of -0.021835041583732086
# ADDR_PCT_CD_13.0 has weight of -0.00933172355291619
# PREM_TYP_DESC_ABANDONED BUILDING has weight of -0.00722264557416929
# PREM_TYP_DESC_CONSTRUCTION SITE has weight of 0.001909751616891115
# ADDR_PCT_CD_19.0 has weight of 0.011481589308144998
# ADDR_PCT_CD_6.0 has weight of 0.012996707886186048
# PREM_TYP_DESC_VARIETY STORE has weight of 0.01973428415581345
# PREM_TYP_DESC_TAXI (YELLOW LICENSED) has weight of 0.030074247884457637
# PREM_TYP_DESC_COMMERCIAL BUILDING has weight of 0.037746639600756485
# PREM_TYP_DESC_TAXI (LIVERY LICENSED) has weight of 0.0405609291148449
# PREM_TYP_DESC_STORE UNCLASSIFIED has weight of 0.04257100936092052
# ADDR_PCT_CD_9.0 has weight of 0.04899786035124542
# Daytime_Day has weight of 0.04937993034989741
# PREM_TYP_DESC_JEWELRY has weight of 0.052271642440514764
# PREM_TYP_DESC_CHECK CASHING BUSINESS has weight of 0.05694841416041763
# PREM_TYP_DESC_LIQUOR STORE has weight of 0.05758669873116594
# ADDR_PCT_CD_90.0 has weight of 0.05798583766704817
# PREM_TYP_DESC_SMALL MERCHANT has weight of 0.07226554717383284
# PREM_TYP_DESC_TELECOMM. STORE has weight of 0.07818024555880572
# PREM_TYP_DESC_GYM/FITNESS FACILITY has weight of 0.09048464558572819
# PREM_TYP_DESC_RESTAURANT/DINER has weight of 0.09169868212599766
# PREM_TYP_DESC_PARKING LOT/GARAGE (PUBLIC) has weight of 0.09523925839023314
# PREM_TYP_DESC_PARKING LOT/GARAGE (PRIVATE) has weight of 0.10015421099424597
# PREM_TYP_DESC_SHOE has weight of 0.10264252201945123
# PREM_TYP_DESC_ATM has weight of 0.10323647264944755
# BORO_NM_MANHATTAN has weight of 0.11142181872585694
# PREM_TYP_DESC_FOOD SUPERMARKET has weight of 0.11845586289659854
# LOC_OF_OCCUR_DESC_OPPOSITE OF has weight of 0.1268496495687605
# Duration_lbl_Medium has weight of 0.12706952858828152
# PREM_TYP_DESC_BANK has weight of 0.13005446201008272
# LOC_OF_OCCUR_DESC_REAR OF has weight of 0.15081936374110919
# Duration_lbl_Short has weight of 0.2465708567797427
# PREM_TYP_DESC_CLOTHING/BOUTIQUE has weight of 0.2765175780635875
# PREM_TYP_DESC_DRUG STORE has weight of 0.29720656036096754
# PREM_TYP_DESC_DEPARTMENT STORE has weight of 0.42876088649776206
# PREM_TYP_DESC_CHAIN STORE has weight of 0.4445301938422917
# Duration has weight of 1.4492181638267354

# %%
# okay, so run through the cross validation loop and set the training and testing variable for one single iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test)

# %%
# lets investigate SVMs on the data and play with the parameters and kernels
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='rbf', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# accuracy: 0.7195
# [[ 258  378]
#  [ 183 1181]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (5224, 50)
# (5224,)
# [2460 2764]

# %% [markdown]
# ### SVM (SVC) 'Linear'

# %%
# lets investigate SVMs on the data and play with the parameters and kernels - using LINEAR
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=0.5, kernel='linear', degree=3, gamma='auto') # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# accuracy: 0.721
# [[ 390  246]
#  [ 312 1052]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (5072, 50)
# (5072,)
# [2443 2629]

# %% [markdown]
# ### SVM (SVC) adjusting cost

# %%
# lets investigate SVMs on the data and play with the parameters and kernels - using LINEAR
from sklearn.svm import SVC

# train the model just as before
svm_clf = SVC(C=2.5, kernel='rbf', gamma='scale', cache_size=1000) # get object
svm_clf.fit(X_train_scaled, y_train)  # train object

y_hat = svm_clf.predict(X_test_scaled) # get test set precitions

acc = mt.accuracy_score(y_test,y_hat)
conf = mt.confusion_matrix(y_test,y_hat)
print('accuracy:', acc )
print(conf)
# Out:
# accuracy: 0.7265
# [[ 313  323]
#  [ 224 1140]]

# %%
# look at the support vectors
print(svm_clf.support_vectors_.shape)
print(svm_clf.support_.shape)
print(svm_clf.n_support_ )
# Out:
# (5185, 50)
# (5185,)
# [2416 2769]
