# %% [markdown]
# # Linear Regression

# %%
#convert day to categorical variables

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
crime = pd.read_csv('Training_and_Test_Set.csv') # read in the csv %%file

# %%
crime.head()
# Out:
#   CMPLNT_FR_DT     Daytime   Day_Name     Month  Day  Year  Season  GeoCell  \
# 0   11/26/2014     Morning  Wednesday  November   26  2014    Fall       66
# 1    12/1/2014  Late Night     Monday  December    1  2014  Winter       60
# 2   11/10/2015     Morning    Tuesday  November   10  2015    Fall       15
# 3     2/4/2014     Morning    Tuesday  February    4  2014  Winter       48
# 4    8/25/2015  Late Night    Tuesday    August   25  2015  Summer       35
#
#     BORO_NM  PRCP  ...  TMIN  TMAX  Population  PC_INCOME  Hm_Sls_Price_Range  \
# 0    QUEENS  1.24  ...    34    51     2250002      40997              Medium
# 1    QUEENS  0.09  ...    42    65     2250002      40997              Medium
# 2  BROOKLYN  0.26  ...    51    57     2552911      43915                High
# 3    QUEENS  0.00  ...    22    35     2250002      40997              Medium
# 4  BROOKLYN  0.00  ...    73    90     2552911      43915                High
#
#   Holiday Event is_Holiday  is_Event  count_cmplnt
# 0     NaN   NaN          0         0             1
# 1     NaN   NaN          0         0             1
# 2     NaN   NaN          0         0             2
# 3     NaN   NaN          0         0             3
# 4     NaN   NaN          0         0             1
#
# [5 rows x 21 columns]

# %%
# perform one-hot encoding of the categorical data 
tmp_df = pd.get_dummies(crime.BORO_NM,prefix='BORO_NM')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Day_Name,prefix='Day_Name')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Month,prefix='Month')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Season,prefix='Season')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Daytime,prefix='Daytime')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

tmp_df = pd.get_dummies(crime.Daytime,prefix='Hm_Sls_Price_Range')
crime = pd.concat((crime,tmp_df),axis=1) # add back into the dataframe

# %%
#Now we drop the original variables
if 'BORO_NM' in crime:    
    del crime['BORO_NM'] # get rid of the original category as it is now one-hot encoded
if 'Day_Name' in crime:    
    del crime['Day_Name'] # get rid of the original category as it is now one-hot encoded
if 'Month' in crime:    
    del crime['Month'] # get rid of the original category as it is now one-hot encoded
if 'Season' in crime:    
    del crime['Season'] # get rid of the original category as it is now one-hot encoded
if 'Daytime' in crime:    
    del crime['Daytime'] # get rid of the original category as it is now one-hot encoded
if 'Hm_Sls_Price_Range' in crime:    
    del crime['Hm_Sls_Price_Range'] # get rid of the original category as it is now one-hot encoded

# %%
#binary Y/N converted to Is Holiday or Is Event.  Can drop originals
if 'Holiday' in crime:    
    del crime['Holiday']
if 'Event' in crime:    
    del crime['Event']

# %%
#check datatypes for conversions needed
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170650 entries, 0 to 170649
# Data columns (total 53 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   CMPLNT_FR_DT                      170650 non-null  object
#  1   Day                               170650 non-null  int64
#  2   Year                              170650 non-null  int64
#  3   GeoCell                           170650 non-null  int64
#  4   PRCP                              170650 non-null  float64
#  5   SNOW                              170650 non-null  float64
#  6   TMIN                              170650 non-null  int64
#  7   TMAX                              170650 non-null  int64
#  8   Population                        170650 non-null  int64
#  9   PC_INCOME                         170650 non-null  int64
#  10  is_Holiday                        170650 non-null  int64
#  11  is_Event                          170650 non-null  int64
#  12  count_cmplnt                      170650 non-null  int64
#  13  BORO_NM_BRONX                     170650 non-null  uint8
#  14  BORO_NM_BROOKLYN                  170650 non-null  uint8
#  15  BORO_NM_MANHATTAN                 170650 non-null  uint8
#  16  BORO_NM_QUEENS                    170650 non-null  uint8
#  17  BORO_NM_STATEN ISLAND             170650 non-null  uint8
#  18  Day_Name_Friday                   170650 non-null  uint8
#  19  Day_Name_Monday                   170650 non-null  uint8
#  20  Day_Name_Saturday                 170650 non-null  uint8
#  21  Day_Name_Sunday                   170650 non-null  uint8
#  22  Day_Name_Thursday                 170650 non-null  uint8
#  23  Day_Name_Tuesday                  170650 non-null  uint8
#  24  Day_Name_Wednesday                170650 non-null  uint8
#  25  Month_April                       170650 non-null  uint8
#  26  Month_August                      170650 non-null  uint8
#  27  Month_December                    170650 non-null  uint8
#  28  Month_February                    170650 non-null  uint8
#  29  Month_January                     170650 non-null  uint8
#  30  Month_July                        170650 non-null  uint8
#  31  Month_June                        170650 non-null  uint8
#  32  Month_March                       170650 non-null  uint8
#  33  Month_May                         170650 non-null  uint8
#  34  Month_November                    170650 non-null  uint8
#  35  Month_October                     170650 non-null  uint8
#  36  Month_September                   170650 non-null  uint8
#  37  Season_Fall                       170650 non-null  uint8
#  38  Season_Spring                     170650 non-null  uint8
#  39  Season_Summer                     170650 non-null  uint8
#  40  Season_Winter                     170650 non-null  uint8
#  41  Daytime_Day                       170650 non-null  uint8
#  42  Daytime_Early Morning             170650 non-null  uint8
#  43  Daytime_Evening                   170650 non-null  uint8
#  44  Daytime_Late Night                170650 non-null  uint8
#  45  Daytime_Morning                   170650 non-null  uint8
#  46  Daytime_Night                     170650 non-null  uint8
#  47  Hm_Sls_Price_Range_Day            170650 non-null  uint8
#  48  Hm_Sls_Price_Range_Early Morning  170650 non-null  uint8
#  49  Hm_Sls_Price_Range_Evening        170650 non-null  uint8
#  50  Hm_Sls_Price_Range_Late Night     170650 non-null  uint8
#  51  Hm_Sls_Price_Range_Morning        170650 non-null  uint8
#  52  Hm_Sls_Price_Range_Night          170650 non-null  uint8
# dtypes: float64(2), int64(10), object(1), uint8(40)
# memory usage: 23.4+ MB

# %%
#evaluating a linear regression model
# create x explanatory and y response variables for regression
y = crime['count_cmplnt']

#Delete the response variable from our training dataset
X = crime.drop('count_cmplnt', axis=1)
X = crime.drop('CMPLNT_FR_DT', axis=1) #dropping this because I have day, month and year as columns

#inspect data 
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170650 entries, 0 to 170649
# Data columns (total 52 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Day                               170650 non-null  int64
#  1   Year                              170650 non-null  int64
#  2   GeoCell                           170650 non-null  int64
#  3   PRCP                              170650 non-null  float64
#  4   SNOW                              170650 non-null  float64
#  5   TMIN                              170650 non-null  int64
#  6   TMAX                              170650 non-null  int64
#  7   Population                        170650 non-null  int64
#  8   PC_INCOME                         170650 non-null  int64
#  9   is_Holiday                        170650 non-null  int64
#  10  is_Event                          170650 non-null  int64
#  11  count_cmplnt                      170650 non-null  int64
#  12  BORO_NM_BRONX                     170650 non-null  uint8
#  13  BORO_NM_BROOKLYN                  170650 non-null  uint8
#  14  BORO_NM_MANHATTAN                 170650 non-null  uint8
#  15  BORO_NM_QUEENS                    170650 non-null  uint8
#  16  BORO_NM_STATEN ISLAND             170650 non-null  uint8
#  17  Day_Name_Friday                   170650 non-null  uint8
#  18  Day_Name_Monday                   170650 non-null  uint8
#  19  Day_Name_Saturday                 170650 non-null  uint8
#  20  Day_Name_Sunday                   170650 non-null  uint8
#  21  Day_Name_Thursday                 170650 non-null  uint8
#  22  Day_Name_Tuesday                  170650 non-null  uint8
#  23  Day_Name_Wednesday                170650 non-null  uint8
#  24  Month_April                       170650 non-null  uint8
#  25  Month_August                      170650 non-null  uint8
#  26  Month_December                    170650 non-null  uint8
#  27  Month_February                    170650 non-null  uint8
#  28  Month_January                     170650 non-null  uint8
#  29  Month_July                        170650 non-null  uint8
#  30  Month_June                        170650 non-null  uint8
#  31  Month_March                       170650 non-null  uint8
#  32  Month_May                         170650 non-null  uint8
#  33  Month_November                    170650 non-null  uint8
#  34  Month_October                     170650 non-null  uint8
#  35  Month_September                   170650 non-null  uint8
#  36  Season_Fall                       170650 non-null  uint8
#  37  Season_Spring                     170650 non-null  uint8
#  38  Season_Summer                     170650 non-null  uint8
#  39  Season_Winter                     170650 non-null  uint8
#  40  Daytime_Day                       170650 non-null  uint8
#  41  Daytime_Early Morning             170650 non-null  uint8
#  42  Daytime_Evening                   170650 non-null  uint8
#  43  Daytime_Late Night                170650 non-null  uint8
#  44  Daytime_Morning                   170650 non-null  uint8
#  45  Daytime_Night                     170650 non-null  uint8
#  46  Hm_Sls_Price_Range_Day            170650 non-null  uint8
#  47  Hm_Sls_Price_Range_Early Morning  170650 non-null  uint8
#  48  Hm_Sls_Price_Range_Evening        170650 non-null  uint8
#  49  Hm_Sls_Price_Range_Late Night     170650 non-null  uint8
#  50  Hm_Sls_Price_Range_Morning        170650 non-null  uint8
#  51  Hm_Sls_Price_Range_Night          170650 non-null  uint8
# dtypes: float64(2), int64(10), uint8(40)
# memory usage: 22.1 MB

# %%
y.describe()
# Out:
# count    170650.000000
# mean          4.714122
# std           5.140051
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           6.000000
# max         132.000000
# Name: count_cmplnt, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136520 entries, 50203 to 43567
# Data columns (total 52 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Day                               136520 non-null  int64
#  1   Year                              136520 non-null  int64
#  2   GeoCell                           136520 non-null  int64
#  3   PRCP                              136520 non-null  float64
#  4   SNOW                              136520 non-null  float64
#  5   TMIN                              136520 non-null  int64
#  6   TMAX                              136520 non-null  int64
#  7   Population                        136520 non-null  int64
#  8   PC_INCOME                         136520 non-null  int64
#  9   is_Holiday                        136520 non-null  int64
#  10  is_Event                          136520 non-null  int64
#  11  count_cmplnt                      136520 non-null  int64
#  12  BORO_NM_BRONX                     136520 non-null  uint8
#  13  BORO_NM_BROOKLYN                  136520 non-null  uint8
#  14  BORO_NM_MANHATTAN                 136520 non-null  uint8
#  15  BORO_NM_QUEENS                    136520 non-null  uint8
#  16  BORO_NM_STATEN ISLAND             136520 non-null  uint8
#  17  Day_Name_Friday                   136520 non-null  uint8
#  18  Day_Name_Monday                   136520 non-null  uint8
#  19  Day_Name_Saturday                 136520 non-null  uint8
#  20  Day_Name_Sunday                   136520 non-null  uint8
#  21  Day_Name_Thursday                 136520 non-null  uint8
#  22  Day_Name_Tuesday                  136520 non-null  uint8
#  23  Day_Name_Wednesday                136520 non-null  uint8
#  24  Month_April                       136520 non-null  uint8
#  25  Month_August                      136520 non-null  uint8
#  26  Month_December                    136520 non-null  uint8
#  27  Month_February                    136520 non-null  uint8
#  28  Month_January                     136520 non-null  uint8
#  29  Month_July                        136520 non-null  uint8
#  30  Month_June                        136520 non-null  uint8
#  31  Month_March                       136520 non-null  uint8
#  32  Month_May                         136520 non-null  uint8
#  33  Month_November                    136520 non-null  uint8
#  34  Month_October                     136520 non-null  uint8
#  35  Month_September                   136520 non-null  uint8
#  36  Season_Fall                       136520 non-null  uint8
#  37  Season_Spring                     136520 non-null  uint8
#  38  Season_Summer                     136520 non-null  uint8
#  39  Season_Winter                     136520 non-null  uint8
#  40  Daytime_Day                       136520 non-null  uint8
#  41  Daytime_Early Morning             136520 non-null  uint8
#  42  Daytime_Evening                   136520 non-null  uint8
#  43  Daytime_Late Night                136520 non-null  uint8
#  44  Daytime_Morning                   136520 non-null  uint8
#  45  Daytime_Night                     136520 non-null  uint8
#  46  Hm_Sls_Price_Range_Day            136520 non-null  uint8
#  47  Hm_Sls_Price_Range_Early Morning  136520 non-null  uint8
#  48  Hm_Sls_Price_Range_Evening        136520 non-null  uint8
#  49  Hm_Sls_Price_Range_Late Night     136520 non-null  uint8
#  50  Hm_Sls_Price_Range_Morning        136520 non-null  uint8
#  51  Hm_Sls_Price_Range_Night          136520 non-null  uint8
# dtypes: float64(2), int64(10), uint8(40)
# memory usage: 18.7 MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34130 entries, 29879 to 47678
# Data columns (total 52 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Day                               34130 non-null  int64
#  1   Year                              34130 non-null  int64
#  2   GeoCell                           34130 non-null  int64
#  3   PRCP                              34130 non-null  float64
#  4   SNOW                              34130 non-null  float64
#  5   TMIN                              34130 non-null  int64
#  6   TMAX                              34130 non-null  int64
#  7   Population                        34130 non-null  int64
#  8   PC_INCOME                         34130 non-null  int64
#  9   is_Holiday                        34130 non-null  int64
#  10  is_Event                          34130 non-null  int64
#  11  count_cmplnt                      34130 non-null  int64
#  12  BORO_NM_BRONX                     34130 non-null  uint8
#  13  BORO_NM_BROOKLYN                  34130 non-null  uint8
#  14  BORO_NM_MANHATTAN                 34130 non-null  uint8
#  15  BORO_NM_QUEENS                    34130 non-null  uint8
#  16  BORO_NM_STATEN ISLAND             34130 non-null  uint8
#  17  Day_Name_Friday                   34130 non-null  uint8
#  18  Day_Name_Monday                   34130 non-null  uint8
#  19  Day_Name_Saturday                 34130 non-null  uint8
#  20  Day_Name_Sunday                   34130 non-null  uint8
#  21  Day_Name_Thursday                 34130 non-null  uint8
#  22  Day_Name_Tuesday                  34130 non-null  uint8
#  23  Day_Name_Wednesday                34130 non-null  uint8
#  24  Month_April                       34130 non-null  uint8
#  25  Month_August                      34130 non-null  uint8
#  26  Month_December                    34130 non-null  uint8
#  27  Month_February                    34130 non-null  uint8
#  28  Month_January                     34130 non-null  uint8
#  29  Month_July                        34130 non-null  uint8
#  30  Month_June                        34130 non-null  uint8
#  31  Month_March                       34130 non-null  uint8
#  32  Month_May                         34130 non-null  uint8
#  33  Month_November                    34130 non-null  uint8
#  34  Month_October                     34130 non-null  uint8
#  35  Month_September                   34130 non-null  uint8
#  36  Season_Fall                       34130 non-null  uint8
#  37  Season_Spring                     34130 non-null  uint8
#  38  Season_Summer                     34130 non-null  uint8
#  39  Season_Winter                     34130 non-null  uint8
#  40  Daytime_Day                       34130 non-null  uint8
#  41  Daytime_Early Morning             34130 non-null  uint8
#  42  Daytime_Evening                   34130 non-null  uint8
#  43  Daytime_Late Night                34130 non-null  uint8
#  44  Daytime_Morning                   34130 non-null  uint8
#  45  Daytime_Night                     34130 non-null  uint8
#  46  Hm_Sls_Price_Range_Day            34130 non-null  uint8
#  47  Hm_Sls_Price_Range_Early Morning  34130 non-null  uint8
#  48  Hm_Sls_Price_Range_Evening        34130 non-null  uint8
#  49  Hm_Sls_Price_Range_Late Night     34130 non-null  uint8
#  50  Hm_Sls_Price_Range_Morning        34130 non-null  uint8
#  51  Hm_Sls_Price_Range_Night          34130 non-null  uint8
# dtypes: float64(2), int64(10), uint8(40)
# memory usage: 4.7 MB

# %%
from sklearn.preprocessing import StandardScaler

# we want to normalize the features based upon the mean and standard deviation of each column. 
# However, we do not want to accidentally use the testing data to find out the mean and std (this would be snooping)
# to Make things easier, let's start by just using whatever was last stored in the variables:
##    X_train , y_train , X_test, y_test (they were set in a for loop above)

# scale attributes by the training set
scl_obj = StandardScaler()
scl_obj.fit(X_train) # find scalings for each column that make this zero mean and unit std
# the line of code above only looks at training data to get mean and std and we can use it 
# to transform new feature data

X_train_scaled = scl_obj.transform(X_train) # apply to training
X_test_scaled = scl_obj.transform(X_test) # apply those means and std to the test set (without snooping at the test set values)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
lr = regressor.fit(X_train, y_train)

# %%
print(regressor.intercept_)
# Out:
# -1.8383529987175962e-07

# %%
coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#                                    Coefficient
# Day                               1.775225e-14
# Year                              9.105538e-11
# GeoCell                          -1.219318e-13
# PRCP                              3.719858e-12
# SNOW                             -1.000935e-12
# TMIN                              4.452549e-13
# TMAX                             -4.752865e-13
# Population                        2.220446e-16
# PC_INCOME                         9.367507e-17
# is_Holiday                       -8.762708e-12
# is_Event                          4.492150e-12
# count_cmplnt                      1.000000e+00
# BORO_NM_BRONX                    -5.998908e-13
# BORO_NM_BROOKLYN                 -3.530856e-13
# BORO_NM_MANHATTAN                 1.075141e-12
# BORO_NM_QUEENS                    4.850981e-14
# BORO_NM_STATEN ISLAND            -1.699938e-13
# Day_Name_Friday                  -1.095321e-12
# Day_Name_Monday                   2.167632e-13
# Day_Name_Saturday                 2.600995e-13
# Day_Name_Sunday                  -2.388743e-12
# Day_Name_Thursday                 3.031575e-13
# Day_Name_Tuesday                  1.524478e-12
# Day_Name_Wednesday                1.159651e-12
# Month_April                      -3.571010e-12
# Month_August                      2.241710e-12
# Month_December                   -2.564240e-12
# Month_February                    2.929978e-12
# Month_January                     6.148001e-13
# Month_July                        1.497768e-12
# Month_June                       -3.950957e-12
# Month_March                       2.711640e-12
# Month_May                         5.756710e-13
# Month_November                   -9.762742e-14
# Month_October                     1.958465e-12
# Month_September                  -2.380825e-12
# Season_Fall                      -5.062808e-13
# Season_Spring                    -2.853516e-13
# Season_Summer                    -1.903130e-13
# Season_Winter                     1.024520e-12
# Daytime_Day                       2.307308e-13
# Daytime_Early Morning             1.478500e-12
# Daytime_Evening                  -1.103740e-12
# Daytime_Late Night               -8.082163e-13
# Daytime_Morning                  -1.110683e-13
# Daytime_Night                     3.017777e-13
# Hm_Sls_Price_Range_Day            2.306957e-13
# Hm_Sls_Price_Range_Early Morning  1.478500e-12
# Hm_Sls_Price_Range_Evening       -1.103742e-12
# Hm_Sls_Price_Range_Late Night    -8.082181e-13
# Hm_Sls_Price_Range_Morning       -1.110527e-13
# Hm_Sls_Price_Range_Night          3.017205e-13

# %%
print(regressor.coef_)
# Out:
# [ 1.77522512e-14  9.10553799e-11 -1.21931762e-13  3.71985776e-12
#  -1.00093545e-12  4.45254944e-13 -4.75286477e-13  2.22044605e-16
#   9.36750677e-17 -8.76270844e-12  4.49215014e-12  1.00000000e+00
#  -5.99890797e-13 -3.53085616e-13  1.07514149e-12  4.85098073e-14
#  -1.69993793e-13 -1.09532088e-12  2.16763239e-13  2.60099451e-13
#  -2.38874285e-12  3.03157456e-13  1.52447759e-12  1.15965137e-12
#  -3.57100981e-12  2.24171029e-12 -2.56424049e-12  2.92997831e-12
#   6.14800095e-13  1.49776806e-12 -3.95095675e-12  2.71163994e-12
#   5.75671021e-13 -9.76274183e-14  1.95846507e-12 -2.38082514e-12
#  -5.06280781e-13 -2.85351603e-13 -1.90313043e-13  1.02451966e-12
#   2.30730799e-13  1.47849961e-12 -1.10374036e-12 -8.08216341e-13
#  -1.11068273e-13  3.01777700e-13  2.30695671e-13  1.47849961e-12
#  -1.10374210e-12 -8.08218076e-13 -1.11052660e-13  3.01720454e-13]

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#         Actual  Predicted
# 29879        9        9.0
# 142968      12       12.0
# 58631        7        7.0
# 160497       1        1.0
# 57495        5        5.0
# ...        ...        ...
# 531          1        1.0
# 164879       1        1.0
# 105058       4        4.0
# 34210        3        3.0
# 47678        1        1.0
#
# [34130 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.298341313810322e-10
# Mean Squared Error: 2.453997065027149e-20
# Root Mean Squared Error: 1.5665238794947075e-10

# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

# %%
X2 = sm.add_constant(X_train)
est = sm.OLS(y_train, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           count_cmplnt   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.079e+24
# Date:                Thu, 15 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:15:19   Log-Likelihood:             2.7994e+06
# No. Observations:              136520   AIC:                        -5.599e+06
# Df Residuals:                  136482   BIC:                        -5.598e+06
# Df Model:                          37
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              -4.2e-09   4.02e-09     -1.045      0.296   -1.21e-08    3.68e-09
# Day                              -2.075e-12    9.3e-14    -22.313      0.000   -2.26e-12   -1.89e-12
# Year                              6.285e-12   6.13e-12      1.025      0.305   -5.74e-12    1.83e-11
# GeoCell                           1.468e-13   7.01e-14      2.095      0.036    9.44e-15    2.84e-13
# PRCP                               1.56e-10   2.34e-12     66.571      0.000    1.51e-10    1.61e-10
# SNOW                              1.612e-10   1.07e-12    150.105      0.000    1.59e-10    1.63e-10
# TMIN                              2.634e-12   2.08e-13     12.663      0.000    2.23e-12    3.04e-12
# TMAX                             -7.315e-13   1.88e-13     -3.890      0.000    -1.1e-12   -3.63e-13
# Population                       -2.743e-15   2.51e-15     -1.091      0.275   -7.67e-15    2.19e-15
# PC_INCOME                        -7.415e-17   2.19e-15     -0.034      0.973   -4.36e-15    4.21e-15
# is_Holiday                       -8.799e-15   5.26e-12     -0.002      0.999   -1.03e-11    1.03e-11
# is_Event                         -1.185e-13   2.61e-12     -0.045      0.964   -5.24e-12       5e-12
# count_cmplnt                         1.0000   1.78e-13    5.6e+12      0.000       1.000       1.000
# BORO_NM_BRONX                    -1.529e-09   1.53e-09     -0.997      0.319   -4.54e-09    1.48e-09
# BORO_NM_BROOKLYN                  1.527e-09   1.43e-09      1.072      0.284   -1.27e-09    4.32e-09
# BORO_NM_MANHATTAN                -1.004e-09   7.74e-10     -1.298      0.194   -2.52e-09    5.12e-10
# BORO_NM_QUEENS                    7.345e-10   6.63e-10      1.108      0.268   -5.65e-10    2.03e-09
# BORO_NM_STATEN ISLAND            -3.928e-09    3.8e-09     -1.034      0.301   -1.14e-08    3.52e-09
# Day_Name_Friday                  -5.999e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Day_Name_Monday                      -6e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Day_Name_Saturday                    -6e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Day_Name_Sunday                  -5.999e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Day_Name_Thursday                -5.999e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Day_Name_Tuesday                     -6e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Day_Name_Wednesday                   -6e-10   5.74e-10     -1.045      0.296   -1.72e-09    5.25e-10
# Month_April                        -3.5e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.06e-10
# Month_August                     -3.501e-10   3.35e-10     -1.046      0.296   -1.01e-09    3.06e-10
# Month_December                   -3.499e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.06e-10
# Month_February                   -3.499e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.07e-10
# Month_January                    -3.498e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.07e-10
# Month_July                       -3.501e-10   3.35e-10     -1.046      0.296   -1.01e-09    3.06e-10
# Month_June                       -3.501e-10   3.35e-10     -1.046      0.296   -1.01e-09    3.06e-10
# Month_March                      -3.498e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.07e-10
# Month_May                          -3.5e-10   3.35e-10     -1.046      0.296   -1.01e-09    3.06e-10
# Month_November                   -3.499e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.06e-10
# Month_October                      -3.5e-10   3.35e-10     -1.045      0.296   -1.01e-09    3.06e-10
# Month_September                  -3.501e-10   3.35e-10     -1.046      0.296   -1.01e-09    3.06e-10
# Season_Fall                       -1.05e-09      1e-09     -1.045      0.296   -3.02e-09    9.19e-10
# Season_Spring                     -1.05e-09      1e-09     -1.045      0.296   -3.02e-09    9.19e-10
# Season_Summer                     -1.05e-09      1e-09     -1.046      0.296   -3.02e-09    9.18e-10
# Season_Winter                    -1.049e-09      1e-09     -1.045      0.296   -3.02e-09    9.19e-10
# Daytime_Day                          -7e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Daytime_Early Morning            -6.999e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Daytime_Evening                  -6.999e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Daytime_Late Night                   -7e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.12e-10
# Daytime_Morning                      -7e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Daytime_Night                    -6.999e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Hm_Sls_Price_Range_Day               -7e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.12e-10
# Hm_Sls_Price_Range_Early Morning -6.999e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Hm_Sls_Price_Range_Evening       -6.999e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Hm_Sls_Price_Range_Late Night        -7e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.12e-10
# Hm_Sls_Price_Range_Morning           -7e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# Hm_Sls_Price_Range_Night         -6.999e-10    6.7e-10     -1.045      0.296   -2.01e-09    6.13e-10
# ==============================================================================
# Omnibus:                   127214.367   Durbin-Watson:                   0.694
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6583590.223
# Skew:                          -4.467   Prob(JB):                         0.00
# Kurtosis:                      35.826   Cond. No.                     1.07e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.73e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
